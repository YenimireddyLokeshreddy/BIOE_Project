# %%
#installing pandas datareader
#!pip install pandas-datareader

# %%
import pandas_datareader as pdr
import pandas as pd
from datetime import datetime

# %%
#!pip install yfinance

# %%
import yfinance as yf

# Define the stock symbol and the date range
symbol = 'AAPL'
start_date = '2020-07-14'
end_date = '2023-07-17'

# Retrieve the stock data from Yahoo Finance
data = yf.download(symbol, start=start_date, end=end_date)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
data.head()
# Out:
#                  Open       High        Low      Close  Adj Close     Volume
# Date
# 2020-07-14  94.839996  97.254997  93.877502  97.057503  95.291222  170989200
# 2020-07-15  98.989998  99.247498  96.489998  97.724998  95.946564  153198000
# 2020-07-16  96.562500  97.404999  95.904999  96.522499  94.765968  110577600
# 2020-07-17  96.987503  97.147499  95.839996  96.327499  94.574493   92186800
# 2020-07-20  96.417503  98.500000  96.062500  98.357498  96.567558   90318000

# %%
data.tail()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2023-07-10  189.259995  189.990005  187.039993  188.610001  188.610001
# 2023-07-11  189.160004  189.300003  186.600006  188.080002  188.080002
# 2023-07-12  189.679993  191.699997  188.470001  189.770004  189.770004
# 2023-07-13  190.500000  191.190002  189.779999  190.539993  190.539993
# 2023-07-14  190.229996  191.179993  189.630005  190.690002  190.690002
#
#               Volume
# Date
# 2023-07-10  59922200
# 2023-07-11  46638100
# 2023-07-12  60750200
# 2023-07-13  41342300
# 2023-07-14  41573900

# %%
data['High'].plot(xlim=['2020-07-14','2023-07-17'],ylim=[120,200],figsize=(12,4),ls='--',c='green')
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
index = data.loc['2020-07-14':'2023-07-14'].index
stock_open = data.loc['2020-07-14':'2023-07-14']['Open']
stock_high = data.loc['2020-07-14':'2023-07-14']['High']
stock_low = data.loc['2020-07-14':'2023-07-14']['Low']
stock_close = data.loc['2020-07-14':'2023-07-14']['Close']

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

figure, axis = plt.subplots(figsize=(12,4))
plt.tight_layout()
# preventing overlapping
figure.autofmt_xdate()

# assuming 'index', 'stock_open', 'stock_high', 'stock_low', 'stock_close' are defined
axis.plot(index, stock_open, label='Open')
axis.plot(index, stock_high, label='High')
axis.plot(index, stock_low, label='Low')
axis.plot(index, stock_close, label='Close')

# Add labels and title
axis.set_xlabel('Date')
axis.set_ylabel('Price')
axis.set_title('Stock Prices Over Time')

# Add a legend
axis.legend()

plt.show()

# %%
df1 = stock_open

# %%
df1
# Out:
# Date
# 2020-07-14     94.839996
# 2020-07-15     98.989998
# 2020-07-16     96.562500
# 2020-07-17     96.987503
# 2020-07-20     96.417503
#                  ...
# 2023-07-10    189.259995
# 2023-07-11    189.160004
# 2023-07-12    189.679993
# 2023-07-13    190.500000
# 2023-07-14    190.229996
# Name: Open, Length: 756, dtype: float64

# %%
# Calculate the split point
split_point = int(len(df1) * 0.8)

# Split the data
train_data = df1.iloc[:split_point]
test_data = df1.iloc[split_point:]

# Print the shapes of the training and testing sets
print("Training set shape:", train_data.shape)
print("Testing set shape:", test_data.shape)
# Out:
# Training set shape: (604,)
# Testing set shape: (152,)

# %%
import numpy as np
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler(feature_range=(0,1))
train_data_scaled=scaler.fit_transform(np.array(train_data).reshape(-1,1))
test_data_scaled=scaler.fit_transform(np.array(test_data).reshape(-1,1))

# %%
train_data_scaled
# Out:
# array([[0.04203828],
#        [0.08732296],
#        [0.06083419],
#        [0.0654718 ],
#        [0.05925199],
#        [0.08931443],
#        [0.06225271],
#        [0.06558086],
#        [0.        ],
#        [0.02970779],
#        [0.03688242],
#        [0.03014428],
#        [0.03491826],
#        [0.12982512],
#        [0.18782217],
#        [0.19799761],
#        [0.20067108],
#        [0.21188308],
#        [0.24243662],
#        [0.23583485],
#        [0.22896034],
#        [0.21289243],
#        [0.25580377],
#        [0.26016857],
#        [0.27361755],
#        [0.2549581 ],
#        [0.27274457],
#        [0.27020756],
#        [0.30853581],
#        [0.4114902 ],
#        [0.36784241],
#        [0.38401939],
#        [0.39452217],
#        [0.38219159],
#        [0.39929616],
#        [0.45582007],
#        [0.50852489],
#        [0.39198516],
#        [0.31734726],
#        [0.25056599],
#        [0.28668466],
#        [0.32051174],
#        [0.25733144],
#        [0.25896825],
#        [0.29836046],
#        [0.26453338],
#        [0.20440841],
#        [0.21182855],
#        [0.14788442],
#        [0.23670782],
#        [0.22514117],
#        [0.15475893],
#        [0.19033196],
#        [0.26213273],
#        [0.25711323],
#        [0.24882012],
#        [0.29083117],
#        [0.23899933],
#        [0.25012958],
#        [0.26966193],
#        [0.25787707],
#        [0.27566355],
#        [0.26507892],
#        [0.31723811],
#        [0.37408946],
#        [0.32749539],
#        [0.30261612],
#        [0.33055073],
#        [0.31614693],
#        [0.27511791],
#        [0.28024655],
#        [0.28875787],
#        [0.27719121],
#        [0.25122076],
#        [0.26737043],
#        [0.26256922],
#        [0.23332514],
#        [0.21903041],
#        [0.1977521 ],
#        [0.20375372],
#        [0.25263929],
#        [0.29421386],
#        [0.29825131],
#        [0.32203941],
#        [0.2680252 ],
#        [0.28592082],
#        [0.31243691],
#        [0.31047275],
#        [0.30479848],
#        [0.31167307],
#        [0.3014158 ],
#        [0.29028554],
#        [0.30174314],
#        [0.28581168],
#        [0.25012958],
#        [0.2680252 ],
#        [0.27915537],
#        [0.28352018],
#        [0.32760453],
#        [0.33862556],
#        [0.35499351],
#        [0.34495452],
#        [0.34179004],
#        [0.36426875],
#        [0.36601462],
#        [0.32203941],
#        [0.34309951],
#        [0.34495452],
#        [0.36394132],
#        [0.39744114],
#        [0.41369987],
#        [0.41435473],
#        [0.37136146],
#        [0.44327137],
#        [0.44927299],
#        [0.44010698],
#        [0.46924191],
#        [0.51354447],
#        [0.4865919 ],
#        [0.47022395],
#        [0.46411327],
#        [0.41359081],
#        [0.40082383],
#        [0.40780748],
#        [0.4522191 ],
#        [0.41686443],
#        [0.40933515],
#        [0.4121722 ],
#        [0.43443271],
#        [0.41239048],
#        [0.40147852],
#        [0.4110811 ],
#        [0.46716861],
#        [0.49423024],
#        [0.56832259],
#        [0.57410592],
#        [0.57225074],
#        [0.52958508],
#        [0.48931989],
#        [0.46662298],
#        [0.48822863],
#        [0.48855597],
#        [0.49444853],
#        [0.50590613],
#        [0.49150225],
#        [0.49794027],
#        [0.4964126 ],
#        [0.49008364],
#        [0.47317022],
#        [0.48560986],
#        [0.43934306],
#        [0.41697349],
#        [0.42832203],
#        [0.40398822],
#        [0.35761244],
#        [0.37048857],
#        [0.36765143],
#        [0.34484538],
#        [0.3575033 ],
#        [0.40835311],
#        [0.36906996],
#        [0.33567937],
#        [0.32727719],
#        [0.32673156],
#        [0.3059988 ],
#        [0.33502467],
#        [0.34429983],
#        [0.32094823],
#        [0.33196934],
#        [0.3787816 ],
#        [0.36077692],
#        [0.34800986],
#        [0.31549224],
#        [0.32018439],
#        [0.35292029],
#        [0.34735517],
#        [0.31156393],
#        [0.3204026 ],
#        [0.33458819],
#        [0.31778375],
#        [0.33458819],
#        [0.35652126],
#        [0.35881277],
#        [0.38751121],
#        [0.38020021],
#        [0.4142455 ],
#        [0.42352074],
#        [0.4532013 ],
#        [0.45232833],
#        [0.47960824],
#        [0.46738689],
#        [0.47262459],
#        [0.46400404],
#        [0.48048122],
#        [0.45145535],
#        [0.45887541],
#        [0.44927299],
#        [0.47840792],
#        [0.480372  ],
#        [0.47273365],
#        [0.49630354],
#        [0.44512639],
#        [0.44796344],
#        [0.43868837],
#        [0.41697349],
#        [0.40267884],
#        [0.43497834],
#        [0.41926508],
#        [0.35477531],
#        [0.35368413],
#        [0.36656025],
#        [0.38478322],
#        [0.39100304],
#        [0.3881659 ],
#        [0.35106528],
#        [0.37365305],
#        [0.40191501],
#        [0.38216437],
#        [0.40191501],
#        [0.39253071],
#        [0.38685652],
#        [0.37736308],
#        [0.37201624],
#        [0.36328663],
#        [0.36765143],
#        [0.36099513],
#        [0.38391024],
#        [0.38860239],
#        [0.3952587 ],
#        [0.3931854 ],
#        [0.38783856],
#        [0.40191501],
#        [0.42504841],
#        [0.42974047],
#        [0.42352074],
#        [0.43345067],
#        [0.42897672],
#        [0.44894564],
#        [0.46684126],
#        [0.47426132],
#        [0.46345858],
#        [0.46291295],
#        [0.47808058],
#        [0.49302992],
#        [0.49772215],
#        [0.51190757],
#        [0.53558669],
#        [0.57345106],
#        [0.5520637 ],
#        [0.56483068],
#        [0.60258616],
#        [0.57879799],
#        [0.62320978],
#        [0.63564941],
#        [0.62713809],
#        [0.57574265],
#        [0.57257825],
#        [0.59516594],
#        [0.59963989],
#        [0.61720816],
#        [0.62506479],
#        [0.63433986],
#        [0.58730931],
#        [0.58599993],
#        [0.58261724],
#        [0.60422289],
#        [0.59822128],
#        [0.61415282],
#        [0.61098826],
#        [0.60411383],
#        [0.60247694],
#        [0.60509587],
#        [0.60084021],
#        [0.60236788],
#        [0.63270313],
#        [0.6280109 ],
#        [0.64645215],
#        [0.64176009],
#        [0.58970996],
#        [0.61600784],
#        [0.6255012 ],
#        [0.63794083],
#        [0.64186915],
#        [0.62593777],
#        [0.61644424],
#        [0.63303048],
#        [0.67296832],
#        [0.67482334],
#        [0.68617171],
#        [0.68497139],
#        [0.69817494],
#        [0.72010793],
#        [0.70384921],
#        [0.69850229],
#        [0.65081704],
#        [0.6477617 ],
#        [0.62822919],
#        [0.62691981],
#        [0.63106641],
#        [0.57628828],
#        [0.57770673],
#        [0.58338099],
#        [0.60738729],
#        [0.59658455],
#        [0.59451125],
#        [0.57028667],
#        [0.56177535],
#        [0.57476061],
#        [0.55555544],
#        [0.55402778],
#        [0.52925773],
#        [0.52903944],
#        [0.56821337],
#        [0.57879799],
#        [0.55959299],
#        [0.57006838],
#        [0.54835367],
#        [0.55784703],
#        [0.57596094],
#        [0.57246903],
#        [0.61131561],
#        [0.62975686],
#        [0.63095718],
#        [0.64055976],
#        [0.62953857],
#        [0.63663145],
#        [0.6369588 ],
#        [0.64197837],
#        [0.61360719],
#        [0.63292142],
#        [0.62932045],
#        [0.64819811],
#        [0.66118338],
#        [0.66456606],
#        [0.65932836],
#        [0.64612481],
#        [0.64416073],
#        [0.63259407],
#        [0.62681058],
#        [0.64797982],
#        [0.64328776],
#        [0.65485442],
#        [0.68442592],
#        [0.72741893],
#        [0.77139415],
#        [0.76528347],
#        [0.7612461 ],
#        [0.74837006],
#        [0.74618753],
#        [0.75295306],
#        [0.83468359],
#        [0.7393131 ],
#        [0.79692828],
#        [0.79987439],
#        [0.85214281],
#        [0.88542434],
#        [0.9157596 ],
#        [0.91903322],
#        [0.98352282],
#        [0.91946963],
#        [0.91794196],
#        [0.96344484],
#        [0.86141788],
#        [0.8434132 ],
#        [0.87920444],
#        [0.89535411],
#        [0.92601687],
#        [0.93954761],
#        [0.97304743],
#        [0.96399047],
#        [0.96551814],
#        [0.95045957],
#        [0.94762252],
#        [1.        ],
#        [0.96704581],
#        [0.89164408],
#        [0.89371738],
#        [0.85214281],
#        [0.88749764],
#        [0.92896299],
#        [0.92525296],
#        [0.87680379],
#        [0.87865881],
#        [0.8621818 ],
#        [0.82922761],
#        [0.801293  ],
#        [0.75328041],
#        [0.74193187],
#        [0.79125401],
#        [0.77979641],
#        [0.81536953],
#        [0.86392775],
#        [0.90593873],
#        [0.91401364],
#        [0.91106737],
#        [0.88051382],
#        [0.89339003],
#        [0.88105945],
#        [0.92819923],
#        [0.90735734],
#        [0.8876067 ],
#        [0.83348327],
#        [0.87276642],
#        [0.882369  ],
#        [0.87342111],
#        [0.86021772],
#        [0.80740367],
#        [0.81351435],
#        [0.67209534],
#        [0.79496404],
#        [0.78645272],
#        [0.80434834],
#        [0.80096565],
#        [0.8454865 ],
#        [0.80205692],
#        [0.78972634],
#        [0.74018608],
#        [0.76921179],
#        [0.75524448],
#        [0.74138624],
#        [0.65976477],
#        [0.65376315],
#        [0.72087185],
#        [0.73789449],
#        [0.75862717],
#        [0.79136307],
#        [0.813187  ],
#        [0.8402488 ],
#        [0.87374846],
#        [0.90452028],
#        [0.88586075],
#        [0.93518289],
#        [0.95547915],
#        [0.94773158],
#        [0.90615701],
#        [0.91204957],
#        [0.94402155],
#        [0.88793405],
#        [0.87483972],
#        [0.88160509],
#        [0.84810543],
#        [0.84057615],
#        [0.83370156],
#        [0.86894716],
#        [0.79583702],
#        [0.80784025],
#        [0.8486509 ],
#        [0.85028779],
#        [0.82355351],
#        [0.76528347],
#        [0.77761405],
#        [0.70843222],
#        [0.74487815],
#        [0.7731401 ],
#        [0.71716182],
#        [0.73287492],
#        [0.74946115],
#        [0.79507326],
#        [0.70952331],
#        [0.69773837],
#        [0.70417655],
#        [0.68213433],
#        [0.56504897],
#        [0.58490866],
#        [0.59538423],
#        [0.63150281],
#        [0.60956982],
#        [0.53351339],
#        [0.52489284],
#        [0.51070725],
#        [0.54366144],
#        [0.5176909 ],
#        [0.50634253],
#        [0.59363827],
#        [0.6337944 ],
#        [0.64285118],
#        [0.6202635 ],
#        [0.61011528],
#        [0.61153389],
#        [0.5822899 ],
#        [0.62844747],
#        [0.61207952],
#        [0.53787811],
#        [0.45702039],
#        [0.45985761],
#        [0.47251537],
#        [0.44840001],
#        [0.42646702],
#        [0.46302201],
#        [0.47797135],
#        [0.5001228 ],
#        [0.53373151],
#        [0.56428505],
#        [0.55806532],
#        [0.50710645],
#        [0.50481486],
#        [0.49161131],
#        [0.51048913],
#        [0.549554  ],
#        [0.57072307],
#        [0.59221966],
#        [0.59669361],
#        [0.59767565],
#        [0.56744962],
#        [0.57934362],
#        [0.6415418 ],
#        [0.65201736],
#        [0.62124554],
#        [0.6561638 ],
#        [0.6930463 ],
#        [0.70275795],
#        [0.68769938],
#        [0.66860343],
#        [0.67209534],
#        [0.72010793],
#        [0.76659302],
#        [0.76408315],
#        [0.75415339],
#        [0.76222814],
#        [0.81864299],
#        [0.78808961],
#        [0.8225713 ],
#        [0.79692828],
#        [0.83686595],
#        [0.86283649],
#        [0.86021772],
#        [0.87876803],
#        [0.89251705],
#        [0.89240799],
#        [0.90310168],
#        [0.89524505],
#        [0.85879911],
#        [0.83031887],
#        [0.8329378 ],
#        [0.84886918],
#        [0.8684017 ],
#        [0.76561082],
#        [0.77630467],
#        [0.75644481],
#        [0.71639791],
#        [0.75033413],
#        [0.71454289],
#        [0.69653821],
#        [0.69457397],
#        [0.70363092],
#        [0.74858818],
#        [0.75197086],
#        [0.6962107 ],
#        [0.69468303],
#        [0.657146  ],
#        [0.63641316],
#        [0.68104307],
#        [0.72403625],
#        [0.66991298],
#        [0.65692772],
#        [0.64023242],
#        [0.6738413 ],
#        [0.6181902 ],
#        [0.60138584],
#        [0.54879008],
#        [0.51529042],
#        [0.58970996],
#        [0.57923456],
#        [0.59822128],
#        [0.5625391 ],
#        [0.53940578],
#        [0.53373151],
#        [0.52532941],
#        [0.48015388],
#        [0.58185333],
#        [0.54649866],
#        [0.59472953],
#        [0.55326402],
#        [0.56777696],
#        [0.56614007],
#        [0.61327985],
#        [0.64492448],
#        [0.65441801],
#        [0.62288243],
#        [0.62430087],
#        [0.6784243 ],
#        [0.69937526],
#        [0.63248485],
#        [0.5573014 ],
#        [0.55762875],
#        [0.50328719],
#        [0.53929672],
#        [0.51845482],
#        [0.54835367],
#        [0.5983305 ],
#        [0.63270313],
#        [0.66816703],
#        [0.63444909],
#        [0.60498664],
#        [0.66914907],
#        [0.6456884 ],
#        [0.62353712],
#        [0.63794083],
#        [0.6255012 ],
#        [0.59091028],
#        [0.58163504],
#        [0.55009946],
#        [0.6244101 ],
#        [0.59985817]])

# %%
train_data_scaled.shape,test_data_scaled.shape
# Out:
# ((604, 1), (152, 1))

# %%
def prepare_data(train_data, window_size):
    X, y = [], []
    for i in range(len(train_data) - window_size):
        X.append(train_data[i:i+window_size])
        y.append(train_data[i+window_size])
    X = np.array(X)
    y = np.array(y)
    return X, y

# %%
X_train, y_train = prepare_data(train_data_scaled, window_size=4)
X_test, y_test = prepare_data(test_data_scaled, window_size=4)

# %%
X_train.shape,y_train.shape
# Out:
# ((600, 4, 1), (600, 1))

# %%
from keras.models import Model
from keras.layers import Dense, LSTM, GRU, SimpleRNN, Dropout, Input, Concatenate, Average
from keras.layers.core import Reshape

# Assuming each data point has 5, 21, or 42 time steps and 1 feature (open price)
n_steps = 4 # change this to 21 or 42 for one month or two months respectively
n_features = 1
input_shape=(n_steps, n_features)

# Define the input layer
inputs = Input(shape=input_shape)

# Define the RNN, LSTM, and GRU layers
rnn = SimpleRNN(125, activation='tanh', return_sequences=False)(inputs)
lstm = LSTM(125, activation='relu', return_sequences=False)(inputs)
gru = GRU(125, activation='tanh', return_sequences=False)(inputs)

# Average the hidden states from RNN, LSTM, and GRU
average = Average()([rnn, lstm, gru])

# Dropout layer with a rate of 0.02
dropout = Dropout(0.02)(average)

# Dense layer with 32 units and the ReLU activation function
dense1 = Dense(32, activation='relu')(dropout)

# Dense layer with a prediction window size of units
outputs = Dense(1)(dense1)

# Define the model
model = Model(inputs=inputs, outputs=outputs)

# Compile the model
model.compile(optimizer='adam', loss='mse')

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 4, 1)]       0           []
#
#  simple_rnn (SimpleRNN)         (None, 125)          15875       ['input_1[0][0]']
#
#  lstm (LSTM)                    (None, 125)          63500       ['input_1[0][0]']
#
#  gru (GRU)                      (None, 125)          48000       ['input_1[0][0]']
#
#  average (Average)              (None, 125)          0           ['simple_rnn[0][0]',
#                                                                   'lstm[0][0]',
#                                                                   'gru[0][0]']
#
#  dropout (Dropout)              (None, 125)          0           ['average[0][0]']
#
#  dense (Dense)                  (None, 32)           4032        ['dropout[0][0]']
#
#  dense_1 (Dense)                (None, 1)            33          ['dense[0][0]']
#
# ==================================================================================================
# Total params: 131,440
# Trainable params: 131,440
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# Train the model
model.fit(X_train, y_train, epochs=200, verbose=1)
# Out:
# Epoch 1/200
# 19/19 [==============================] - 2s 4ms/step - loss: 0.0339
# Epoch 2/200
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0042
# Epoch 3/200
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0027
# Epoch 4/200
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0022
# Epoch 5/200
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0021
# Epoch 6/200
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0020
# Epoch 7/200
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0020
# Epoch 8/200
# 19/19 [==============================] - 0s 8ms/step - loss: 0.0018
# Epoch 9/200
# 19/19 [==============================] - 0s 8ms/step - loss: 0.0018
# Epoch 10/200
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0018
# Epoch 11/200
# 19/19 [==============================] - 0s 6ms/step - loss: 0.0018
# Epoch 12/200
# 19/19 [==============================] - 0s 6ms/step - loss: 0.0017
# Epoch 13/200
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0016
# Epoch 14/200
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0016
# Epoch 15/200
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0015
# Epoch 16/200
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0015
# Epoch 17/200
# 19/19 [==============================] - 0s 6ms/step - loss: 0.0016
# Epoch 18/200
# 19/19 [==============================] - 0s 6ms/step - loss: 0.0015
# Epoch 19/200
# 19/19 [==============================] - 0s 7ms/step - loss: 0.0014
# Epoch 20/200
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0015
# Epoch 21/200
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0015
# Epoch 22/200
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0017
# Epoch 23/200
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0015
# Epoch 24/200
# 19/19 [==============================] - 0s 7ms/step - loss: 0.0013
# Epoch 25/200
# 19/19 [==============================] - 0s 11ms/step - loss: 0.0015
# Epoch 26/200
# 19/19 [==============================] - 0s 12ms/step - loss: 0.0014
# Epoch 27/200
# 19/19 [==============================] - 0s 11ms/step - loss: 0.0013
# Epoch 28/200
# 19/19 [==============================] - 0s 10ms/step - loss: 0.0013
# Epoch 29/200
# 19/19 [==============================] - 0s 9ms/step - loss: 0.0014
# Epoch 30/200
# 19/19 [==============================] - 0s 8ms/step - loss: 0.0014
# Epoch 31/200
# 19/19 [==============================] - 0s 9ms/step - loss: 0.0013
# Epoch 32/200
# 19/19 [==============================] - 0s 7ms/step - loss: 0.0012
# Epoch 33/200
# 19/19 [==============================] - 0s 11ms/step - loss: 0.0013
# Epoch 34/200
# 19/19 [==============================] - 0s 12ms/step - loss: 0.0013
# Epoch 35/200
# 19/19 [==============================] - 0s 13ms/step - loss: 0.0013
# Epoch 36/200
# 19/19 [==============================] - 0s 12ms/step - loss: 0.0013
# Epoch 37/200
# 19/19 [==============================] - 0s 14ms/step - loss: 0.0012
# Epoch 38/200
# 19/19 [==============================] - 0s 13ms/step - loss: 0.0015
# Epoch 39/200
# 19/19 [==============================] - 0s 13ms/step - loss: 0.0013
# Epoch 40/200
# 19/19 [==============================] - 0s 13ms/step - loss: 0.0013
# Epoch 41/200
# 19/19 [==============================] - 0s 10ms/step - loss: 0.0012
# Epoch 42/200
# 19/19 [==============================] - 0s 6ms/step - loss: 0.0012
# Epoch 43/200
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0012
# Epoch 44/200
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0013
# Epoch 45/200
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0017
# Epoch 46/200
# 19/19 [==============================] - 0s 6ms/step - loss: 0.0015
# Epoch 47/200
# 19/19 [==============================] - 0s 9ms/step - loss: 0.0012
# Epoch 48/200
# 19/19 [==============================] - 0s 10ms/step - loss: 0.0014
# Epoch 49/200
# 19/19 [==============================] - 0s 12ms/step - loss: 0.0012
# Epoch 50/200
# 19/19 [==============================] - 0s 8ms/step - loss: 0.0012
# Epoch 51/200
# 19/19 [==============================] - 0s 9ms/step - loss: 0.0013
# Epoch 52/200
# 19/19 [==============================] - 0s 8ms/step - loss: 0.0013
# Epoch 53/200
# 19/19 [==============================] - 0s 7ms/step - loss: 0.0013
# Epoch 54/200
# 19/19 [==============================] - 0s 9ms/step - loss: 0.0013
# Epoch 55/200
# 19/19 [==============================] - 0s 13ms/step - loss: 0.0012
# Epoch 56/200
# 19/19 [==============================] - 0s 12ms/step - loss: 0.0012
# Epoch 57/200
# 19/19 [==============================] - 0s 12ms/step - loss: 0.0013
# Epoch 58/200
# 19/19 [==============================] - 0s 12ms/step - loss: 0.0013
# Epoch 59/200
# 19/19 [==============================] - 0s 13ms/step - loss: 0.0012
# Epoch 60/200
# 19/19 [==============================] - 0s 12ms/step - loss: 0.0012
# Epoch 61/200
# 19/19 [==============================] - 0s 12ms/step - loss: 0.0012
# Epoch 62/200
# 19/19 [==============================] - 0s 11ms/step - loss: 0.0014
# Epoch 63/200
# 19/19 [==============================] - 0s 13ms/step - loss: 0.0012
# Epoch 64/200
# 19/19 [==============================] - 0s 8ms/step - loss: 0.0012
# Epoch 65/200
# 19/19 [==============================] - 0s 9ms/step - loss: 0.0012
# Epoch 66/200
# 19/19 [==============================] - 0s 9ms/step - loss: 0.0012
# Epoch 67/200
# 19/19 [==============================] - 0s 9ms/step - loss: 0.0011
# Epoch 68/200
# 19/19 [==============================] - 0s 10ms/step - loss: 0.0013
# Epoch 69/200
# 19/19 [==============================] - 0s 8ms/step - loss: 0.0013
# Epoch 70/200
# 19/19 [==============================] - 0s 10ms/step - loss: 0.0012
# Epoch 71/200
# 19/19 [==============================] - 0s 8ms/step - loss: 0.0013
# Epoch 72/200
# 19/19 [==============================] - 0s 8ms/step - loss: 0.0013
# Epoch 73/200
# 19/19 [==============================] - 0s 10ms/step - loss: 0.0013
# Epoch 74/200
# 19/19 [==============================] - 0s 10ms/step - loss: 0.0012
# Epoch 75/200
# 19/19 [==============================] - 0s 12ms/step - loss: 0.0012
# Epoch 76/200
# 19/19 [==============================] - 0s 11ms/step - loss: 0.0012
# Epoch 77/200
# 19/19 [==============================] - 0s 10ms/step - loss: 0.0012
# Epoch 78/200
# 19/19 [==============================] - 0s 8ms/step - loss: 0.0012
# Epoch 79/200
# 19/19 [==============================] - 0s 10ms/step - loss: 0.0012
# Epoch 80/200
# 19/19 [==============================] - 0s 9ms/step - loss: 0.0012
# Epoch 81/200
# 19/19 [==============================] - 0s 9ms/step - loss: 0.0015
# Epoch 82/200
# 19/19 [==============================] - 0s 11ms/step - loss: 0.0012
# Epoch 83/200
# 19/19 [==============================] - 0s 13ms/step - loss: 0.0014
# Epoch 84/200
# 19/19 [==============================] - 0s 12ms/step - loss: 0.0012
# Epoch 85/200
# 19/19 [==============================] - 0s 12ms/step - loss: 0.0013
# Epoch 86/200
# 19/19 [==============================] - 0s 12ms/step - loss: 0.0012
# Epoch 87/200
# 19/19 [==============================] - 0s 11ms/step - loss: 0.0012
# Epoch 88/200
# 19/19 [==============================] - 0s 12ms/step - loss: 0.0013
# Epoch 89/200
# 19/19 [==============================] - 0s 11ms/step - loss: 0.0014
# Epoch 90/200
# 19/19 [==============================] - 0s 13ms/step - loss: 0.0012
# Epoch 91/200
# 19/19 [==============================] - 0s 10ms/step - loss: 0.0012
# Epoch 92/200
# 19/19 [==============================] - 0s 9ms/step - loss: 0.0012
# Epoch 93/200
# 19/19 [==============================] - 0s 12ms/step - loss: 0.0012
# Epoch 94/200
# 19/19 [==============================] - 0s 11ms/step - loss: 0.0012
# Epoch 95/200
# 19/19 [==============================] - 0s 11ms/step - loss: 0.0012
# Epoch 96/200
# 19/19 [==============================] - 0s 9ms/step - loss: 0.0012
# Epoch 97/200
# 19/19 [==============================] - 0s 12ms/step - loss: 0.0012
# Epoch 98/200
# 19/19 [==============================] - 0s 11ms/step - loss: 0.0012
# Epoch 99/200
# 19/19 [==============================] - 0s 13ms/step - loss: 0.0014
# Epoch 100/200
# 19/19 [==============================] - 0s 13ms/step - loss: 0.0012
# Epoch 101/200
# 19/19 [==============================] - 0s 12ms/step - loss: 0.0011
# Epoch 102/200
# 19/19 [==============================] - 0s 11ms/step - loss: 0.0012
# Epoch 103/200
# 19/19 [==============================] - 0s 9ms/step - loss: 0.0012
# Epoch 104/200
# 19/19 [==============================] - 0s 11ms/step - loss: 0.0012
# Epoch 105/200
# 19/19 [==============================] - 0s 12ms/step - loss: 0.0012
# Epoch 106/200
# 19/19 [==============================] - 0s 12ms/step - loss: 0.0012
# Epoch 107/200
# 19/19 [==============================] - 0s 12ms/step - loss: 0.0012
# Epoch 108/200
# 19/19 [==============================] - 0s 12ms/step - loss: 0.0012
# Epoch 109/200
# 19/19 [==============================] - 0s 12ms/step - loss: 0.0013
# Epoch 110/200
# 19/19 [==============================] - 0s 11ms/step - loss: 0.0014
# Epoch 111/200
# 19/19 [==============================] - 0s 9ms/step - loss: 0.0012
# Epoch 112/200
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0013
# Epoch 113/200
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0012
# Epoch 114/200
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0013
# Epoch 115/200
# 19/19 [==============================] - 0s 8ms/step - loss: 0.0013
# Epoch 116/200
# 19/19 [==============================] - 0s 9ms/step - loss: 0.0012
# Epoch 117/200
# 19/19 [==============================] - 0s 11ms/step - loss: 0.0013
# Epoch 118/200
# 19/19 [==============================] - 0s 8ms/step - loss: 0.0012
# Epoch 119/200
# 19/19 [==============================] - 0s 6ms/step - loss: 0.0011
# Epoch 120/200
# 19/19 [==============================] - 0s 11ms/step - loss: 0.0012
# Epoch 121/200
# 19/19 [==============================] - 0s 11ms/step - loss: 0.0012
# Epoch 122/200
# 19/19 [==============================] - 0s 11ms/step - loss: 0.0011
# Epoch 123/200
# 19/19 [==============================] - 0s 11ms/step - loss: 0.0011
# Epoch 124/200
# 19/19 [==============================] - 0s 11ms/step - loss: 0.0012
# Epoch 125/200
# 19/19 [==============================] - 0s 12ms/step - loss: 0.0012
# Epoch 126/200
# 19/19 [==============================] - 0s 9ms/step - loss: 0.0011
# Epoch 127/200
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0012
# Epoch 128/200
# 19/19 [==============================] - 0s 6ms/step - loss: 0.0012
# Epoch 129/200
# 19/19 [==============================] - 0s 7ms/step - loss: 0.0012
# Epoch 130/200
# 19/19 [==============================] - 0s 6ms/step - loss: 0.0014
# Epoch 131/200
# 19/19 [==============================] - 0s 9ms/step - loss: 0.0012
# Epoch 132/200
# 19/19 [==============================] - 0s 12ms/step - loss: 0.0012
# Epoch 133/200
# 19/19 [==============================] - 0s 13ms/step - loss: 0.0012
# Epoch 134/200
# 19/19 [==============================] - 0s 12ms/step - loss: 0.0012
# Epoch 135/200
# 19/19 [==============================] - 0s 11ms/step - loss: 0.0012
# Epoch 136/200
# 19/19 [==============================] - 0s 12ms/step - loss: 0.0012
# Epoch 137/200
# 19/19 [==============================] - 0s 10ms/step - loss: 0.0013
# Epoch 138/200
# 19/19 [==============================] - 0s 12ms/step - loss: 0.0013
# Epoch 139/200
# 19/19 [==============================] - 0s 12ms/step - loss: 0.0013
# Epoch 140/200
# 19/19 [==============================] - 0s 13ms/step - loss: 0.0012
# Epoch 141/200
# 19/19 [==============================] - 0s 12ms/step - loss: 0.0012
# Epoch 142/200
# 19/19 [==============================] - 0s 13ms/step - loss: 0.0012
# Epoch 143/200
# 19/19 [==============================] - 0s 9ms/step - loss: 0.0012
# Epoch 144/200
# 19/19 [==============================] - 0s 7ms/step - loss: 0.0013
# Epoch 145/200
# 19/19 [==============================] - 0s 7ms/step - loss: 0.0011
# Epoch 146/200
# 19/19 [==============================] - 0s 11ms/step - loss: 0.0011
# Epoch 147/200
# 19/19 [==============================] - 0s 9ms/step - loss: 0.0012
# Epoch 148/200
# 19/19 [==============================] - 0s 11ms/step - loss: 0.0012
# Epoch 149/200
# 19/19 [==============================] - 0s 10ms/step - loss: 0.0012
# Epoch 150/200
# 19/19 [==============================] - 0s 10ms/step - loss: 0.0012
# Epoch 151/200
# 19/19 [==============================] - 0s 11ms/step - loss: 0.0012
# Epoch 152/200
# 19/19 [==============================] - 0s 11ms/step - loss: 0.0011
# Epoch 153/200
# 19/19 [==============================] - 0s 8ms/step - loss: 0.0012
# Epoch 154/200
# 19/19 [==============================] - 0s 7ms/step - loss: 0.0013
# Epoch 155/200
# 19/19 [==============================] - 0s 10ms/step - loss: 0.0012
# Epoch 156/200
# 19/19 [==============================] - 0s 11ms/step - loss: 0.0011
# Epoch 157/200
# 19/19 [==============================] - 0s 12ms/step - loss: 0.0012
# Epoch 158/200
# 19/19 [==============================] - 0s 11ms/step - loss: 0.0012
# Epoch 159/200
# 19/19 [==============================] - 0s 13ms/step - loss: 0.0012
# Epoch 160/200
# 19/19 [==============================] - 0s 10ms/step - loss: 0.0012
# Epoch 161/200
# 19/19 [==============================] - 0s 12ms/step - loss: 0.0011
# Epoch 162/200
# 19/19 [==============================] - 0s 11ms/step - loss: 0.0011
# Epoch 163/200
# 19/19 [==============================] - 0s 8ms/step - loss: 0.0012
# Epoch 164/200
# 19/19 [==============================] - 0s 7ms/step - loss: 0.0011
# Epoch 165/200
# 19/19 [==============================] - 0s 6ms/step - loss: 0.0011
# Epoch 166/200
# 19/19 [==============================] - 0s 8ms/step - loss: 0.0012
# Epoch 167/200
# 19/19 [==============================] - 0s 6ms/step - loss: 0.0013
# Epoch 168/200
# 19/19 [==============================] - 0s 12ms/step - loss: 0.0011
# Epoch 169/200
# 19/19 [==============================] - 0s 13ms/step - loss: 0.0012
# Epoch 170/200
# 19/19 [==============================] - 0s 13ms/step - loss: 0.0012
# Epoch 171/200
# 19/19 [==============================] - 0s 11ms/step - loss: 0.0012
# Epoch 172/200
# 19/19 [==============================] - 0s 7ms/step - loss: 0.0011
# Epoch 173/200
# 19/19 [==============================] - 0s 6ms/step - loss: 0.0012
# Epoch 174/200
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0012
# Epoch 175/200
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0013
# Epoch 176/200
# 19/19 [==============================] - 0s 7ms/step - loss: 0.0011
# Epoch 177/200
# 19/19 [==============================] - 0s 8ms/step - loss: 0.0012
# Epoch 178/200
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0011
# Epoch 179/200
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0011
# Epoch 180/200
# 19/19 [==============================] - 0s 6ms/step - loss: 0.0013
# Epoch 181/200
# 19/19 [==============================] - 0s 9ms/step - loss: 0.0011
# Epoch 182/200
# 19/19 [==============================] - 0s 11ms/step - loss: 0.0012
# Epoch 183/200
# 19/19 [==============================] - 0s 7ms/step - loss: 0.0014
# Epoch 184/200
# 19/19 [==============================] - 0s 13ms/step - loss: 0.0012
# Epoch 185/200
# 19/19 [==============================] - 0s 12ms/step - loss: 0.0012
# Epoch 186/200
# 19/19 [==============================] - 0s 10ms/step - loss: 0.0012
# Epoch 187/200
# 19/19 [==============================] - 0s 12ms/step - loss: 0.0013
# Epoch 188/200
# 19/19 [==============================] - 0s 12ms/step - loss: 0.0011
# Epoch 189/200
# 19/19 [==============================] - 0s 13ms/step - loss: 0.0011
# Epoch 190/200
# 19/19 [==============================] - 0s 13ms/step - loss: 0.0012
# Epoch 191/200
# 19/19 [==============================] - 0s 11ms/step - loss: 0.0012
# Epoch 192/200
# 19/19 [==============================] - 0s 9ms/step - loss: 0.0012
# Epoch 193/200
# 19/19 [==============================] - 0s 12ms/step - loss: 0.0011
# Epoch 194/200
# 19/19 [==============================] - 0s 9ms/step - loss: 0.0011
# Epoch 195/200
# 19/19 [==============================] - 0s 9ms/step - loss: 0.0012
# Epoch 196/200
# 19/19 [==============================] - 0s 10ms/step - loss: 0.0012
# Epoch 197/200
# 19/19 [==============================] - 0s 12ms/step - loss: 0.0014
# Epoch 198/200
# 19/19 [==============================] - 0s 8ms/step - loss: 0.0012
# Epoch 199/200
# 19/19 [==============================] - 0s 10ms/step - loss: 0.0011
# Epoch 200/200
# 19/19 [==============================] - 0s 8ms/step - loss: 0.0012

# %%
### Lets Do the prediction and check performance metrics
train_predict=model.predict(X_train)
test_predict=model.predict(X_test)
# Out:
# 19/19 [==============================] - 1s 3ms/step
# 5/5 [==============================] - 0s 4ms/step

# %%
train_predict
# Out:
# array([[0.06784259],
#        [0.06652326],
#        [0.09454641],
#        [0.06696883],
#        [0.06917433],
#        [0.03215985],
#        [0.05313106],
#        [0.0557375 ],
#        [0.04982649],
#        [0.05306799],
#        [0.13664237],
#        [0.19108558],
#        [0.19537023],
#        [0.20249113],
#        [0.21736692],
#        [0.24762975],
#        [0.23947555],
#        [0.2328968 ],
#        [0.2198987 ],
#        [0.2627472 ],
#        [0.26495773],
#        [0.27547666],
#        [0.25950933],
#        [0.27792296],
#        [0.27616352],
#        [0.31218562],
#        [0.40863   ],
#        [0.36487105],
#        [0.38355452],
#        [0.40257084],
#        [0.38614002],
#        [0.4044032 ],
#        [0.4582583 ],
#        [0.5063943 ],
#        [0.3923606 ],
#        [0.32535115],
#        [0.26932845],
#        [0.30100217],
#        [0.32876083],
#        [0.25831556],
#        [0.26488233],
#        [0.30824178],
#        [0.2679121 ],
#        [0.20906466],
#        [0.22345835],
#        [0.15935285],
#        [0.24515867],
#        [0.23206872],
#        [0.15567961],
#        [0.20124015],
#        [0.2709712 ],
#        [0.2567657 ],
#        [0.24921787],
#        [0.29675025],
#        [0.24333331],
#        [0.25495967],
#        [0.27854806],
#        [0.26161602],
#        [0.28001815],
#        [0.2705537 ],
#        [0.3207799 ],
#        [0.37430003],
#        [0.325631  ],
#        [0.3057426 ],
#        [0.34025255],
#        [0.32165504],
#        [0.27897042],
#        [0.2886298 ],
#        [0.29685262],
#        [0.28163126],
#        [0.25666058],
#        [0.2749064 ],
#        [0.26926744],
#        [0.23809636],
#        [0.22681075],
#        [0.20706823],
#        [0.21226978],
#        [0.25977123],
#        [0.2966338 ],
#        [0.2975667 ],
#        [0.3233712 ],
#        [0.27188703],
#        [0.29188332],
#        [0.32066658],
#        [0.31268   ],
#        [0.30779696],
#        [0.31702074],
#        [0.3065417 ],
#        [0.29537284],
#        [0.308093  ],
#        [0.29128256],
#        [0.25555357],
#        [0.27637175],
#        [0.28633183],
#        [0.28680083],
#        [0.33088472],
#        [0.34075317],
#        [0.35560903],
#        [0.348233  ],
#        [0.3460102 ],
#        [0.3700821 ],
#        [0.37018704],
#        [0.32554224],
#        [0.35007623],
#        [0.35222647],
#        [0.36699972],
#        [0.40001616],
#        [0.41513413],
#        [0.41682974],
#        [0.37624353],
#        [0.4475675 ],
#        [0.45398518],
#        [0.44085675],
#        [0.47381014],
#        [0.5159615 ],
#        [0.4895788 ],
#        [0.47583887],
#        [0.4740713 ],
#        [0.42251217],
#        [0.41047904],
#        [0.41853657],
#        [0.45619592],
#        [0.42087516],
#        [0.41419303],
#        [0.4216201 ],
#        [0.4397157 ],
#        [0.41765457],
#        [0.40724403],
#        [0.41923717],
#        [0.47006482],
#        [0.49445796],
#        [0.56384987],
#        [0.5735498 ],
#        [0.5727932 ],
#        [0.5384357 ],
#        [0.5006742 ],
#        [0.48024842],
#        [0.49789217],
#        [0.49538335],
#        [0.49875095],
#        [0.5112262 ],
#        [0.49766332],
#        [0.50397474],
#        [0.50369406],
#        [0.49650356],
#        [0.4811758 ],
#        [0.4927986 ],
#        [0.4477949 ],
#        [0.42543396],
#        [0.4390412 ],
#        [0.41174266],
#        [0.36408764],
#        [0.38027677],
#        [0.3760347 ],
#        [0.34928077],
#        [0.36394045],
#        [0.41218734],
#        [0.37119034],
#        [0.33917165],
#        [0.33724588],
#        [0.33475843],
#        [0.31177273],
#        [0.3408221 ],
#        [0.34917846],
#        [0.3232449 ],
#        [0.3372868 ],
#        [0.38305196],
#        [0.3626574 ],
#        [0.35044447],
#        [0.32286683],
#        [0.3278174 ],
#        [0.35954067],
#        [0.35016754],
#        [0.31450483],
#        [0.32760063],
#        [0.34171757],
#        [0.32134143],
#        [0.33910227],
#        [0.3616433 ],
#        [0.36126772],
#        [0.38988873],
#        [0.3840597 ],
#        [0.41640952],
#        [0.42756853],
#        [0.4542349 ],
#        [0.45607066],
#        [0.48188546],
#        [0.47286424],
#        [0.47725847],
#        [0.4715647 ],
#        [0.4859317 ],
#        [0.45901278],
#        [0.46528405],
#        [0.45808178],
#        [0.48290733],
#        [0.4855313 ],
#        [0.4771496 ],
#        [0.5015338 ],
#        [0.45243582],
#        [0.4555031 ],
#        [0.4495297 ],
#        [0.42411903],
#        [0.41104016],
#        [0.44184473],
#        [0.42537293],
#        [0.35933462],
#        [0.36373365],
#        [0.37688628],
#        [0.38904572],
#        [0.3945939 ],
#        [0.3921484 ],
#        [0.35642457],
#        [0.38104248],
#        [0.40780565],
#        [0.3846999 ],
#        [0.40589598],
#        [0.39904407],
#        [0.3916552 ],
#        [0.38417068],
#        [0.3785474 ],
#        [0.3697674 ],
#        [0.3738216 ],
#        [0.36675364],
#        [0.38871667],
#        [0.39347917],
#        [0.3989237 ],
#        [0.39834678],
#        [0.39329007],
#        [0.40779033],
#        [0.4293302 ],
#        [0.4331034 ],
#        [0.42808446],
#        [0.43914926],
#        [0.43544835],
#        [0.45346877],
#        [0.47110513],
#        [0.4774005 ],
#        [0.4686101 ],
#        [0.46940348],
#        [0.48437557],
#        [0.49754864],
#        [0.50168747],
#        [0.5159767 ],
#        [0.53933173],
#        [0.5750604 ],
#        [0.5557769 ],
#        [0.5689983 ],
#        [0.607798  ],
#        [0.5836184 ],
#        [0.62570184],
#        [0.64077985],
#        [0.6301872 ],
#        [0.5849799 ],
#        [0.58309376],
#        [0.6045708 ],
#        [0.60491383],
#        [0.6208146 ],
#        [0.62988955],
#        [0.6386661 ],
#        [0.5956015 ],
#        [0.59478706],
#        [0.59314585],
#        [0.6098731 ],
#        [0.6042103 ],
#        [0.6185553 ],
#        [0.6173618 ],
#        [0.6101489 ],
#        [0.6098832 ],
#        [0.6122238 ],
#        [0.60772246],
#        [0.60898423],
#        [0.6378006 ],
#        [0.6330668 ],
#        [0.6500109 ],
#        [0.64802307],
#        [0.59830374],
#        [0.6245305 ],
#        [0.6340459 ],
#        [0.64131325],
#        [0.6468803 ],
#        [0.632389  ],
#        [0.6243232 ],
#        [0.640514  ],
#        [0.67707366],
#        [0.6778557 ],
#        [0.68912405],
#        [0.69101983],
#        [0.70340544],
#        [0.7249819 ],
#        [0.7093348 ],
#        [0.70485944],
#        [0.661843  ],
#        [0.65782386],
#        [0.6398844 ],
#        [0.63506997],
#        [0.63908774],
#        [0.58603656],
#        [0.5871776 ],
#        [0.59379   ],
#        [0.6121424 ],
#        [0.6020208 ],
#        [0.6000795 ],
#        [0.5793268 ],
#        [0.57051337],
#        [0.58296496],
#        [0.56320673],
#        [0.56088465],
#        [0.5389282 ],
#        [0.5372523 ],
#        [0.5743177 ],
#        [0.58236927],
#        [0.5636733 ],
#        [0.57638955],
#        [0.55712515],
#        [0.5643764 ],
#        [0.58256984],
#        [0.57747024],
#        [0.6144258 ],
#        [0.6332784 ],
#        [0.6334979 ],
#        [0.64520556],
#        [0.63623035],
#        [0.64282274],
#        [0.64406925],
#        [0.6478254 ],
#        [0.6216466 ],
#        [0.6397471 ],
#        [0.637264  ],
#        [0.6525158 ],
#        [0.6663117 ],
#        [0.6689034 ],
#        [0.6651868 ],
#        [0.6536736 ],
#        [0.65216714],
#        [0.6411066 ],
#        [0.6346758 ],
#        [0.654658  ],
#        [0.64947593],
#        [0.65954846],
#        [0.68912274],
#        [0.72911435],
#        [0.77100796],
#        [0.7667183 ],
#        [0.76523215],
#        [0.7564947 ],
#        [0.7540763 ],
#        [0.7604483 ],
#        [0.8366246 ],
#        [0.74613804],
#        [0.7992113 ],
#        [0.8101589 ],
#        [0.85132855],
#        [0.88663644],
#        [0.91380286],
#        [0.91946834],
#        [0.98168486],
#        [0.92278534],
#        [0.92043966],
#        [0.9695007 ],
#        [0.86847657],
#        [0.8509548 ],
#        [0.89085233],
#        [0.89921695],
#        [0.9257534 ],
#        [0.94033617],
#        [0.9720922 ],
#        [0.96504444],
#        [0.9666393 ],
#        [0.95501006],
#        [0.951801  ],
#        [1.0016594 ],
#        [0.96914506],
#        [0.8967747 ],
#        [0.9038494 ],
#        [0.86439264],
#        [0.8927498 ],
#        [0.93279964],
#        [0.925142  ],
#        [0.8809374 ],
#        [0.8860103 ],
#        [0.8715146 ],
#        [0.8370455 ],
#        [0.8114148 ],
#        [0.76585555],
#        [0.7536342 ],
#        [0.79934925],
#        [0.78533   ],
#        [0.81697285],
#        [0.86663306],
#        [0.90422446],
#        [0.9127791 ],
#        [0.91228867],
#        [0.8862403 ],
#        [0.8992136 ],
#        [0.88814855],
#        [0.930099  ],
#        [0.9113806 ],
#        [0.8908338 ],
#        [0.8436551 ],
#        [0.88022614],
#        [0.8891391 ],
#        [0.875812  ],
#        [0.86589104],
#        [0.81694645],
#        [0.8227147 ],
#        [0.68897456],
#        [0.8016904 ],
#        [0.797226  ],
#        [0.80119336],
#        [0.80734414],
#        [0.84832966],
#        [0.8085112 ],
#        [0.7955807 ],
#        [0.75307494],
#        [0.7777877 ],
#        [0.76484877],
#        [0.7474882 ],
#        [0.67285997],
#        [0.66650146],
#        [0.7302442 ],
#        [0.7403235 ],
#        [0.75822014],
#        [0.79387003],
#        [0.81533694],
#        [0.84169084],
#        [0.87498623],
#        [0.9045622 ],
#        [0.88781226],
#        [0.9358722 ],
#        [0.9572732 ],
#        [0.9471949 ],
#        [0.9110164 ],
#        [0.91848695],
#        [0.94914365],
#        [0.8930029 ],
#        [0.880641  ],
#        [0.8908685 ],
#        [0.85564196],
#        [0.8476528 ],
#        [0.8425898 ],
#        [0.87376255],
#        [0.8041093 ],
#        [0.81435126],
#        [0.8573178 ],
#        [0.8532838 ],
#        [0.82776237],
#        [0.77561754],
#        [0.7882043 ],
#        [0.7224317 ],
#        [0.75244915],
#        [0.7814792 ],
#        [0.72271293],
#        [0.7397061 ],
#        [0.7586536 ],
#        [0.7971853 ],
#        [0.7172108 ],
#        [0.7063516 ],
#        [0.7175881 ],
#        [0.6907044 ],
#        [0.57718325],
#        [0.59889156],
#        [0.60916394],
#        [0.63384813],
#        [0.6146016 ],
#        [0.5422921 ],
#        [0.5382336 ],
#        [0.5245251 ],
#        [0.5496934 ],
#        [0.5249009 ],
#        [0.51256764],
#        [0.5974866 ],
#        [0.63351446],
#        [0.63979936],
#        [0.6246722 ],
#        [0.61802477],
#        [0.62045056],
#        [0.5913759 ],
#        [0.6339644 ],
#        [0.61923295],
#        [0.54568195],
#        [0.47087923],
#        [0.47688004],
#        [0.48432654],
#        [0.4550943 ],
#        [0.4338806 ],
#        [0.47032464],
#        [0.48277825],
#        [0.5012233 ],
#        [0.5354733 ],
#        [0.5650546 ],
#        [0.56049687],
#        [0.5145741 ],
#        [0.51509225],
#        [0.5030634 ],
#        [0.51677203],
#        [0.55346984],
#        [0.57205594],
#        [0.5931703 ],
#        [0.6001449 ],
#        [0.60234624],
#        [0.5754909 ],
#        [0.5869804 ],
#        [0.6460523 ],
#        [0.6534944 ],
#        [0.6243637 ],
#        [0.6618113 ],
#        [0.6979358 ],
#        [0.7041686 ],
#        [0.69199604],
#        [0.6765986 ],
#        [0.6808894 ],
#        [0.7253478 ],
#        [0.76773375],
#        [0.7647937 ],
#        [0.7580864 ],
#        [0.7692575 ],
#        [0.8225204 ],
#        [0.79274124],
#        [0.82457834],
#        [0.80511785],
#        [0.83982784],
#        [0.8673542 ],
#        [0.8618755 ],
#        [0.8814913 ],
#        [0.8962044 ],
#        [0.89533865],
#        [0.90632796],
#        [0.8998288 ],
#        [0.8651921 ],
#        [0.8394715 ],
#        [0.8425735 ],
#        [0.85584635],
#        [0.87212926],
#        [0.7745481 ],
#        [0.7856323 ],
#        [0.7709505 ],
#        [0.7256171 ],
#        [0.7588782 ],
#        [0.72448224],
#        [0.70374733],
#        [0.7052018 ],
#        [0.7113773 ],
#        [0.75246036],
#        [0.75539094],
#        [0.7024922 ],
#        [0.7043876 ],
#        [0.67035455],
#        [0.6466232 ],
#        [0.68921703],
#        [0.7273006 ],
#        [0.67392105],
#        [0.6642429 ],
#        [0.65278083],
#        [0.6805671 ],
#        [0.6274614 ],
#        [0.60973424],
#        [0.5638039 ],
#        [0.5283427 ],
#        [0.5978001 ],
#        [0.58456117],
#        [0.59853226],
#        [0.57098407],
#        [0.5480773 ],
#        [0.5448051 ],
#        [0.53455263],
#        [0.48984292],
#        [0.5854545 ],
#        [0.5524965 ],
#        [0.5925195 ],
#        [0.5622039 ],
#        [0.5722601 ],
#        [0.57516855],
#        [0.6160384 ],
#        [0.6470204 ],
#        [0.6550789 ],
#        [0.62845284],
#        [0.63202846],
#        [0.6842682 ],
#        [0.7016405 ],
#        [0.6377372 ],
#        [0.5700076 ],
#        [0.57377833],
#        [0.51852274],
#        [0.5469223 ],
#        [0.5283121 ],
#        [0.55148166],
#        [0.6016412 ],
#        [0.6319157 ],
#        [0.66687423],
#        [0.6384234 ],
#        [0.6126583 ],
#        [0.676349  ],
#        [0.6522754 ],
#        [0.62799585],
#        [0.64688003],
#        [0.6337806 ],
#        [0.59924585],
#        [0.5918299 ],
#        [0.5618245 ],
#        [0.6291361 ]], dtype=float32)

# %%
##Transformback to original form
train_predict=scaler.inverse_transform(train_predict)
test_predict=scaler.inverse_transform(test_predict)

# %%
train_predict.shape,test_predict.shape
# Out:
# ((600, 1), (148, 1))

# %%
train_data_compare = np.array(train_data[n_steps:]).reshape(-1,1)
test_data_campare = np.array(test_data[n_steps:]).reshape(-1,1)
train_data_compare.shape,test_data_campare.shape
# Out:
# ((600, 1), (148, 1))

# %%
### Calculate RMSE performance metrics
import math
from sklearn.metrics import mean_squared_error

print(f"The RMSE for train is {math.sqrt(mean_squared_error(train_data_compare, train_predict))}")
print(f"The RMSE for test is {math.sqrt(mean_squared_error(test_data_campare, test_predict))}")
# Out:
# The RMSE for train is 22.731873317380472
# The RMSE for test is 2.1660841316374455

# %%
#predicting for next five days
# Assuming `test_data_scaled` is your time series data and `model` is your trained model
window_size=n_steps
input_seq = test_data_scaled[-n_steps:]

for _ in range(window_size):
    # Reshape the input sequence
    input_seq = input_seq.reshape((1, n_steps, n_features))

    # Make a prediction
    prediction = model.predict(input_seq)

    # Update the input sequence
    input_seq = np.append(input_seq[:, 1:, :], prediction)

# `input_seq` now contains the original data for the last `n_steps` time steps followed by `window_size` forecasted time steps
# Out:
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 16ms/step

# %%
future_predict = scaler.inverse_transform(np.array(input_seq).reshape(-1,1))

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming 'dates', 'stock_open', 'train_predict', 'test_predict' are defined
dates = np.array(index)
stock_open = np.array(stock_open)
train_predict = np.array(train_predict)
test_predict = np.array(test_predict)

# Create empty arrays for the plot
trainPredictPlot = np.empty_like(stock_open)
trainPredictPlot[:] = np.nan
trainPredictPlot[n_steps:len(train_predict)+n_steps] = train_predict.flatten()

testPredictPlot = np.empty_like(stock_open)
testPredictPlot[:] = np.nan
testPredictPlot[len(train_predict)+(n_steps*2):len(train_predict)+(n_steps*2)+len(test_predict)] = test_predict.flatten()

# Flatten future_predict
future_predict = future_predict.flatten()

# Create an array for the future prediction dates
future_dates = np.arange(dates[-1] + np.timedelta64(1, 'D'), dates[-1] + np.timedelta64(window_size + 1, 'D'), np.timedelta64(1, 'D'))

# Create an array for the plot
futurePredictPlot = np.empty_like(np.concatenate((stock_open, np.full(window_size, np.nan))))
futurePredictPlot[:] = np.nan
futurePredictPlot[len(train_predict) + (n_steps * 2) + len(test_predict):] = future_predict

# Plotting
plt.figure(figsize=(8,4))
plt.plot(np.concatenate((dates, future_dates)), np.concatenate((stock_open, np.full(window_size, np.nan))), color='blue', label='Actual')
plt.plot(dates, trainPredictPlot, color='orange', label='Train Predict')
plt.plot(dates, testPredictPlot, color='green', label='Test Predict')
plt.plot(np.concatenate((dates, future_dates)), futurePredictPlot, color='red', label='Future Predict')
plt.xlabel('Date')
plt.ylabel('Price')
plt.title('Stock Prices Over Time for Ensemble')
plt.legend()
plt.show()

# %%
future_predict
# Out:
# array([190.40770828, 190.5923132 , 190.82896991, 191.02676753])
