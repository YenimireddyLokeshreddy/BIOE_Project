# %%
#installing pandas datareader
#!pip install pandas-datareader

# %%
import pandas_datareader as pdr
import pandas as pd
from datetime import datetime

# %%
#!pip install yfinance

# %%
import yfinance as yf

# Define the stock symbol and the date range
symbol = 'AAPL'
start_date = '2020-07-14'
end_date = '2023-07-17'

# Retrieve the stock data from Yahoo Finance
data = yf.download(symbol, start=start_date, end=end_date)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
data.head()
# Out:
#                  Open       High        Low      Close  Adj Close     Volume
# Date
# 2020-07-14  94.839996  97.254997  93.877502  97.057503  95.291206  170989200
# 2020-07-15  98.989998  99.247498  96.489998  97.724998  95.946579  153198000
# 2020-07-16  96.562500  97.404999  95.904999  96.522499  94.765961  110577600
# 2020-07-17  96.987503  97.147499  95.839996  96.327499  94.574509   92186800
# 2020-07-20  96.417503  98.500000  96.062500  98.357498  96.567543   90318000

# %%
data.tail()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2023-07-10  189.259995  189.990005  187.039993  188.610001  188.610001
# 2023-07-11  189.160004  189.300003  186.600006  188.080002  188.080002
# 2023-07-12  189.679993  191.699997  188.470001  189.770004  189.770004
# 2023-07-13  190.500000  191.190002  189.779999  190.539993  190.539993
# 2023-07-14  190.229996  191.179993  189.630005  190.690002  190.690002
#
#               Volume
# Date
# 2023-07-10  59922200
# 2023-07-11  46638100
# 2023-07-12  60750200
# 2023-07-13  41342300
# 2023-07-14  41573900

# %%
data['High'].plot(xlim=['2020-07-14','2023-07-17'],ylim=[120,200],figsize=(12,4),ls='--',c='green')
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
index = data.loc['2020-07-14':'2023-07-17'].index
stock_open = data.loc['2020-07-14':'2023-07-17']['Open']
stock_high = data.loc['2020-07-14':'2023-07-17']['High']
stock_low = data.loc['2020-07-14':'2023-07-17']['Low']
stock_close = data.loc['2020-07-14':'2023-07-17']['Close']

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

figure, axis = plt.subplots(figsize=(12,4))
plt.tight_layout()
# preventing overlapping
figure.autofmt_xdate()

# assuming 'index', 'stock_open', 'stock_high', 'stock_low', 'stock_close' are defined
axis.plot(index, stock_open, label='Open')
axis.plot(index, stock_high, label='High')
axis.plot(index, stock_low, label='Low')
axis.plot(index, stock_close, label='Close')

# Add labels and title
axis.set_xlabel('Date')
axis.set_ylabel('Price')
axis.set_title('Stock Prices Over Time')

# Add a legend
axis.legend()

plt.show()

# %%
df1 = stock_open

# %%
df1
# Out:
# Date
# 2020-07-14     94.839996
# 2020-07-15     98.989998
# 2020-07-16     96.562500
# 2020-07-17     96.987503
# 2020-07-20     96.417503
#                  ...
# 2023-07-10    189.259995
# 2023-07-11    189.160004
# 2023-07-12    189.679993
# 2023-07-13    190.500000
# 2023-07-14    190.229996
# Name: Open, Length: 756, dtype: float64

# %%
# Calculate the split point
split_point = int(len(df1) * 0.8)

# Split the data
train_data = df1.iloc[:split_point]
test_data = df1.iloc[split_point:]

# Print the shapes of the training and testing sets
print("Training set shape:", train_data.shape)
print("Testing set shape:", test_data.shape)
# Out:
# Training set shape: (604,)
# Testing set shape: (152,)

# %%
import numpy as np
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler(feature_range=(0,1))
train_data_scaled=scaler.fit_transform(np.array(train_data).reshape(-1,1))
test_data_scaled=scaler.fit_transform(np.array(test_data).reshape(-1,1))

# %%
train_data_scaled
# Out:
# array([[0.04203828],
#        [0.08732296],
#        [0.06083419],
#        [0.0654718 ],
#        [0.05925199],
#        [0.08931443],
#        [0.06225271],
#        [0.06558086],
#        [0.        ],
#        [0.02970779],
#        [0.03688242],
#        [0.03014428],
#        [0.03491826],
#        [0.12982512],
#        [0.18782217],
#        [0.19799761],
#        [0.20067108],
#        [0.21188308],
#        [0.24243662],
#        [0.23583485],
#        [0.22896034],
#        [0.21289243],
#        [0.25580377],
#        [0.26016857],
#        [0.27361755],
#        [0.2549581 ],
#        [0.27274457],
#        [0.27020756],
#        [0.30853581],
#        [0.4114902 ],
#        [0.36784241],
#        [0.38401939],
#        [0.39452217],
#        [0.38219159],
#        [0.39929616],
#        [0.45582007],
#        [0.50852489],
#        [0.39198516],
#        [0.31734726],
#        [0.25056599],
#        [0.28668466],
#        [0.32051174],
#        [0.25733144],
#        [0.25896825],
#        [0.29836046],
#        [0.26453338],
#        [0.20440841],
#        [0.21182855],
#        [0.14788442],
#        [0.23670782],
#        [0.22514117],
#        [0.15475893],
#        [0.19033196],
#        [0.26213273],
#        [0.25711323],
#        [0.24882012],
#        [0.29083117],
#        [0.23899933],
#        [0.25012958],
#        [0.26966193],
#        [0.25787707],
#        [0.27566355],
#        [0.26507892],
#        [0.31723811],
#        [0.37408946],
#        [0.32749539],
#        [0.30261612],
#        [0.33055073],
#        [0.31614693],
#        [0.27511791],
#        [0.28024655],
#        [0.28875787],
#        [0.27719121],
#        [0.25122076],
#        [0.26737043],
#        [0.26256922],
#        [0.23332514],
#        [0.21903041],
#        [0.1977521 ],
#        [0.20375372],
#        [0.25263929],
#        [0.29421386],
#        [0.29825131],
#        [0.32203941],
#        [0.2680252 ],
#        [0.28592082],
#        [0.31243691],
#        [0.31047275],
#        [0.30479848],
#        [0.31167307],
#        [0.3014158 ],
#        [0.29028554],
#        [0.30174314],
#        [0.28581168],
#        [0.25012958],
#        [0.2680252 ],
#        [0.27915537],
#        [0.28352018],
#        [0.32760453],
#        [0.33862556],
#        [0.35499351],
#        [0.34495452],
#        [0.34179004],
#        [0.36426875],
#        [0.36601462],
#        [0.32203941],
#        [0.34309951],
#        [0.34495452],
#        [0.36394132],
#        [0.39744114],
#        [0.41369987],
#        [0.41435473],
#        [0.37136146],
#        [0.44327137],
#        [0.44927299],
#        [0.44010698],
#        [0.46924191],
#        [0.51354447],
#        [0.4865919 ],
#        [0.47022395],
#        [0.46411327],
#        [0.41359081],
#        [0.40082383],
#        [0.40780748],
#        [0.4522191 ],
#        [0.41686443],
#        [0.40933515],
#        [0.4121722 ],
#        [0.43443271],
#        [0.41239048],
#        [0.40147852],
#        [0.4110811 ],
#        [0.46716861],
#        [0.49423024],
#        [0.56832259],
#        [0.57410592],
#        [0.57225074],
#        [0.52958508],
#        [0.48931989],
#        [0.46662298],
#        [0.48822863],
#        [0.48855597],
#        [0.49444853],
#        [0.50590613],
#        [0.49150225],
#        [0.49794027],
#        [0.4964126 ],
#        [0.49008364],
#        [0.47317022],
#        [0.48560986],
#        [0.43934306],
#        [0.41697349],
#        [0.42832203],
#        [0.40398822],
#        [0.35761244],
#        [0.37048857],
#        [0.36765143],
#        [0.34484538],
#        [0.3575033 ],
#        [0.40835311],
#        [0.36906996],
#        [0.33567937],
#        [0.32727719],
#        [0.32673156],
#        [0.3059988 ],
#        [0.33502467],
#        [0.34429983],
#        [0.32094823],
#        [0.33196934],
#        [0.3787816 ],
#        [0.36077692],
#        [0.34800986],
#        [0.31549224],
#        [0.32018439],
#        [0.35292029],
#        [0.34735517],
#        [0.31156393],
#        [0.3204026 ],
#        [0.33458819],
#        [0.31778375],
#        [0.33458819],
#        [0.35652126],
#        [0.35881277],
#        [0.38751121],
#        [0.38020021],
#        [0.4142455 ],
#        [0.42352074],
#        [0.4532013 ],
#        [0.45232833],
#        [0.47960824],
#        [0.46738689],
#        [0.47262459],
#        [0.46400404],
#        [0.48048122],
#        [0.45145535],
#        [0.45887541],
#        [0.44927299],
#        [0.47840792],
#        [0.480372  ],
#        [0.47273365],
#        [0.49630354],
#        [0.44512639],
#        [0.44796344],
#        [0.43868837],
#        [0.41697349],
#        [0.40267884],
#        [0.43497834],
#        [0.41926508],
#        [0.35477531],
#        [0.35368413],
#        [0.36656025],
#        [0.38478322],
#        [0.39100304],
#        [0.3881659 ],
#        [0.35106528],
#        [0.37365305],
#        [0.40191501],
#        [0.38216437],
#        [0.40191501],
#        [0.39253071],
#        [0.38685652],
#        [0.37736308],
#        [0.37201624],
#        [0.36328663],
#        [0.36765143],
#        [0.36099513],
#        [0.38391024],
#        [0.38860239],
#        [0.3952587 ],
#        [0.3931854 ],
#        [0.38783856],
#        [0.40191501],
#        [0.42504841],
#        [0.42974047],
#        [0.42352074],
#        [0.43345067],
#        [0.42897672],
#        [0.44894564],
#        [0.46684126],
#        [0.47426132],
#        [0.46345858],
#        [0.46291295],
#        [0.47808058],
#        [0.49302992],
#        [0.49772215],
#        [0.51190757],
#        [0.53558669],
#        [0.57345106],
#        [0.5520637 ],
#        [0.56483068],
#        [0.60258616],
#        [0.57879799],
#        [0.62320978],
#        [0.63564941],
#        [0.62713809],
#        [0.57574265],
#        [0.57257825],
#        [0.59516594],
#        [0.59963989],
#        [0.61720816],
#        [0.62506479],
#        [0.63433986],
#        [0.58730931],
#        [0.58599993],
#        [0.58261724],
#        [0.60422289],
#        [0.59822128],
#        [0.61415282],
#        [0.61098826],
#        [0.60411383],
#        [0.60247694],
#        [0.60509587],
#        [0.60084021],
#        [0.60236788],
#        [0.63270313],
#        [0.6280109 ],
#        [0.64645215],
#        [0.64176009],
#        [0.58970996],
#        [0.61600784],
#        [0.6255012 ],
#        [0.63794083],
#        [0.64186915],
#        [0.62593777],
#        [0.61644424],
#        [0.63303048],
#        [0.67296832],
#        [0.67482334],
#        [0.68617171],
#        [0.68497139],
#        [0.69817494],
#        [0.72010793],
#        [0.70384921],
#        [0.69850229],
#        [0.65081704],
#        [0.6477617 ],
#        [0.62822919],
#        [0.62691981],
#        [0.63106641],
#        [0.57628828],
#        [0.57770673],
#        [0.58338099],
#        [0.60738729],
#        [0.59658455],
#        [0.59451125],
#        [0.57028667],
#        [0.56177535],
#        [0.57476061],
#        [0.55555544],
#        [0.55402778],
#        [0.52925773],
#        [0.52903944],
#        [0.56821337],
#        [0.57879799],
#        [0.55959299],
#        [0.57006838],
#        [0.54835367],
#        [0.55784703],
#        [0.57596094],
#        [0.57246903],
#        [0.61131561],
#        [0.62975686],
#        [0.63095718],
#        [0.64055976],
#        [0.62953857],
#        [0.63663145],
#        [0.6369588 ],
#        [0.64197837],
#        [0.61360719],
#        [0.63292142],
#        [0.62932045],
#        [0.64819811],
#        [0.66118338],
#        [0.66456606],
#        [0.65932836],
#        [0.64612481],
#        [0.64416073],
#        [0.63259407],
#        [0.62681058],
#        [0.64797982],
#        [0.64328776],
#        [0.65485442],
#        [0.68442592],
#        [0.72741893],
#        [0.77139415],
#        [0.76528347],
#        [0.7612461 ],
#        [0.74837006],
#        [0.74618753],
#        [0.75295306],
#        [0.83468359],
#        [0.7393131 ],
#        [0.79692828],
#        [0.79987439],
#        [0.85214281],
#        [0.88542434],
#        [0.9157596 ],
#        [0.91903322],
#        [0.98352282],
#        [0.91946963],
#        [0.91794196],
#        [0.96344484],
#        [0.86141788],
#        [0.8434132 ],
#        [0.87920444],
#        [0.89535411],
#        [0.92601687],
#        [0.93954761],
#        [0.97304743],
#        [0.96399047],
#        [0.96551814],
#        [0.95045957],
#        [0.94762252],
#        [1.        ],
#        [0.96704581],
#        [0.89164408],
#        [0.89371738],
#        [0.85214281],
#        [0.88749764],
#        [0.92896299],
#        [0.92525296],
#        [0.87680379],
#        [0.87865881],
#        [0.8621818 ],
#        [0.82922761],
#        [0.801293  ],
#        [0.75328041],
#        [0.74193187],
#        [0.79125401],
#        [0.77979641],
#        [0.81536953],
#        [0.86392775],
#        [0.90593873],
#        [0.91401364],
#        [0.91106737],
#        [0.88051382],
#        [0.89339003],
#        [0.88105945],
#        [0.92819923],
#        [0.90735734],
#        [0.8876067 ],
#        [0.83348327],
#        [0.87276642],
#        [0.882369  ],
#        [0.87342111],
#        [0.86021772],
#        [0.80740367],
#        [0.81351435],
#        [0.67209534],
#        [0.79496404],
#        [0.78645272],
#        [0.80434834],
#        [0.80096565],
#        [0.8454865 ],
#        [0.80205692],
#        [0.78972634],
#        [0.74018608],
#        [0.76921179],
#        [0.75524448],
#        [0.74138624],
#        [0.65976477],
#        [0.65376315],
#        [0.72087185],
#        [0.73789449],
#        [0.75862717],
#        [0.79136307],
#        [0.813187  ],
#        [0.8402488 ],
#        [0.87374846],
#        [0.90452028],
#        [0.88586075],
#        [0.93518289],
#        [0.95547915],
#        [0.94773158],
#        [0.90615701],
#        [0.91204957],
#        [0.94402155],
#        [0.88793405],
#        [0.87483972],
#        [0.88160509],
#        [0.84810543],
#        [0.84057615],
#        [0.83370156],
#        [0.86894716],
#        [0.79583702],
#        [0.80784025],
#        [0.8486509 ],
#        [0.85028779],
#        [0.82355351],
#        [0.76528347],
#        [0.77761405],
#        [0.70843222],
#        [0.74487815],
#        [0.7731401 ],
#        [0.71716182],
#        [0.73287492],
#        [0.74946115],
#        [0.79507326],
#        [0.70952331],
#        [0.69773837],
#        [0.70417655],
#        [0.68213433],
#        [0.56504897],
#        [0.58490866],
#        [0.59538423],
#        [0.63150281],
#        [0.60956982],
#        [0.53351339],
#        [0.52489284],
#        [0.51070725],
#        [0.54366144],
#        [0.5176909 ],
#        [0.50634253],
#        [0.59363827],
#        [0.6337944 ],
#        [0.64285118],
#        [0.6202635 ],
#        [0.61011528],
#        [0.61153389],
#        [0.5822899 ],
#        [0.62844747],
#        [0.61207952],
#        [0.53787811],
#        [0.45702039],
#        [0.45985761],
#        [0.47251537],
#        [0.44840001],
#        [0.42646702],
#        [0.46302201],
#        [0.47797135],
#        [0.5001228 ],
#        [0.53373151],
#        [0.56428505],
#        [0.55806532],
#        [0.50710645],
#        [0.50481486],
#        [0.49161131],
#        [0.51048913],
#        [0.549554  ],
#        [0.57072307],
#        [0.59221966],
#        [0.59669361],
#        [0.59767565],
#        [0.56744962],
#        [0.57934362],
#        [0.6415418 ],
#        [0.65201736],
#        [0.62124554],
#        [0.6561638 ],
#        [0.6930463 ],
#        [0.70275795],
#        [0.68769938],
#        [0.66860343],
#        [0.67209534],
#        [0.72010793],
#        [0.76659302],
#        [0.76408315],
#        [0.75415339],
#        [0.76222814],
#        [0.81864299],
#        [0.78808961],
#        [0.8225713 ],
#        [0.79692828],
#        [0.83686595],
#        [0.86283649],
#        [0.86021772],
#        [0.87876803],
#        [0.89251705],
#        [0.89240799],
#        [0.90310168],
#        [0.89524505],
#        [0.85879911],
#        [0.83031887],
#        [0.8329378 ],
#        [0.84886918],
#        [0.8684017 ],
#        [0.76561082],
#        [0.77630467],
#        [0.75644481],
#        [0.71639791],
#        [0.75033413],
#        [0.71454289],
#        [0.69653821],
#        [0.69457397],
#        [0.70363092],
#        [0.74858818],
#        [0.75197086],
#        [0.6962107 ],
#        [0.69468303],
#        [0.657146  ],
#        [0.63641316],
#        [0.68104307],
#        [0.72403625],
#        [0.66991298],
#        [0.65692772],
#        [0.64023242],
#        [0.6738413 ],
#        [0.6181902 ],
#        [0.60138584],
#        [0.54879008],
#        [0.51529042],
#        [0.58970996],
#        [0.57923456],
#        [0.59822128],
#        [0.5625391 ],
#        [0.53940578],
#        [0.53373151],
#        [0.52532941],
#        [0.48015388],
#        [0.58185333],
#        [0.54649866],
#        [0.59472953],
#        [0.55326402],
#        [0.56777696],
#        [0.56614007],
#        [0.61327985],
#        [0.64492448],
#        [0.65441801],
#        [0.62288243],
#        [0.62430087],
#        [0.6784243 ],
#        [0.69937526],
#        [0.63248485],
#        [0.5573014 ],
#        [0.55762875],
#        [0.50328719],
#        [0.53929672],
#        [0.51845482],
#        [0.54835367],
#        [0.5983305 ],
#        [0.63270313],
#        [0.66816703],
#        [0.63444909],
#        [0.60498664],
#        [0.66914907],
#        [0.6456884 ],
#        [0.62353712],
#        [0.63794083],
#        [0.6255012 ],
#        [0.59091028],
#        [0.58163504],
#        [0.55009946],
#        [0.6244101 ],
#        [0.59985817]])

# %%
train_data_scaled.shape,test_data_scaled.shape
# Out:
# ((604, 1), (152, 1))

# %%
def prepare_data(train_data, window_size):
    X, y = [], []
    for i in range(len(train_data) - window_size):
        X.append(train_data[i:i+window_size])
        y.append(train_data[i+window_size])
    X = np.array(X)
    y = np.array(y)
    return X, y

# %%
X_train, y_train = prepare_data(train_data_scaled, window_size=4)
X_test, y_test = prepare_data(test_data_scaled, window_size=4)

# %%
X_train.shape,y_train.shape
# Out:
# ((600, 4, 1), (600, 1))

# %%
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout, BatchNormalization, Conv1D

# Assuming each data point has 5 time steps and 2 features (open and score)
n_steps = 4
n_features = 1
input_shape=(n_steps, n_features)

# Define the model
model = Sequential()

# One-dimensional convolutional layer with 64 filters of size 1 with a stride of 1
model.add(Conv1D(filters=64, kernel_size=1, activation='relu', input_shape=input_shape))

# LSTM layer with 128 units
model.add(LSTM(256, activation='relu', return_sequences=True))

# LSTM layer with 64 units
model.add(LSTM(256, activation='relu', return_sequences=True))

# Another LSTM layer with 64 units
model.add(LSTM(128, activation='tanh'))

# Dense layer with 64 units and the ReLU activation
model.add(Dense(256, activation='relu'))



# Dense layer with 2 units (for 'Open' and 'Score')
model.add(Dense(1))

# Compile the model
model.compile(optimizer='adam', loss='mse')

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 4, 64)             128
#
#  lstm (LSTM)                 (None, 4, 256)            328704
#
#  lstm_1 (LSTM)               (None, 4, 256)            525312
#
#  lstm_2 (LSTM)               (None, 128)               197120
#
#  dense (Dense)               (None, 256)               33024
#
#  dense_1 (Dense)             (None, 1)                 257
#
# =================================================================
# Total params: 1,084,545
# Trainable params: 1,084,545
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Train the model
model.fit(X_train, y_train, epochs=150, verbose=1)
# Out:
# Epoch 1/150
# 19/19 [==============================] - 3s 27ms/step - loss: 0.1221
# Epoch 2/150
# 19/19 [==============================] - 1s 41ms/step - loss: 0.0197
# Epoch 3/150
# 19/19 [==============================] - 1s 39ms/step - loss: 0.0074
# Epoch 4/150
# 19/19 [==============================] - 1s 36ms/step - loss: 0.0029
# Epoch 5/150
# 19/19 [==============================] - 1s 35ms/step - loss: 0.0027
# Epoch 6/150
# 19/19 [==============================] - 1s 40ms/step - loss: 0.0025
# Epoch 7/150
# 19/19 [==============================] - 1s 35ms/step - loss: 0.0028
# Epoch 8/150
# 19/19 [==============================] - 1s 40ms/step - loss: 0.0028
# Epoch 9/150
# 19/19 [==============================] - 1s 32ms/step - loss: 0.0026
# Epoch 10/150
# 19/19 [==============================] - 0s 25ms/step - loss: 0.0026
# Epoch 11/150
# 19/19 [==============================] - 1s 34ms/step - loss: 0.0025
# Epoch 12/150
# 19/19 [==============================] - 1s 40ms/step - loss: 0.0024
# Epoch 13/150
# 19/19 [==============================] - 0s 25ms/step - loss: 0.0025
# Epoch 14/150
# 19/19 [==============================] - 1s 34ms/step - loss: 0.0023
# Epoch 15/150
# 19/19 [==============================] - 1s 26ms/step - loss: 0.0025
# Epoch 16/150
# 19/19 [==============================] - 1s 34ms/step - loss: 0.0025
# Epoch 17/150
# 19/19 [==============================] - 1s 31ms/step - loss: 0.0024
# Epoch 18/150
# 19/19 [==============================] - 0s 24ms/step - loss: 0.0023
# Epoch 19/150
# 19/19 [==============================] - 0s 25ms/step - loss: 0.0021
# Epoch 20/150
# 19/19 [==============================] - 0s 25ms/step - loss: 0.0022
# Epoch 21/150
# 19/19 [==============================] - 0s 24ms/step - loss: 0.0023
# Epoch 22/150
# 19/19 [==============================] - 0s 25ms/step - loss: 0.0024
# Epoch 23/150
# 19/19 [==============================] - 0s 25ms/step - loss: 0.0031
# Epoch 24/150
# 19/19 [==============================] - 0s 26ms/step - loss: 0.0026
# Epoch 25/150
# 19/19 [==============================] - 0s 25ms/step - loss: 0.0021
# Epoch 26/150
# 19/19 [==============================] - 0s 25ms/step - loss: 0.0024
# Epoch 27/150
# 19/19 [==============================] - 0s 26ms/step - loss: 0.0024
# Epoch 28/150
# 19/19 [==============================] - 0s 26ms/step - loss: 0.0019
# Epoch 29/150
# 19/19 [==============================] - 1s 26ms/step - loss: 0.0019
# Epoch 30/150
# 19/19 [==============================] - 1s 31ms/step - loss: 0.0018
# Epoch 31/150
# 19/19 [==============================] - 1s 38ms/step - loss: 0.0018
# Epoch 32/150
# 19/19 [==============================] - 1s 31ms/step - loss: 0.0016
# Epoch 33/150
# 19/19 [==============================] - 1s 29ms/step - loss: 0.0015
# Epoch 34/150
# 19/19 [==============================] - 0s 25ms/step - loss: 0.0014
# Epoch 35/150
# 19/19 [==============================] - 1s 28ms/step - loss: 0.0015
# Epoch 36/150
# 19/19 [==============================] - 1s 34ms/step - loss: 0.0018
# Epoch 37/150
# 19/19 [==============================] - 1s 37ms/step - loss: 0.0018
# Epoch 38/150
# 19/19 [==============================] - 1s 40ms/step - loss: 0.0014
# Epoch 39/150
# 19/19 [==============================] - 1s 39ms/step - loss: 0.0013
# Epoch 40/150
# 19/19 [==============================] - 1s 37ms/step - loss: 0.0014
# Epoch 41/150
# 19/19 [==============================] - 1s 40ms/step - loss: 0.0013
# Epoch 42/150
# 19/19 [==============================] - 1s 41ms/step - loss: 0.0012
# Epoch 43/150
# 19/19 [==============================] - 1s 42ms/step - loss: 0.0015
# Epoch 44/150
# 19/19 [==============================] - 1s 41ms/step - loss: 0.0017
# Epoch 45/150
# 19/19 [==============================] - 1s 40ms/step - loss: 0.0012
# Epoch 46/150
# 19/19 [==============================] - 1s 42ms/step - loss: 0.0014
# Epoch 47/150
# 19/19 [==============================] - 1s 34ms/step - loss: 0.0013
# Epoch 48/150
# 19/19 [==============================] - 1s 35ms/step - loss: 0.0016
# Epoch 49/150
# 19/19 [==============================] - 1s 36ms/step - loss: 0.0015
# Epoch 50/150
# 19/19 [==============================] - 1s 37ms/step - loss: 0.0014
# Epoch 51/150
# 19/19 [==============================] - 1s 36ms/step - loss: 0.0012
# Epoch 52/150
# 19/19 [==============================] - 1s 34ms/step - loss: 0.0012
# Epoch 53/150
# 19/19 [==============================] - 1s 37ms/step - loss: 0.0013
# Epoch 54/150
# 19/19 [==============================] - 1s 40ms/step - loss: 0.0013
# Epoch 55/150
# 19/19 [==============================] - 1s 35ms/step - loss: 0.0015
# Epoch 56/150
# 19/19 [==============================] - 1s 27ms/step - loss: 0.0012
# Epoch 57/150
# 19/19 [==============================] - 1s 38ms/step - loss: 0.0012
# Epoch 58/150
# 19/19 [==============================] - 1s 43ms/step - loss: 0.0012
# Epoch 59/150
# 19/19 [==============================] - 1s 37ms/step - loss: 0.0013
# Epoch 60/150
# 19/19 [==============================] - 1s 36ms/step - loss: 0.0015
# Epoch 61/150
# 19/19 [==============================] - 1s 28ms/step - loss: 0.0016
# Epoch 62/150
# 19/19 [==============================] - 0s 27ms/step - loss: 0.0015
# Epoch 63/150
# 19/19 [==============================] - 1s 33ms/step - loss: 0.0014
# Epoch 64/150
# 19/19 [==============================] - 1s 34ms/step - loss: 0.0015
# Epoch 65/150
# 19/19 [==============================] - 1s 38ms/step - loss: 0.0014
# Epoch 66/150
# 19/19 [==============================] - 1s 38ms/step - loss: 0.0012
# Epoch 67/150
# 19/19 [==============================] - 1s 37ms/step - loss: 0.0012
# Epoch 68/150
# 19/19 [==============================] - 1s 41ms/step - loss: 0.0015
# Epoch 69/150
# 19/19 [==============================] - 1s 38ms/step - loss: 0.0013
# Epoch 70/150
# 19/19 [==============================] - 1s 36ms/step - loss: 0.0012
# Epoch 71/150
# 19/19 [==============================] - 1s 41ms/step - loss: 0.0013
# Epoch 72/150
# 19/19 [==============================] - 1s 37ms/step - loss: 0.0014
# Epoch 73/150
# 19/19 [==============================] - 1s 37ms/step - loss: 0.0016
# Epoch 74/150
# 19/19 [==============================] - 1s 32ms/step - loss: 0.0016
# Epoch 75/150
# 19/19 [==============================] - 1s 37ms/step - loss: 0.0017
# Epoch 76/150
# 19/19 [==============================] - 1s 40ms/step - loss: 0.0013
# Epoch 77/150
# 19/19 [==============================] - 1s 36ms/step - loss: 0.0012
# Epoch 78/150
# 19/19 [==============================] - 1s 37ms/step - loss: 0.0014
# Epoch 79/150
# 19/19 [==============================] - 1s 41ms/step - loss: 0.0013
# Epoch 80/150
# 19/19 [==============================] - 1s 35ms/step - loss: 0.0013
# Epoch 81/150
# 19/19 [==============================] - 1s 30ms/step - loss: 0.0017
# Epoch 82/150
# 19/19 [==============================] - 0s 25ms/step - loss: 0.0014
# Epoch 83/150
# 19/19 [==============================] - 0s 26ms/step - loss: 0.0012
# Epoch 84/150
# 19/19 [==============================] - 0s 25ms/step - loss: 0.0011
# Epoch 85/150
# 19/19 [==============================] - 1s 27ms/step - loss: 0.0012
# Epoch 86/150
# 19/19 [==============================] - 0s 26ms/step - loss: 0.0012
# Epoch 87/150
# 19/19 [==============================] - 0s 26ms/step - loss: 0.0012
# Epoch 88/150
# 19/19 [==============================] - 1s 27ms/step - loss: 0.0012
# Epoch 89/150
# 19/19 [==============================] - 1s 32ms/step - loss: 0.0013
# Epoch 90/150
# 19/19 [==============================] - 1s 26ms/step - loss: 0.0013
# Epoch 91/150
# 19/19 [==============================] - 1s 45ms/step - loss: 0.0013
# Epoch 92/150
# 19/19 [==============================] - 1s 40ms/step - loss: 0.0013
# Epoch 93/150
# 19/19 [==============================] - 1s 40ms/step - loss: 0.0012
# Epoch 94/150
# 19/19 [==============================] - 1s 33ms/step - loss: 0.0014
# Epoch 95/150
# 19/19 [==============================] - 1s 42ms/step - loss: 0.0014
# Epoch 96/150
# 19/19 [==============================] - 1s 40ms/step - loss: 0.0013
# Epoch 97/150
# 19/19 [==============================] - 1s 42ms/step - loss: 0.0013
# Epoch 98/150
# 19/19 [==============================] - 1s 43ms/step - loss: 0.0011
# Epoch 99/150
# 19/19 [==============================] - 1s 44ms/step - loss: 0.0012
# Epoch 100/150
# 19/19 [==============================] - 1s 44ms/step - loss: 0.0013
# Epoch 101/150
# 19/19 [==============================] - 1s 40ms/step - loss: 0.0012
# Epoch 102/150
# 19/19 [==============================] - 1s 42ms/step - loss: 0.0011
# Epoch 103/150
# 19/19 [==============================] - 1s 44ms/step - loss: 0.0012
# Epoch 104/150
# 19/19 [==============================] - 1s 39ms/step - loss: 0.0013
# Epoch 105/150
# 19/19 [==============================] - 1s 38ms/step - loss: 0.0012
# Epoch 106/150
# 19/19 [==============================] - 1s 44ms/step - loss: 0.0013
# Epoch 107/150
# 19/19 [==============================] - 1s 42ms/step - loss: 0.0012
# Epoch 108/150
# 19/19 [==============================] - 1s 42ms/step - loss: 0.0012
# Epoch 109/150
# 19/19 [==============================] - 1s 36ms/step - loss: 0.0011
# Epoch 110/150
# 19/19 [==============================] - 1s 26ms/step - loss: 0.0011
# Epoch 111/150
# 19/19 [==============================] - 0s 25ms/step - loss: 0.0012
# Epoch 112/150
# 19/19 [==============================] - 0s 26ms/step - loss: 0.0011
# Epoch 113/150
# 19/19 [==============================] - 0s 25ms/step - loss: 0.0014
# Epoch 114/150
# 19/19 [==============================] - 1s 26ms/step - loss: 0.0016
# Epoch 115/150
# 19/19 [==============================] - 0s 26ms/step - loss: 0.0013
# Epoch 116/150
# 19/19 [==============================] - 0s 25ms/step - loss: 0.0012
# Epoch 117/150
# 19/19 [==============================] - 0s 25ms/step - loss: 0.0015
# Epoch 118/150
# 19/19 [==============================] - 0s 25ms/step - loss: 0.0012
# Epoch 119/150
# 19/19 [==============================] - 0s 25ms/step - loss: 0.0011
# Epoch 120/150
# 19/19 [==============================] - 0s 25ms/step - loss: 0.0011
# Epoch 121/150
# 19/19 [==============================] - 0s 25ms/step - loss: 0.0011
# Epoch 122/150
# 19/19 [==============================] - 0s 27ms/step - loss: 0.0012
# Epoch 123/150
# 19/19 [==============================] - 1s 29ms/step - loss: 0.0011
# Epoch 124/150
# 19/19 [==============================] - 1s 29ms/step - loss: 0.0011
# Epoch 125/150
# 19/19 [==============================] - 1s 32ms/step - loss: 0.0015
# Epoch 126/150
# 19/19 [==============================] - 1s 30ms/step - loss: 0.0012
# Epoch 127/150
# 19/19 [==============================] - 1s 35ms/step - loss: 0.0012
# Epoch 128/150
# 19/19 [==============================] - 1s 34ms/step - loss: 0.0011
# Epoch 129/150
# 19/19 [==============================] - 1s 33ms/step - loss: 0.0011
# Epoch 130/150
# 19/19 [==============================] - 1s 35ms/step - loss: 0.0012
# Epoch 131/150
# 19/19 [==============================] - 1s 32ms/step - loss: 0.0012
# Epoch 132/150
# 19/19 [==============================] - 1s 36ms/step - loss: 0.0012
# Epoch 133/150
# 19/19 [==============================] - 1s 32ms/step - loss: 0.0012
# Epoch 134/150
# 19/19 [==============================] - 1s 33ms/step - loss: 0.0013
# Epoch 135/150
# 19/19 [==============================] - 1s 32ms/step - loss: 0.0011
# Epoch 136/150
# 19/19 [==============================] - 1s 33ms/step - loss: 0.0012
# Epoch 137/150
# 19/19 [==============================] - 1s 32ms/step - loss: 0.0015
# Epoch 138/150
# 19/19 [==============================] - 1s 35ms/step - loss: 0.0011
# Epoch 139/150
# 19/19 [==============================] - 1s 31ms/step - loss: 0.0011
# Epoch 140/150
# 19/19 [==============================] - 1s 35ms/step - loss: 0.0013
# Epoch 141/150
# 19/19 [==============================] - 1s 31ms/step - loss: 0.0012
# Epoch 142/150
# 19/19 [==============================] - 1s 36ms/step - loss: 0.0011
# Epoch 143/150
# 19/19 [==============================] - 1s 34ms/step - loss: 0.0011
# Epoch 144/150
# 19/19 [==============================] - 1s 34ms/step - loss: 0.0012
# Epoch 145/150
# 19/19 [==============================] - 1s 36ms/step - loss: 0.0014
# Epoch 146/150
# 19/19 [==============================] - 1s 33ms/step - loss: 0.0011
# Epoch 147/150
# 19/19 [==============================] - 1s 34ms/step - loss: 0.0011
# Epoch 148/150
# 19/19 [==============================] - 1s 35ms/step - loss: 0.0011
# Epoch 149/150
# 19/19 [==============================] - 1s 36ms/step - loss: 0.0012
# Epoch 150/150
# 19/19 [==============================] - 1s 31ms/step - loss: 0.0012

# %%
### Lets Do the prediction and check performance metrics
train_predict=model.predict(X_train)
test_predict=model.predict(X_test)
# Out:
# 19/19 [==============================] - 1s 12ms/step
# 5/5 [==============================] - 0s 15ms/step

# %%
train_predict.shape
# Out:
# (600, 1)

# %%
##Transformback to original form
train_predict=scaler.inverse_transform(train_predict)
test_predict=scaler.inverse_transform(test_predict)

# %%
train_predict.shape,test_predict.shape
# Out:
# ((600, 1), (148, 1))

# %%
train_data_compare = np.array(train_data[n_steps:]).reshape(-1,1)
test_data_campare = np.array(test_data[n_steps:]).reshape(-1,1)
train_data_compare.shape,test_data_campare.shape
# Out:
# ((600, 1), (148, 1))

# %%
### Calculate RMSE performance metrics
import math
from sklearn.metrics import mean_squared_error

print(f"The RMSE for train is {math.sqrt(mean_squared_error(train_data_compare, train_predict))}")
print(f"The RMSE for test is {math.sqrt(mean_squared_error(test_data_campare, test_predict))}")
# Out:
# The RMSE for train is 23.25198553431382
# The RMSE for test is 2.3719769161904942

# %%
#predicting for next five days
# Assuming `test_data_scaled` is your time series data and `model` is your trained model
window_size=n_steps
input_seq = test_data_scaled[-n_steps:]

for _ in range(window_size):
    # Reshape the input sequence
    input_seq = input_seq.reshape((1, n_steps, n_features))

    # Make a prediction
    prediction = model.predict(input_seq)

    # Update the input sequence
    input_seq = np.append(input_seq[:, 1:, :], prediction)

# `input_seq` now contains the original data for the last `n_steps` time steps followed by `window_size` forecasted time steps
# Out:
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 28ms/step

# %%
future_predict = scaler.inverse_transform(np.array(input_seq).reshape(-1,1))

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming 'dates', 'stock_open', 'train_predict', 'test_predict' are defined
dates = np.array(index)
stock_open = np.array(stock_open)
train_predict = np.array(train_predict)
test_predict = np.array(test_predict)

# Create empty arrays for the plot
trainPredictPlot = np.empty_like(stock_open)
trainPredictPlot[:] = np.nan
trainPredictPlot[n_steps:len(train_predict)+n_steps] = train_predict.flatten()

testPredictPlot = np.empty_like(stock_open)
testPredictPlot[:] = np.nan
testPredictPlot[len(train_predict)+(n_steps*2):len(train_predict)+(n_steps*2)+len(test_predict)] = test_predict.flatten()

# Flatten future_predict
future_predict = future_predict.flatten()

# Create an array for the future prediction dates
future_dates = np.arange(dates[-1] + np.timedelta64(1, 'D'), dates[-1] + np.timedelta64(window_size + 1, 'D'), np.timedelta64(1, 'D'))

# Create an array for the plot
futurePredictPlot = np.empty_like(np.concatenate((stock_open, np.full(window_size, np.nan))))
futurePredictPlot[:] = np.nan
futurePredictPlot[len(train_predict) + (n_steps * 2) + len(test_predict):] = future_predict

# Plotting
plt.figure(figsize=(8,4))
plt.plot(np.concatenate((dates, future_dates)), np.concatenate((stock_open, np.full(window_size, np.nan))), color='blue', label='Actual')
plt.plot(dates, trainPredictPlot, color='orange', label='Train Predict')
plt.plot(dates, testPredictPlot, color='green', label='Test Predict')
plt.plot(np.concatenate((dates, future_dates)), futurePredictPlot, color='red', label='Future Predict')
plt.xlabel('Date')
plt.ylabel('Price')
plt.title('Stock Prices Over Time For LSTM')
plt.legend()
plt.show()

# %%
future_predict
# Out:
# array([192.25849974, 194.01026111, 195.75871017, 197.35221567])
