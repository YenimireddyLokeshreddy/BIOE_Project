# %% [markdown]
# # SENTIMENT_SCORE ALONG WITH STOCK PRICE

# %%
#installing pandas datareader
#!pip install pandas-datareader

# %%
#!pip install yfinance

# %%
import pandas_datareader as pdr
import pandas as pd
from datetime import datetime

# %%
import yfinance as yf

# Define the stock symbol and the date range
symbol = 'AAPL'
start_date = '2021-08-18'
end_date = '2023-07-17'

# Retrieve the stock data from Yahoo Finance
data = yf.download(symbol, start=start_date, end=end_date)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
# Load the sentiment score data
df_senti_avg = pd.read_csv('Sentiment_score.csv')
df_senti_avg.head()
# Out:
#   publishedAt     score
# 0  2021-08-18  0.398418
# 1  2021-08-19 -0.052142
# 2  2021-08-20  0.258557
# 3  2021-08-21  0.253870
# 4  2021-08-22 -0.018721

# %%
data.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2021-08-18  149.800003  150.720001  146.149994  146.360001  144.881470
# 2021-08-19  145.029999  148.000000  144.500000  146.699997  145.218048
# 2021-08-20  147.440002  148.500000  146.779999  148.190002  146.692978
# 2021-08-23  148.309998  150.190002  147.889999  149.710007  148.197632
# 2021-08-24  149.449997  150.860001  149.149994  149.619995  148.108536
#
#               Volume
# Date
# 2021-08-18  86326000
# 2021-08-19  86960300
# 2021-08-20  60549600
# 2021-08-23  60131800
# 2021-08-24  48606400

# %%
data.tail()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2023-07-10  189.259995  189.990005  187.039993  188.610001  188.610001
# 2023-07-11  189.160004  189.300003  186.600006  188.080002  188.080002
# 2023-07-12  189.679993  191.699997  188.470001  189.770004  189.770004
# 2023-07-13  190.500000  191.190002  189.779999  190.539993  190.539993
# 2023-07-14  190.229996  191.179993  189.630005  190.690002  190.690002
#
#               Volume
# Date
# 2023-07-10  59922200
# 2023-07-11  46638100
# 2023-07-12  60750200
# 2023-07-13  41342300
# 2023-07-14  41573900

# %%
data['High'].plot(xlim=['2021-08-18','2023-07-17'],ylim=[120,200],figsize=(12,4),ls='--',c='green')
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
index = data.loc['2021-08-18':'2023-07-17'].index
stock_open = data.loc['2021-08-18':'2023-07-17']['Open']
stock_high = data.loc['2021-08-18':'2023-07-17']['High']
stock_low = data.loc['2021-08-18':'2023-07-17']['Low']
stock_close = data.loc['2021-08-18':'2023-07-17']['Close']

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

figure, axis = plt.subplots(figsize=(12,4))
plt.tight_layout()
# preventing overlapping
figure.autofmt_xdate()

# assuming 'index', 'stock_open', 'stock_high', 'stock_low', 'stock_close' are defined
axis.plot(index, stock_open, label='Open')
axis.plot(index, stock_high, label='High')
axis.plot(index, stock_low, label='Low')
axis.plot(index, stock_close, label='Close')

# Add labels and title
axis.set_xlabel('Date')
axis.set_ylabel('Price')
axis.set_title('Stock Prices Over Time')

# Add a legend
axis.legend()

plt.show()

# %%
import pandas as pd

# Assuming you have already performed the necessary data_reset and df_senti_avg operations
# Reset the index and make it a column
data.reset_index(level=0, inplace=True)
df_senti_avg['publishedAt'] = pd.to_datetime(df_senti_avg['publishedAt'])

# Perform the left join operation
merged_df = pd.merge(data, df_senti_avg, how='left', left_on='Date', right_on='publishedAt')
merged_df.set_index('Date', inplace=True)
#merged_df.drop( 'index', axis=1, inplace=True)
merged_df
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2021-08-18  149.800003  150.720001  146.149994  146.360001  144.881470
# 2021-08-19  145.029999  148.000000  144.500000  146.699997  145.218048
# 2021-08-20  147.440002  148.500000  146.779999  148.190002  146.692978
# 2021-08-23  148.309998  150.190002  147.889999  149.710007  148.197632
# 2021-08-24  149.449997  150.860001  149.149994  149.619995  148.108536
# ...                ...         ...         ...         ...         ...
# 2023-07-10  189.259995  189.990005  187.039993  188.610001  188.610001
# 2023-07-11  189.160004  189.300003  186.600006  188.080002  188.080002
# 2023-07-12  189.679993  191.699997  188.470001  189.770004  189.770004
# 2023-07-13  190.500000  191.190002  189.779999  190.539993  190.539993
# 2023-07-14  190.229996  191.179993  189.630005  190.690002  190.690002
#
#               Volume publishedAt     score
# Date
# 2021-08-18  86326000  2021-08-18  0.398418
# 2021-08-19  86960300  2021-08-19 -0.052142
# 2021-08-20  60549600  2021-08-20  0.258557
# 2021-08-23  60131800  2021-08-23  0.187540
# 2021-08-24  48606400  2021-08-24  0.498763
# ...              ...         ...       ...
# 2023-07-10  59922200  2023-07-10  0.293409
# 2023-07-11  46638100  2023-07-11  0.475714
# 2023-07-12  60750200  2023-07-12  0.000000
# 2023-07-13  41342300  2023-07-13  0.080541
# 2023-07-14  41573900  2023-07-14  0.185541
#
# [479 rows x 8 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Compute the correlation matrix
corr = merged_df.corr()
print(corr)
# Out:
#                Open      High       Low     Close  Adj Close    Volume  \
# Open       1.000000  0.994532  0.994394  0.985436   0.984747 -0.138902
# High       0.994532  1.000000  0.993868  0.993555   0.992620 -0.100386
# Low        0.994394  0.993868  1.000000  0.994057   0.993694 -0.177348
# Close      0.985436  0.993555  0.994057  1.000000   0.999385 -0.137961
# Adj Close  0.984747  0.992620  0.993694  0.999385   1.000000 -0.151376
# Volume    -0.138902 -0.100386 -0.177348 -0.137961  -0.151376  1.000000
# score      0.070517  0.070197  0.072402  0.072011   0.071724 -0.041740
#
#               score
# Open       0.070517
# High       0.070197
# Low        0.072402
# Close      0.072011
# Adj Close  0.071724
# Volume    -0.041740
# score      1.000000

# %%
senti_open = merged_df[["Open","score"]]
senti_open
# Out:
#                   Open     score
# Date
# 2021-08-18  149.800003  0.398418
# 2021-08-19  145.029999 -0.052142
# 2021-08-20  147.440002  0.258557
# 2021-08-23  148.309998  0.187540
# 2021-08-24  149.449997  0.498763
# ...                ...       ...
# 2023-07-10  189.259995  0.293409
# 2023-07-11  189.160004  0.475714
# 2023-07-12  189.679993  0.000000
# 2023-07-13  190.500000  0.080541
# 2023-07-14  190.229996  0.185541
#
# [479 rows x 2 columns]

# %%
# Calculate the split point
split_point = int(len(senti_open) * 0.8)

# Split the data
train_data = senti_open.iloc[:split_point]
test_data = senti_open.iloc[split_point:]

# Print the shapes of the training and testing sets
print("Training set shape:", train_data.shape)
print("Testing set shape:", test_data.shape)
# Out:
# Training set shape: (383, 2)
# Testing set shape: (96, 2)

# %%
import numpy as np
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler(feature_range=(0,1))
train_data_scaled=scaler.fit_transform(train_data)
test_data_scaled=scaler.transform(test_data)

# %%
train_data_scaled
# Out:
# array([[0.42016955, 0.69379794],
#        [0.33592363, 0.33580399],
#        [0.37848815, 0.58267041],
#        [0.39385366, 0.52624398],
#        [0.41398788, 0.77352712],
#        [0.42034607, 0.5648515 ],
#        [0.39456028, 0.67646793],
#        [0.3791945 , 0.37723377],
#        [0.40604021, 0.58438735],
#        [0.47068174, 0.28401847],
#        [0.47368418, 0.27837804],
#        [0.49205213, 0.49452171],
#        [0.49010934, 0.31197911],
#        [0.51148   , 0.29821344],
#        [0.54697973, 0.33663457],
#        [0.52066411, 0.52672757],
#        [0.51200983, 0.40861575],
#        [0.43482871, 0.69361817],
#        [0.42988348, 0.60902651],
#        [0.39826906, 0.50163996],
#        [0.39614976, 0.51016145],
#        [0.40286125, 0.30542591],
#        [0.31419993, 0.67735725],
#        [0.31649576, 0.45651427],
#        [0.32567986, 0.37723377],
#        [0.36453534, 0.37723377],
#        [0.34705052, 0.67912008],
#        [0.34369477, 0.88728122],
#        [0.30448599, 0.45610611],
#        [0.29070997, 0.4504763 ],
#        [0.31172732, 0.32592518],
#        [0.28064272, 0.37723377],
#        [0.27817011, 0.61159813],
#        [0.23807847, 0.41412081],
#        [0.23772516, 0.5851669 ],
#        [0.30113025, 0.53317002],
#        [0.31826202, 0.65310683],
#        [0.2871777 , 0.69099373],
#        [0.30413269, 0.05969402],
#        [0.26898627, 0.68164048],
#        [0.28435178, 0.69462631],
#        [0.3136701 , 0.45597675],
#        [0.30801826, 0.58290144],
#        [0.37089352, 0.46096239],
#        [0.40074168, 0.45358583],
#        [0.40268446, 0.27275391],
#        [0.41822676, 0.55970161],
#        [0.40038837, 0.45675207],
#        [0.41186857, 0.69491691],
#        [0.4123984 , 0.58943557],
#        [0.42052285, 0.37211512],
#        [0.37460258, 0.29765495],
#        [0.40586369, 0.50835927],
#        [0.40003533, 0.43379957],
#        [0.43058983, 0.40457907],
#        [0.45160718, 0.37723377],
#        [0.45708223, 0.50739147],
#        [0.44860474, 0.30057779],
#        [0.42723408, 0.61186867],
#        [0.42405512, 0.65583484],
#        [0.40533387, 0.37723377],
#        [0.39597297, 0.45445854],
#        [0.43023652, 0.60096282],
#        [0.42264216, 0.57576139],
#        [0.44136342, 0.37916964],
#        [0.48922648, 0.44603871],
#        [0.55881297, 0.42172721],
#        [0.62998921, 0.49710927],
#        [0.62009875, 0.15678328],
#        [0.61356404, 0.54226117],
#        [0.59272348, 0.57976504],
#        [0.58919095, 0.54732369],
#        [0.60014132, 0.53911177],
#        [0.73242656, 0.60323324],
#        [0.57806432, 0.53607321],
#        [0.67131756, 0.4131463 ],
#        [0.676086  , 0.58034596],
#        [0.76068523, 0.84535076],
#        [0.81455317, 0.37726723],
#        [0.8636524 , 0.45520808],
#        [0.86895094, 0.42878569],
#        [0.97333081, 0.52588466],
#        [0.86965728, 0.60224263],
#        [0.86718467, 0.06532441],
#        [0.94083352, 0.46178397],
#        [0.77569743, 0.45267288],
#        [0.74655589, 0.58426983],
#        [0.80448593, 0.7238422 ],
#        [0.83062502, 0.37723377],
#        [0.88025435, 0.40739655],
#        [0.90215457, 0.31942414],
#        [0.95637582, 0.57381408],
#        [0.94171666, 0.30467969],
#        [0.94418927, 0.21996134],
#        [0.91981617, 0.52152821],
#        [0.91522425, 0.74321025],
#        [1.        , 0.61509616],
#        [0.94666188, 0.4813386 ],
#        [0.82462014, 0.43529977],
#        [0.82797589, 0.52423473],
#        [0.76068523, 0.37723377],
#        [0.81790892, 0.73103811],
#        [0.88502279, 0.45603163],
#        [0.87901791, 0.48133265],
#        [0.80060035, 0.57908637],
#        [0.80360279, 0.37723377],
#        [0.77693387, 0.4032977 ],
#        [0.72359575, 0.45621067],
#        [0.67838209, 0.37723377],
#        [0.60067115, 0.66359709],
#        [0.58230293, 0.58125024],
#        [0.66213345, 0.53607101],
#        [0.64358872, 1.        ],
#        [0.70116571, 0.61538059],
#        [0.77975979, 0.66701307],
#        [0.8477568 , 0.51478552],
#        [0.86082648, 0.21863604],
#        [0.85605778, 0.83177695],
#        [0.80660523, 0.29914189],
#        [0.82744607, 0.79727291],
#        [0.80748837, 0.37239169],
#        [0.88378662, 0.76076424],
#        [0.8500529 , 0.43712549],
#        [0.81808544, 0.37742392],
#        [0.73048377, 0.24804155],
#        [0.79406565, 0.5892606 ],
#        [0.80960794, 0.52947048],
#        [0.7951253 , 0.44628517],
#        [0.77375491, 0.26486279],
#        [0.68827255, 0.38463255],
#        [0.698163  , 0.47961855],
#        [0.46926878, 0.61104246],
#        [0.66813833, 0.53572873],
#        [0.6543623 , 0.38840557],
#        [0.68332732, 0.36862739],
#        [0.67785227, 0.53270061],
#        [0.74991164, 0.37723377],
#        [0.67961854, 0.29824917],
#        [0.65966084, 0.61305193],
#        [0.57947728, 0.54042577],
#        [0.62645694, 0.65330401],
#        [0.60385011, 0.37723377],
#        [0.5814198 , 0.53558835],
#        [0.44931108, 0.58521701],
#        [0.43959715, 0.44460936],
#        [0.54821617, 0.48331873],
#        [0.57576822, 0.60996064],
#        [0.60932516, 0.45667199],
#        [0.66230997, 0.36999279],
#        [0.69763318, 0.        ],
#        [0.74143415, 0.45584968],
#        [0.79565513, 0.45002143],
#        [0.84546098, 0.45666761],
#        [0.81525952, 0.3480048 ],
#        [0.89509004, 0.41666978],
#        [0.92794063, 0.29030874],
#        [0.91540077, 0.53603944],
#        [0.84811011, 0.82813547],
#        [0.85764752, 0.60503829],
#        [0.90939589, 0.21888571],
#        [0.81861526, 0.53447124],
#        [0.79742139, 0.43763456],
#        [0.8083715 , 0.53142326],
#        [0.75415052, 0.57744681],
#        [0.74196397, 0.57587139],
#        [0.73083708, 0.37723377],
#        [0.78788398, 0.38533343],
#        [0.66955129, 0.51954025],
#        [0.68897916, 0.45512012],
#        [0.75503339, 0.43614377],
#        [0.75768279, 0.66173326],
#        [0.71441191, 0.37723377],
#        [0.62009875, 0.37723377],
#        [0.64005645, 0.4356698 ],
#        [0.52808195, 0.53594622],
#        [0.58707164, 0.41098381],
#        [0.63281513, 0.72065408],
#        [0.54221129, 0.61845516],
#        [0.56764377, 0.45640336],
#        [0.59448948, 0.53136321],
#        [0.66831512, 0.50625961],
#        [0.52984795, 0.45655677],
#        [0.51077339, 0.37723377],
#        [0.52119394, 0.33588952],
#        [0.48551742, 0.4559374 ],
#        [0.2960085 , 0.14295956],
#        [0.32815248, 0.37723377],
#        [0.34510774, 0.5824856 ],
#        [0.4035676 , 0.37599833],
#        [0.36806787, 0.36939382],
#        [0.24496648, 0.59897634],
#        [0.23101366, 0.45924855],
#        [0.20805352, 0.6945809 ],
#        [0.26139164, 0.4565461 ],
#        [0.21935694, 0.45808416],
#        [0.20098899, 0.52248345],
#        [0.34228181, 0.39028724],
#        [0.40727665, 0.6770234 ],
#        [0.42193555, 0.45076449],
#        [0.38537617, 0.68942106],
#        [0.36895074, 0.44663733],
#        [0.37124683, 0.44490573],
#        [0.32391387, 0.45546135],
#        [0.39862237, 0.45667701],
#        [0.37212997, 0.37800377],
#        [0.25203101, 0.53703333],
#        [0.12115847, 0.77482553],
#        [0.12575066, 0.6061935 ],
#        [0.14623792, 0.31693545],
#        [0.10720592, 0.49379604],
#        [0.0717062 , 0.29788058],
#        [0.13087241, 0.53392781],
#        [0.15506872, 0.45766222],
#        [0.19092202, 0.40412778],
#        [0.24531952, 0.55622073],
#        [0.29477206, 0.56917408],
#        [0.28470509, 0.52970666],
#        [0.20222543, 0.53495736],
#        [0.19851638, 0.61545556],
#        [0.17714572, 0.45451955],
#        [0.20770049, 0.73173649],
#        [0.27092906, 0.53224696],
#        [0.30519234, 0.60764804],
#        [0.33998572, 0.5941029 ],
#        [0.34722704, 0.54150864],
#        [0.34881652, 0.3347776 ],
#        [0.29989408, 0.53264835],
#        [0.31914516, 0.37732484],
#        [0.41981624, 0.69410003],
#        [0.4367715 , 0.25544603],
#        [0.38696565, 0.71469494],
#        [0.44348272, 0.66183777],
#        [0.50317903, 0.36775702],
#        [0.51889784, 0.61081017],
#        [0.49452474, 0.49617829],
#        [0.46361694, 0.5309408 ],
#        [0.46926878, 0.40784107],
#        [0.54697973, 0.51793995],
#        [0.62221833, 0.45367293],
#        [0.61815596, 0.67884427],
#        [0.60208411, 0.71338616],
#        [0.61515352, 0.51241335],
#        [0.70646398, 0.47835877],
#        [0.65701171, 0.5357073 ],
#        [0.71282217, 0.61534187],
#        [0.67131756, 0.39867063],
#        [0.73595882, 0.53610982],
#        [0.77799352, 0.37662346],
#        [0.77375491, 0.417136  ],
#        [0.80377958, 0.37723377],
#        [0.8260331 , 0.61298698],
#        [0.82585659, 0.06389479],
#        [0.84316488, 0.31804265],
#        [0.83044851, 0.40357936],
#        [0.77145882, 0.49961584],
#        [0.72536202, 0.36166757],
#        [0.7296009 , 0.61552094],
#        [0.75538669, 0.2982404 ],
#        [0.78700111, 0.40464824],
#        [0.62062858, 0.58594933],
#        [0.63793714, 0.38199458],
#        [0.6057929 , 0.37723377],
#        [0.54097485, 0.38551411],
#        [0.59590244, 0.53524915],
#        [0.53797241, 0.5662325 ],
#        [0.50883087, 0.45071919],
#        [0.50565164, 0.60310632],
#        [0.5203108 , 0.53607708],
#        [0.59307652, 0.42708277],
#        [0.59855157, 0.50275851],
#        [0.50830077, 0.5328939 ],
#        [0.50582816, 0.44254077],
#        [0.44507247, 0.46123166],
#        [0.41151526, 0.76835701],
#        [0.48375116, 0.3494082 ],
#        [0.55333791, 0.43770553],
#        [0.46573651, 0.37723377],
#        [0.44471916, 0.48854481],
#        [0.41769693, 0.42298648],
#        [0.4720947 , 0.33482929],
#        [0.38202042, 0.54358359],
#        [0.35482167, 0.24751897],
#        [0.26969262, 0.29818303],
#        [0.21547164, 0.43384311],
#        [0.33592363, 0.6150175 ],
#        [0.31896864, 0.31529618],
#        [0.34969965, 0.37182149],
#        [0.29194614, 0.35356027],
#        [0.25450363, 0.32299415],
#        [0.24531952, 0.57721528],
#        [0.23172028, 0.45664363],
#        [0.15860125, 0.37723377],
#        [0.32320725, 0.4254695 ],
#        [0.26598383, 0.40410273],
#        [0.34404808, 0.37727116],
#        [0.27693394, 0.53595885],
#        [0.3004239 , 0.32426851],
#        [0.2977745 , 0.68237854],
#        [0.37407275, 0.73980436],
#        [0.42529129, 0.58410793],
#        [0.44065707, 0.42492977],
#        [0.38961505, 0.84944543],
#        [0.39191087, 0.29827863],
#        [0.47951254, 0.45648467],
#        [0.51342279, 0.39943316],
#        [0.40515708, 0.32280049],
#        [0.28346864, 0.38064442],
#        [0.28399847, 0.70290292],
#        [0.19604376, 0.22005776],
#        [0.25432711, 0.39668778],
#        [0.22059338, 0.57808839],
#        [0.26898627, 0.37727336],
#        [0.34987644, 0.5348418 ],
#        [0.40551038, 0.35615128],
#        [0.46291059, 0.52123818],
#        [0.40833631, 0.61478448],
#        [0.36064976, 0.45664754],
#        [0.46450007, 0.45560216],
#        [0.42652773, 0.10912391],
#        [0.3906747 , 0.44718176],
#        [0.41398788, 0.45411977],
#        [0.39385366, 0.61541099],
#        [0.33786641, 0.44029331],
#        [0.32285394, 0.30562865],
#        [0.27181192, 0.42444172],
#        [0.39208766, 0.31405665],
#        [0.35234906, 0.52866563],
#        [0.38431652, 0.51401784],
#        [0.37195345, 0.45116196],
#        [0.28576474, 0.52712968],
#        [0.28876718, 0.3505548 ],
#        [0.28841387, 0.57723884],
#        [0.29477206, 0.26089902],
#        [0.41487101, 0.57217152],
#        [0.34157547, 0.37723377],
#        [0.26669018, 0.59414193],
#        [0.18862592, 0.45396339],
#        [0.16072056, 0.47350559],
#        [0.09501937, 0.50362274],
#        [0.12310126, 0.37723377],
#        [0.14729784, 0.4989553 ],
#        [0.0867184 , 0.44824892],
#        [0.09484286, 0.45918722],
#        [0.0646414 , 0.09659888],
#        [0.0349699 , 0.38791553],
#        [0.04238787, 0.38261794],
#        [0.07541498, 0.49637031],
#        [0.01554216, 0.60763115],
#        [0.01978091, 0.56263003],
#        [0.        , 0.534547  ],
#        [0.07877073, 0.37723377],
#        [0.07506168, 0.8077957 ],
#        [0.09254676, 0.57813412],
#        [0.13899686, 0.38808402],
#        [0.10632279, 0.57169733],
#        [0.15577533, 0.44520381],
#        [0.19092202, 0.60624944],
#        [0.14252913, 0.29787323],
#        [0.163723  , 0.49706145],
#        [0.21388189, 0.58616364],
#        [0.25256084, 0.44346361],
#        [0.2628046 , 0.37625501],
#        [0.30307303, 0.42405442],
#        [0.30289652, 0.52717183],
#        [0.33468745, 0.3031782 ],
#        [0.29477206, 0.27619381],
#        [0.31720237, 0.444904  ],
#        [0.40427394, 0.09259435],
#        [0.38890843, 0.37508385],
#        [0.46909226, 0.4593305 ],
#        [0.43500523, 0.59711153],
#        [0.49222892, 0.50871782],
#        [0.49046265, 0.47856758],
#        [0.41416467, 0.31397098],
#        [0.44048028, 0.4560843 ],
#        [0.46114433, 0.57103902],
#        [0.47862941, 0.39905015],
#        [0.48569394, 0.25264035],
#        [0.46520669, 0.53463535],
#        [0.42723408, 0.46035121],
#        [0.40374412, 0.29782888],
#        [0.42529129, 0.29920825],
#        [0.37265979, 0.45667137]])

# %%
train_data_scaled.shape,test_data_scaled.shape
# Out:
# ((383, 2), (96, 2))

# %%
def create_sequences(data, window_size):
    X, y = [], []
    for i in range(len(data) - window_size):
        X.append(data[i:(i + window_size)])
        y.append(data[i + window_size])
    return np.array(X), np.array(y)

# %%
X_train, y_train = create_sequences(train_data_scaled, window_size=5)
X_test, y_test = create_sequences(test_data_scaled, window_size=5)

# %%
X_train.shape,y_train.shape
# Out:
# ((378, 5, 2), (378, 2))

# %%
from keras.models import Sequential
from keras.layers import Dense, GRU, Dropout, BatchNormalization, Conv1D

# Assuming each data point has 5 time steps and 2 features (open and score)
n_steps = 5
n_features = 2
input_shape=(n_steps, n_features)

# Define the model
model = Sequential()

# One-dimensional convolutional layer with 64 filters of size 1 with a stride of 1
model.add(Conv1D(filters=64, kernel_size=1, activation='relu', input_shape=input_shape))

# GRU layer with 50 units
model.add(GRU(50, activation='relu', return_sequences=True))

# Another GRU layer with 50 units
model.add(GRU(50, activation='relu', return_sequences=True))

# Another GRU layer with 50 units
model.add(GRU(50, activation='relu'))

# Dense layer with 64 units and the ReLU activation
model.add(Dense(64, activation='relu'))

# Dense layer with 2 units (for 'Open' and 'Score')
model.add(Dense(2))

# Compile the model
model.compile(optimizer='adam', loss='mse')

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 5, 64)             192
#
#  gru (GRU)                   (None, 5, 50)             17400
#
#  gru_1 (GRU)                 (None, 5, 50)             15300
#
#  gru_2 (GRU)                 (None, 50)                15300
#
#  dense (Dense)               (None, 64)                3264
#
#  dense_1 (Dense)             (None, 2)                 130
#
# =================================================================
# Total params: 51,586
# Trainable params: 51,586
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Train the model
model.fit(X_train, y_train, epochs=200, verbose=1)
# Out:
# Epoch 1/200
# 12/12 [==============================] - 2s 5ms/step - loss: 0.2272
# Epoch 2/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0857
# Epoch 3/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0369
# Epoch 4/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0258
# Epoch 5/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0213
# Epoch 6/200
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0179
# Epoch 7/200
# 12/12 [==============================] - 0s 12ms/step - loss: 0.0152
# Epoch 8/200
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0142
# Epoch 9/200
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0138
# Epoch 10/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0137
# Epoch 11/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0136
# Epoch 12/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0136
# Epoch 13/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0137
# Epoch 14/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0131
# Epoch 15/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0134
# Epoch 16/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0137
# Epoch 17/200
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0132
# Epoch 18/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0134
# Epoch 19/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0131
# Epoch 20/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0128
# Epoch 21/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0129
# Epoch 22/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0130
# Epoch 23/200
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0132
# Epoch 24/200
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0126
# Epoch 25/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0126
# Epoch 26/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0124
# Epoch 27/200
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0122
# Epoch 28/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0123
# Epoch 29/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0125
# Epoch 30/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0123
# Epoch 31/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0123
# Epoch 32/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0127
# Epoch 33/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0122
# Epoch 34/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0121
# Epoch 35/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0122
# Epoch 36/200
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0119
# Epoch 37/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0117
# Epoch 38/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0119
# Epoch 39/200
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0119
# Epoch 40/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0118
# Epoch 41/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0125
# Epoch 42/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0119
# Epoch 43/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0122
# Epoch 44/200
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0123
# Epoch 45/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0118
# Epoch 46/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0116
# Epoch 47/200
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0115
# Epoch 48/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0116
# Epoch 49/200
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0116
# Epoch 50/200
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0115
# Epoch 51/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0117
# Epoch 52/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0123
# Epoch 53/200
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0116
# Epoch 54/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0116
# Epoch 55/200
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0117
# Epoch 56/200
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0117
# Epoch 57/200
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0127
# Epoch 58/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0122
# Epoch 59/200
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0116
# Epoch 60/200
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0119
# Epoch 61/200
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0115
# Epoch 62/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0118
# Epoch 63/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0113
# Epoch 64/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0114
# Epoch 65/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0117
# Epoch 66/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0119
# Epoch 67/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0115
# Epoch 68/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0116
# Epoch 69/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0114
# Epoch 70/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0115
# Epoch 71/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0114
# Epoch 72/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0118
# Epoch 73/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0114
# Epoch 74/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0118
# Epoch 75/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0116
# Epoch 76/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0118
# Epoch 77/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0118
# Epoch 78/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0119
# Epoch 79/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0122
# Epoch 80/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0123
# Epoch 81/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0114
# Epoch 82/200
# 12/12 [==============================] - 0s 9ms/step - loss: 0.0114
# Epoch 83/200
# 12/12 [==============================] - 0s 9ms/step - loss: 0.0114
# Epoch 84/200
# 12/12 [==============================] - 0s 9ms/step - loss: 0.0116
# Epoch 85/200
# 12/12 [==============================] - 0s 10ms/step - loss: 0.0114
# Epoch 86/200
# 12/12 [==============================] - 0s 14ms/step - loss: 0.0113
# Epoch 87/200
# 12/12 [==============================] - 0s 13ms/step - loss: 0.0114
# Epoch 88/200
# 12/12 [==============================] - 0s 10ms/step - loss: 0.0113
# Epoch 89/200
# 12/12 [==============================] - 0s 9ms/step - loss: 0.0112
# Epoch 90/200
# 12/12 [==============================] - 0s 10ms/step - loss: 0.0121
# Epoch 91/200
# 12/12 [==============================] - 0s 9ms/step - loss: 0.0116
# Epoch 92/200
# 12/12 [==============================] - 0s 9ms/step - loss: 0.0118
# Epoch 93/200
# 12/12 [==============================] - 0s 9ms/step - loss: 0.0115
# Epoch 94/200
# 12/12 [==============================] - 0s 10ms/step - loss: 0.0114
# Epoch 95/200
# 12/12 [==============================] - 0s 9ms/step - loss: 0.0117
# Epoch 96/200
# 12/12 [==============================] - 0s 9ms/step - loss: 0.0116
# Epoch 97/200
# 12/12 [==============================] - 0s 9ms/step - loss: 0.0115
# Epoch 98/200
# 12/12 [==============================] - 0s 11ms/step - loss: 0.0115
# Epoch 99/200
# 12/12 [==============================] - 0s 13ms/step - loss: 0.0118
# Epoch 100/200
# 12/12 [==============================] - 0s 12ms/step - loss: 0.0114
# Epoch 101/200
# 12/12 [==============================] - 0s 11ms/step - loss: 0.0112
# Epoch 102/200
# 12/12 [==============================] - 0s 11ms/step - loss: 0.0112
# Epoch 103/200
# 12/12 [==============================] - 0s 11ms/step - loss: 0.0114
# Epoch 104/200
# 12/12 [==============================] - 0s 11ms/step - loss: 0.0121
# Epoch 105/200
# 12/12 [==============================] - 0s 12ms/step - loss: 0.0121
# Epoch 106/200
# 12/12 [==============================] - 0s 12ms/step - loss: 0.0120
# Epoch 107/200
# 12/12 [==============================] - 0s 10ms/step - loss: 0.0118
# Epoch 108/200
# 12/12 [==============================] - 0s 10ms/step - loss: 0.0114
# Epoch 109/200
# 12/12 [==============================] - 0s 10ms/step - loss: 0.0113
# Epoch 110/200
# 12/12 [==============================] - 0s 9ms/step - loss: 0.0114
# Epoch 111/200
# 12/12 [==============================] - 0s 9ms/step - loss: 0.0112
# Epoch 112/200
# 12/12 [==============================] - 0s 9ms/step - loss: 0.0111
# Epoch 113/200
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0116
# Epoch 114/200
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0115
# Epoch 115/200
# 12/12 [==============================] - 0s 9ms/step - loss: 0.0115
# Epoch 116/200
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0115
# Epoch 117/200
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0118
# Epoch 118/200
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0117
# Epoch 119/200
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0118
# Epoch 120/200
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0115
# Epoch 121/200
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0115
# Epoch 122/200
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0113
# Epoch 123/200
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0117
# Epoch 124/200
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0120
# Epoch 125/200
# 12/12 [==============================] - 0s 9ms/step - loss: 0.0116
# Epoch 126/200
# 12/12 [==============================] - 0s 11ms/step - loss: 0.0114
# Epoch 127/200
# 12/12 [==============================] - 0s 11ms/step - loss: 0.0114
# Epoch 128/200
# 12/12 [==============================] - 0s 9ms/step - loss: 0.0116
# Epoch 129/200
# 12/12 [==============================] - 0s 9ms/step - loss: 0.0116
# Epoch 130/200
# 12/12 [==============================] - 0s 9ms/step - loss: 0.0112
# Epoch 131/200
# 12/12 [==============================] - 0s 9ms/step - loss: 0.0112
# Epoch 132/200
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0114
# Epoch 133/200
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0114
# Epoch 134/200
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0113
# Epoch 135/200
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0111
# Epoch 136/200
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0114
# Epoch 137/200
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0110
# Epoch 138/200
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0116
# Epoch 139/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0112
# Epoch 140/200
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0114
# Epoch 141/200
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0114
# Epoch 142/200
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0113
# Epoch 143/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0113
# Epoch 144/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0112
# Epoch 145/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0112
# Epoch 146/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0113
# Epoch 147/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0114
# Epoch 148/200
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0112
# Epoch 149/200
# 12/12 [==============================] - 0s 10ms/step - loss: 0.0114
# Epoch 150/200
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0114
# Epoch 151/200
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0110
# Epoch 152/200
# 12/12 [==============================] - 0s 9ms/step - loss: 0.0113
# Epoch 153/200
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0114
# Epoch 154/200
# 12/12 [==============================] - 0s 10ms/step - loss: 0.0111
# Epoch 155/200
# 12/12 [==============================] - 0s 9ms/step - loss: 0.0109
# Epoch 156/200
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0110
# Epoch 157/200
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0110
# Epoch 158/200
# 12/12 [==============================] - 0s 9ms/step - loss: 0.0112
# Epoch 159/200
# 12/12 [==============================] - 0s 9ms/step - loss: 0.0115
# Epoch 160/200
# 12/12 [==============================] - 0s 10ms/step - loss: 0.0113
# Epoch 161/200
# 12/12 [==============================] - 0s 9ms/step - loss: 0.0112
# Epoch 162/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0111
# Epoch 163/200
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0112
# Epoch 164/200
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0112
# Epoch 165/200
# 12/12 [==============================] - 0s 10ms/step - loss: 0.0110
# Epoch 166/200
# 12/12 [==============================] - 0s 9ms/step - loss: 0.0109
# Epoch 167/200
# 12/12 [==============================] - 0s 12ms/step - loss: 0.0110
# Epoch 168/200
# 12/12 [==============================] - 0s 11ms/step - loss: 0.0113
# Epoch 169/200
# 12/12 [==============================] - 0s 9ms/step - loss: 0.0111
# Epoch 170/200
# 12/12 [==============================] - 0s 10ms/step - loss: 0.0109
# Epoch 171/200
# 12/12 [==============================] - 0s 9ms/step - loss: 0.0109
# Epoch 172/200
# 12/12 [==============================] - 0s 10ms/step - loss: 0.0109
# Epoch 173/200
# 12/12 [==============================] - 0s 9ms/step - loss: 0.0111
# Epoch 174/200
# 12/12 [==============================] - 0s 9ms/step - loss: 0.0112
# Epoch 175/200
# 12/12 [==============================] - 0s 9ms/step - loss: 0.0109
# Epoch 176/200
# 12/12 [==============================] - 0s 10ms/step - loss: 0.0111
# Epoch 177/200
# 12/12 [==============================] - 0s 13ms/step - loss: 0.0110
# Epoch 178/200
# 12/12 [==============================] - 0s 9ms/step - loss: 0.0109
# Epoch 179/200
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0111
# Epoch 180/200
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0112
# Epoch 181/200
# 12/12 [==============================] - 0s 9ms/step - loss: 0.0109
# Epoch 182/200
# 12/12 [==============================] - 0s 9ms/step - loss: 0.0112
# Epoch 183/200
# 12/12 [==============================] - 0s 9ms/step - loss: 0.0110
# Epoch 184/200
# 12/12 [==============================] - 0s 10ms/step - loss: 0.0108
# Epoch 185/200
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0109
# Epoch 186/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0114
# Epoch 187/200
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0109
# Epoch 188/200
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0112
# Epoch 189/200
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0112
# Epoch 190/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0116
# Epoch 191/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0111
# Epoch 192/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0114
# Epoch 193/200
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0111
# Epoch 194/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0108
# Epoch 195/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0110
# Epoch 196/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0119
# Epoch 197/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0110
# Epoch 198/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0108
# Epoch 199/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0108
# Epoch 200/200
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0111

# %%
### Lets Do the prediction and check performance metrics
train_predict=model.predict(X_train)
test_predict=model.predict(X_test)
# Out:
# 12/12 [==============================] - 0s 3ms/step
# 3/3 [==============================] - 0s 4ms/step

# %%
##Transformback to original form
train_predict=scaler.inverse_transform(train_predict)
test_predict=scaler.inverse_transform(test_predict)

# %%
train_predict
# Out:
# array([[ 1.50003860e+02,  9.54228044e-02],
#        [ 1.50102875e+02,  9.73727927e-02],
#        [ 1.49124252e+02,  1.12355113e-01],
#        [ 1.47086853e+02,  1.16244279e-01],
#        [ 1.49480896e+02,  1.05507374e-01],
#        [ 1.51577286e+02,  9.00858194e-02],
#        [ 1.50452698e+02,  8.85199979e-02],
#        [ 1.51703171e+02,  6.31779060e-02],
#        [ 1.52264664e+02,  6.42176718e-02],
#        [ 1.52288818e+02,  6.05879948e-02],
#        [ 1.54456482e+02,  6.02786243e-02],
#        [ 1.53743790e+02,  6.27380461e-02],
#        [ 1.53821533e+02,  6.25192225e-02],
#        [ 1.50278656e+02,  7.43545219e-02],
#        [ 1.51038879e+02,  8.21495876e-02],
#        [ 1.48980438e+02,  9.57193449e-02],
#        [ 1.48647507e+02,  9.53013524e-02],
#        [ 1.48106659e+02,  9.98883992e-02],
#        [ 1.43668182e+02,  9.74924415e-02],
#        [ 1.44983368e+02,  8.41381252e-02],
#        [ 1.44332413e+02,  8.80846009e-02],
#        [ 1.45482513e+02,  8.22573081e-02],
#        [ 1.45884079e+02,  8.77724960e-02],
#        [ 1.44743637e+02,  9.48928893e-02],
#        [ 1.44514847e+02,  1.12329163e-01],
#        [ 1.43609543e+02,  1.21398821e-01],
#        [ 1.43513443e+02,  1.20982334e-01],
#        [ 1.42500000e+02,  1.04990430e-01],
#        [ 1.41241180e+02,  7.63336122e-02],
#        [ 1.40018097e+02,  8.31759647e-02],
#        [ 1.39007309e+02,  8.62772241e-02],
#        [ 1.44066055e+02,  9.30268094e-02],
#        [ 1.44621307e+02,  1.08887956e-01],
#        [ 1.41931488e+02,  1.16656944e-01],
#        [ 1.42710220e+02,  1.36834398e-01],
#        [ 1.42112213e+02,  1.43547937e-01],
#        [ 1.43224396e+02,  1.42055705e-01],
#        [ 1.45688095e+02,  1.28689468e-01],
#        [ 1.44327850e+02,  1.14366762e-01],
#        [ 1.47216339e+02,  1.11914657e-01],
#        [ 1.48082336e+02,  9.75579321e-02],
#        [ 1.47264008e+02,  8.70844796e-02],
#        [ 1.48691620e+02,  8.02305117e-02],
#        [ 1.48100479e+02,  7.10568652e-02],
#        [ 1.49250748e+02,  7.43770301e-02],
#        [ 1.49825775e+02,  8.60115141e-02],
#        [ 1.48905975e+02,  1.01079136e-01],
#        [ 1.45912659e+02,  9.93269756e-02],
#        [ 1.48385651e+02,  8.27138573e-02],
#        [ 1.48035599e+02,  6.79834336e-02],
#        [ 1.48856354e+02,  6.21004030e-02],
#        [ 1.49890060e+02,  6.34846091e-02],
#        [ 1.50098877e+02,  6.70427606e-02],
#        [ 1.49985596e+02,  6.66671172e-02],
#        [ 1.49293243e+02,  6.91139773e-02],
#        [ 1.50517120e+02,  7.31169730e-02],
#        [ 1.48355865e+02,  8.91944021e-02],
#        [ 1.47472137e+02,  8.59998912e-02],
#        [ 1.50556946e+02,  8.41208696e-02],
#        [ 1.50238297e+02,  8.68453309e-02],
#        [ 1.49816238e+02,  8.43665153e-02],
#        [ 1.52139633e+02,  7.92879984e-02],
#        [ 1.55987244e+02,  7.44446591e-02],
#        [ 1.59346497e+02,  5.81221953e-02],
#        [ 1.60771942e+02,  7.56706148e-02],
#        [ 1.60240646e+02,  1.03335373e-01],
#        [ 1.59011597e+02,  1.08759791e-01],
#        [ 1.59360870e+02,  1.07148886e-01],
#        [ 1.59483780e+02,  1.01277404e-01],
#        [ 1.65051605e+02,  4.69315127e-02],
#        [ 1.59201431e+02,  1.06299020e-01],
#        [ 1.62733963e+02,  8.24443251e-02],
#        [ 1.63713226e+02,  6.52695596e-02],
#        [ 1.67624298e+02,  2.52404455e-02],
#        [ 1.70438797e+02,  1.37049844e-02],
#        [ 1.72298859e+02,  9.68371797e-03],
#        [ 1.72904678e+02,  1.49613637e-02],
#        [ 1.74871277e+02, -2.48874072e-02],
#        [ 1.73664642e+02, -3.50999124e-02],
#        [ 1.74654465e+02,  3.13254967e-02],
#        [ 1.75821060e+02,  1.02326289e-01],
#        [ 1.67317703e+02,  2.08956003e-01],
#        [ 1.67914017e+02,  1.74336642e-01],
#        [ 1.71814789e+02,  2.32319869e-02],
#        [ 1.71619919e+02, -4.37642157e-04],
#        [ 1.73186386e+02,  7.18168728e-03],
#        [ 1.74927017e+02,  3.28673907e-02],
#        [ 1.76936584e+02,  6.88342098e-03],
#        [ 1.76921463e+02,  2.66225524e-02],
#        [ 1.78190613e+02,  7.67113194e-02],
#        [ 1.73888550e+02,  1.78636074e-01],
#        [ 1.77961075e+02,  9.79612172e-02],
#        [ 1.79148849e+02, -1.04664695e-02],
#        [ 1.76471817e+02, -9.56653152e-03],
#        [ 1.70527252e+02,  7.62226656e-02],
#        [ 1.71307480e+02,  5.34194037e-02],
#        [ 1.67541565e+02,  7.20911995e-02],
#        [ 1.70936783e+02, -7.88582023e-03],
#        [ 1.72549911e+02, -2.19740979e-02],
#        [ 1.72907730e+02, -1.85912233e-02],
#        [ 1.71275024e+02, -5.03252447e-03],
#        [ 1.70125977e+02,  2.42046900e-02],
#        [ 1.67783844e+02,  5.43450341e-02],
#        [ 1.65925385e+02,  7.38343596e-02],
#        [ 1.63246704e+02,  7.69964606e-02],
#        [ 1.59347610e+02,  9.74125862e-02],
#        [ 1.59181763e+02,  9.55564901e-02],
#        [ 1.62880325e+02,  7.54584670e-02],
#        [ 1.63131638e+02,  1.08897746e-01],
#        [ 1.66609604e+02,  9.43752751e-02],
#        [ 1.69641006e+02,  5.37654534e-02],
#        [ 1.72499802e+02,  1.42453676e-02],
#        [ 1.73617462e+02,  5.90707064e-02],
#        [ 1.74313614e+02,  4.54528965e-02],
#        [ 1.71452667e+02,  1.35861963e-01],
#        [ 1.73017410e+02,  9.55757648e-02],
#        [ 1.71277557e+02,  1.11958802e-01],
#        [ 1.75378876e+02,  1.62944850e-02],
#        [ 1.72960052e+02,  1.38158966e-02],
#        [ 1.70406143e+02,  6.43858239e-02],
#        [ 1.66522186e+02,  1.23813875e-01],
#        [ 1.70239532e+02,  8.29644874e-02],
#        [ 1.71471039e+02,  8.50806420e-04],
#        [ 1.69992767e+02, -1.02115911e-03],
#        [ 1.68775543e+02,  4.40183915e-02],
#        [ 1.63458069e+02,  1.35499552e-01],
#        [ 1.64201019e+02,  1.15149520e-01],
#        [ 1.53614075e+02,  1.19633235e-01],
#        [ 1.62616348e+02,  5.71607091e-02],
#        [ 1.62665436e+02,  6.82354197e-02],
#        [ 1.62999939e+02,  6.63240701e-02],
#        [ 1.63763733e+02,  3.79344635e-02],
#        [ 1.66032089e+02,  3.43231694e-03],
#        [ 1.63461334e+02,  6.07060306e-02],
#        [ 1.62564590e+02,  8.28203112e-02],
#        [ 1.59129074e+02,  1.07175291e-01],
#        [ 1.60953400e+02,  9.49439034e-02],
#        [ 1.59695724e+02,  1.05879903e-01],
#        [ 1.57679642e+02,  1.04886718e-01],
#        [ 1.51735153e+02,  9.61632952e-02],
#        [ 1.50587769e+02,  9.05955955e-02],
#        [ 1.56232620e+02,  7.30733871e-02],
#        [ 1.57501266e+02,  8.85029361e-02],
#        [ 1.59663742e+02,  8.36086571e-02],
#        [ 1.61808502e+02,  6.36422560e-02],
#        [ 1.65745575e+02,  7.74531662e-02],
#        [ 1.67242935e+02,  1.10372953e-01],
#        [ 1.69155640e+02,  9.79901776e-02],
#        [ 1.72042603e+02,  3.06711271e-02],
#        [ 1.70899963e+02,  2.01853365e-02],
#        [ 1.72736099e+02, -8.70826561e-03],
#        [ 1.75427475e+02,  1.94315314e-02],
#        [ 1.74626099e+02,  4.76005860e-02],
#        [ 1.74150223e+02,  3.45037282e-02],
#        [ 1.75395630e+02, -2.21651210e-03],
#        [ 1.75486801e+02,  3.87661345e-02],
#        [ 1.70041992e+02,  1.62783176e-01],
#        [ 1.69044525e+02,  1.64988965e-01],
#        [ 1.70999069e+02,  6.77578598e-02],
#        [ 1.69287521e+02,  1.49843190e-02],
#        [ 1.68329926e+02,  3.64315137e-03],
#        [ 1.66313690e+02,  4.32975180e-02],
#        [ 1.68130112e+02,  3.00520882e-02],
#        [ 1.64114151e+02,  7.49205276e-02],
#        [ 1.64415359e+02,  4.53507602e-02],
#        [ 1.66605545e+02, -3.95926135e-03],
#        [ 1.67972717e+02, -1.31752081e-02],
#        [ 1.65879623e+02,  3.53821740e-02],
#        [ 1.60034729e+02,  1.10322163e-01],
#        [ 1.60889099e+02,  9.66825634e-02],
#        [ 1.55703720e+02,  9.44654793e-02],
#        [ 1.58161896e+02,  7.75332823e-02],
#        [ 1.60286606e+02,  8.09805989e-02],
#        [ 1.56731140e+02,  1.01866812e-01],
#        [ 1.57309998e+02,  1.00966915e-01],
#        [ 1.58733597e+02,  9.96994302e-02],
#        [ 1.62847595e+02,  7.62959570e-02],
#        [ 1.56266418e+02,  9.84948128e-02],
#        [ 1.53592789e+02,  8.51663798e-02],
#        [ 1.54059967e+02,  8.03960711e-02],
#        [ 1.52236298e+02,  7.20645264e-02],
#        [ 1.43024887e+02,  8.19965899e-02],
#        [ 1.43723602e+02,  7.63456151e-02],
#        [ 1.46660202e+02,  7.13619590e-02],
#        [ 1.47989090e+02,  7.02420399e-02],
#        [ 1.45300888e+02,  6.87547550e-02],
#        [ 1.39239395e+02,  8.58910009e-02],
#        [ 1.39480072e+02,  8.90904665e-02],
#        [ 1.37411545e+02,  9.11366194e-02],
#        [ 1.41796509e+02,  1.06371112e-01],
#        [ 1.39236084e+02,  1.20875955e-01],
#        [ 1.37477097e+02,  1.05432354e-01],
#        [ 1.44996124e+02,  1.02135181e-01],
#        [ 1.49216080e+02,  9.02270004e-02],
#        [ 1.48810974e+02,  9.65753645e-02],
#        [ 1.47711441e+02,  9.96363387e-02],
#        [ 1.47048019e+02,  9.71793234e-02],
#        [ 1.46788651e+02,  9.86525714e-02],
#        [ 1.45207138e+02,  8.93521979e-02],
#        [ 1.47931473e+02,  8.18431452e-02],
#        [ 1.46230286e+02,  7.69131184e-02],
#        [ 1.40131134e+02,  8.48316178e-02],
#        [ 1.33101425e+02,  6.46878406e-02],
#        [ 1.32831482e+02, -4.46581142e-03],
#        [ 1.34697891e+02,  7.51395375e-02],
#        [ 1.32281799e+02,  2.63189599e-02],
#        [ 1.30795380e+02, -1.83339156e-02],
#        [ 1.32349960e+02,  1.39888478e-02],
#        [ 1.34951584e+02,  1.01781368e-01],
#        [ 1.37562378e+02,  1.26684457e-01],
#        [ 1.40021667e+02,  1.10543050e-01],
#        [ 1.43156372e+02,  1.08313590e-01],
#        [ 1.42533279e+02,  1.06570922e-01],
#        [ 1.37423462e+02,  1.06396392e-01],
#        [ 1.37172440e+02,  1.06065944e-01],
#        [ 1.36703445e+02,  1.11252524e-01],
#        [ 1.37642670e+02,  1.17082857e-01],
#        [ 1.42633102e+02,  1.23276338e-01],
#        [ 1.44229004e+02,  1.28566295e-01],
#        [ 1.46358078e+02,  1.21589363e-01],
#        [ 1.46739777e+02,  1.22814238e-01],
#        [ 1.44832794e+02,  1.08988665e-01],
#        [ 1.43594040e+02,  1.00755364e-01],
#        [ 1.44004425e+02,  8.70955810e-02],
#        [ 1.49569611e+02,  7.53077641e-02],
#        [ 1.49474426e+02,  8.56870711e-02],
#        [ 1.47372604e+02,  9.76475775e-02],
#        [ 1.51772293e+02,  8.72623473e-02],
#        [ 1.53748276e+02,  9.54583660e-02],
#        [ 1.53433640e+02,  9.09557119e-02],
#        [ 1.53611465e+02,  9.43524316e-02],
#        [ 1.51356079e+02,  8.86740088e-02],
#        [ 1.51731964e+02,  8.06042403e-02],
#        [ 1.55743835e+02,  7.86967203e-02],
#        [ 1.59332947e+02,  6.69687614e-02],
#        [ 1.59860275e+02,  8.07505995e-02],
#        [ 1.59757019e+02,  9.67158675e-02],
#        [ 1.60767227e+02,  1.08876593e-01],
#        [ 1.64666245e+02,  7.31961206e-02],
#        [ 1.63465332e+02,  8.14326480e-02],
#        [ 1.65803528e+02,  3.90153788e-02],
#        [ 1.64062698e+02,  5.69978468e-02],
#        [ 1.66379761e+02,  1.96655840e-02],
#        [ 1.67970306e+02,  1.16385089e-03],
#        [ 1.68027954e+02,  1.07268235e-02],
#        [ 1.69136765e+02, -2.08752090e-03],
#        [ 1.71033325e+02, -2.93024387e-02],
#        [ 1.72468018e+02,  3.07436679e-02],
#        [ 1.72240158e+02,  1.23350419e-01],
#        [ 1.69982986e+02,  1.89500287e-01],
#        [ 1.68525604e+02,  1.90875113e-01],
#        [ 1.65854919e+02,  1.54746130e-01],
#        [ 1.66595612e+02,  2.68910378e-02],
#        [ 1.68119797e+02,  3.45023386e-02],
#        [ 1.68039246e+02,  4.66639288e-02],
#        [ 1.61304581e+02,  1.22722566e-01],
#        [ 1.61427750e+02,  1.07840054e-01],
#        [ 1.58759918e+02,  9.97478515e-02],
#        [ 1.55482971e+02,  9.06532854e-02],
#        [ 1.58441727e+02,  7.31923655e-02],
#        [ 1.55951126e+02,  7.96780884e-02],
#        [ 1.53970901e+02,  8.31554085e-02],
#        [ 1.53611038e+02,  8.30782503e-02],
#        [ 1.55190613e+02,  8.69829804e-02],
#        [ 1.58454056e+02,  8.81114602e-02],
#        [ 1.58796112e+02,  8.66051987e-02],
#        [ 1.54175018e+02,  9.32086930e-02],
#        [ 1.53732040e+02,  8.30004588e-02],
#        [ 1.50524033e+02,  8.01830962e-02],
#        [ 1.50088882e+02,  8.42931867e-02],
#        [ 1.52941040e+02,  8.67720395e-02],
#        [ 1.55564316e+02,  8.67319405e-02],
#        [ 1.51212463e+02,  8.67544860e-02],
#        [ 1.49825745e+02,  7.63672963e-02],
#        [ 1.49033096e+02,  6.36062920e-02],
#        [ 1.51185272e+02,  6.47115856e-02],
#        [ 1.47423279e+02,  7.29807466e-02],
#        [ 1.45130966e+02,  7.76480213e-02],
#        [ 1.41171967e+02,  8.03606659e-02],
#        [ 1.38451370e+02,  7.40566328e-02],
#        [ 1.45271606e+02,  6.17506020e-02],
#        [ 1.43619003e+02,  7.54411444e-02],
#        [ 1.43972916e+02,  8.02047029e-02],
#        [ 1.42389969e+02,  8.07298943e-02],
#        [ 1.40541443e+02,  7.50134736e-02],
#        [ 1.39149353e+02,  6.58659413e-02],
#        [ 1.39419083e+02,  7.44433105e-02],
#        [ 1.35496918e+02,  8.16100314e-02],
#        [ 1.43898926e+02,  8.40656608e-02],
#        [ 1.42417831e+02,  9.39540565e-02],
#        [ 1.43925171e+02,  7.77403638e-02],
#        [ 1.41532028e+02,  7.99192637e-02],
#        [ 1.42240707e+02,  7.91262984e-02],
#        [ 1.42240677e+02,  8.46929103e-02],
#        [ 1.48087219e+02,  8.76761377e-02],
#        [ 1.50484558e+02,  1.05005808e-01],
#        [ 1.49857208e+02,  1.08721383e-01],
#        [ 1.48119705e+02,  1.19409718e-01],
#        [ 1.47876297e+02,  1.17378496e-01],
#        [ 1.51805176e+02,  9.74644572e-02],
#        [ 1.53988129e+02,  8.34866837e-02],
#        [ 1.47797073e+02,  8.75909179e-02],
#        [ 1.42573608e+02,  6.57814741e-02],
#        [ 1.41731522e+02,  7.03495741e-02],
#        [ 1.38174240e+02,  8.85215402e-02],
#        [ 1.40588318e+02,  9.21248496e-02],
#        [ 1.38591309e+02,  9.42208171e-02],
#        [ 1.41609268e+02,  9.14549157e-02],
#        [ 1.45588974e+02,  7.57168308e-02],
#        [ 1.47693573e+02,  8.53640512e-02],
#        [ 1.49991699e+02,  8.07854831e-02],
#        [ 1.48954941e+02,  7.80043453e-02],
#        [ 1.46562424e+02,  8.74906182e-02],
#        [ 1.51066162e+02,  7.52701759e-02],
#        [ 1.49442474e+02,  9.76202711e-02],
#        [ 1.47760727e+02,  1.01524509e-01],
#        [ 1.48772827e+02,  8.21775272e-02],
#        [ 1.49078888e+02,  8.04156885e-02],
#        [ 1.45790741e+02,  8.45729262e-02],
#        [ 1.43302002e+02,  9.03420076e-02],
#        [ 1.42306000e+02,  8.69920626e-02],
#        [ 1.46678772e+02,  7.08822310e-02],
#        [ 1.45657318e+02,  6.77344576e-02],
#        [ 1.46998260e+02,  6.54435232e-02],
#        [ 1.46527039e+02,  7.59629533e-02],
#        [ 1.42666794e+02,  8.55701566e-02],
#        [ 1.42428284e+02,  9.16338637e-02],
#        [ 1.42702377e+02,  8.86544660e-02],
#        [ 1.42011169e+02,  9.02120769e-02],
#        [ 1.48562775e+02,  7.95171037e-02],
#        [ 1.45260193e+02,  8.20446014e-02],
#        [ 1.40386581e+02,  8.99089724e-02],
#        [ 1.36970871e+02,  8.57198909e-02],
#        [ 1.35463654e+02,  9.57056209e-02],
#        [ 1.31938339e+02, -1.75620988e-03],
#        [ 1.32631317e+02,  5.34677971e-03],
#        [ 1.34088776e+02,  6.00322336e-02],
#        [ 1.31253586e+02, -1.05661657e-02],
#        [ 1.30603043e+02, -4.57104556e-02],
#        [ 1.29627594e+02, -1.65981427e-02],
#        [ 1.28039948e+02,  1.90952308e-02],
#        [ 1.28041107e+02,  1.21785082e-01],
#        [ 1.29312851e+02,  2.16348067e-01],
#        [ 1.28041199e+02,  9.67587382e-02],
#        [ 1.27703194e+02,  1.01721279e-01],
#        [ 1.27443321e+02,  1.50259688e-01],
#        [ 1.30172134e+02,  3.25740218e-01],
#        [ 1.31797775e+02,  2.08275527e-01],
#        [ 1.32505127e+02,  9.03225392e-02],
#        [ 1.35032776e+02,  1.44609123e-01],
#        [ 1.32611938e+02,  6.44460618e-02],
#        [ 1.35273987e+02,  1.19685665e-01],
#        [ 1.37122757e+02,  1.18687913e-01],
#        [ 1.34796387e+02,  1.13619372e-01],
#        [ 1.35546799e+02,  1.16791829e-01],
#        [ 1.38432983e+02,  1.05477288e-01],
#        [ 1.41046585e+02,  1.06688060e-01],
#        [ 1.41353729e+02,  9.92915630e-02],
#        [ 1.43355835e+02,  9.70014930e-02],
#        [ 1.43560150e+02,  8.89752731e-02],
#        [ 1.43655060e+02,  8.05587843e-02],
#        [ 1.41464859e+02,  8.08978975e-02],
#        [ 1.43676041e+02,  6.85553625e-02],
#        [ 1.47410004e+02,  7.06224069e-02],
#        [ 1.47078918e+02,  7.81027302e-02],
#        [ 1.50705429e+02,  7.03322068e-02],
#        [ 1.50397858e+02,  7.57435709e-02],
#        [ 1.52684525e+02,  7.08236396e-02],
#        [ 1.52534088e+02,  7.81687126e-02],
#        [ 1.48294022e+02,  9.06903446e-02],
#        [ 1.49580627e+02,  7.75977969e-02],
#        [ 1.51464020e+02,  6.49250075e-02],
#        [ 1.52140930e+02,  6.88441023e-02],
#        [ 1.51007843e+02,  7.35890195e-02],
#        [ 1.50835815e+02,  7.66529590e-02],
#        [ 1.49736099e+02,  7.29721934e-02],
#        [ 1.47678589e+02,  7.08658770e-02],
#        [ 1.48285706e+02,  7.02448860e-02]], dtype=float32)

# %%
train_predict.shape,test_predict.shape
# Out:
# ((378, 2), (91, 2))

# %%
train_data_campare =train_data[n_steps:]
test_data_campare = test_data[n_steps:]
train_data_campare.shape,test_data_campare.shape
# Out:
# ((378, 2), (91, 2))

# %%
### Calculate RMSE performance metrics
import math
from sklearn.metrics import mean_squared_error

print(f"The RMSE for train is {math.sqrt(mean_squared_error(train_data_campare, train_predict))}")
print(f"The RMSE for test is {math.sqrt(mean_squared_error(test_data_campare, test_predict))}")
# Out:
# The RMSE for train is 2.1706537422739225
# The RMSE for test is 2.675607936967998

# %%
# Assuming `test_data_scaled` is your time series data and `model` is your trained model
window_size=n_steps
input_seq = test_data_scaled[-n_steps:]

for _ in range(window_size):
    # Reshape the input sequence
    input_seq = input_seq.reshape((1, n_steps, n_features))

    # Make a prediction
    prediction = model.predict(input_seq)

    # Update the input sequence
    input_seq = np.concatenate((input_seq[:, 1:, :], prediction.reshape(1, 1, n_features)), axis=1)

# `input_seq` now contains the original data for the last `n_steps` time steps followed by `window_size` forecasted time steps
# Out:
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step

# %%
input_seq
# Out:
# array([[[1.04263008, 0.45163631],
#         [0.97997129, 0.4875685 ],
#         [0.90639114, 0.4741987 ],
#         [0.84424305, 0.46137229],
#         [0.7998783 , 0.44858068]]])

# %%
# Reshape the input sequence to 2D
input_seq_2d = input_seq.reshape(-1, n_features)

# Apply inverse transformation
future_predict = scaler.inverse_transform(input_seq_2d)

future_predict
# Out:
# array([[1.85043720e+02, 9.36408569e-02],
#        [1.81495979e+02, 1.38864047e-01],
#        [1.77329871e+02, 1.22037211e-01],
#        [1.73811046e+02, 1.05894265e-01],
#        [1.71299114e+02, 8.97951281e-02]])

# %%
train_predict.shape,future_predict.shape,test_predict.shape
# Out:
# ((378, 2), (5, 2), (91, 2))

# %%
def extract_first_column(data):
    return data[:, 0].tolist()
train_predict_senti = extract_first_column(train_predict)
test_predict_senti = extract_first_column(test_predict)
future_predict_senti = extract_first_column(future_predict)

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming 'dates', 'stock_open', 'train_predict_senti', 'test_predict_senti', 'future_predict_senti' are defined
dates = np.array(index)
stock_open = np.array(stock_open)
train_predict_senti = np.array(train_predict_senti).flatten()
test_predict_senti = np.array(test_predict_senti).flatten()

# Create empty arrays for the plot
trainPredictPlot = np.empty_like(stock_open)
trainPredictPlot[:] = np.nan
trainPredictPlot[n_steps:len(train_predict_senti)+n_steps] = train_predict_senti

testPredictPlot = np.empty_like(stock_open)
testPredictPlot[:] = np.nan
testPredictPlot[len(train_predict_senti)+(n_steps*2):len(train_predict_senti)+(n_steps*2)+len(test_predict_senti)] = test_predict_senti

# Flatten future_predict_senti
future_predict_senti = np.array(future_predict_senti).flatten()

# Create an array for the future prediction dates
future_dates = np.arange(dates[-1] + np.timedelta64(1, 'D'), dates[-1] + np.timedelta64(window_size + 1, 'D'), np.timedelta64(1, 'D'))

# Create an array for the plot
futurePredictPlot = np.empty_like(np.concatenate((stock_open, np.full(window_size, np.nan))))
futurePredictPlot[:] = np.nan
futurePredictPlot[len(train_predict_senti) + (n_steps * 2) + len(test_predict_senti):] = future_predict_senti

# Plotting
plt.figure(figsize=(8,4))
plt.plot(np.concatenate((dates, future_dates)), np.concatenate((stock_open, np.full(window_size, np.nan))), color='blue', label='Actual')
plt.plot(dates, trainPredictPlot, color='orange', label='Train Predict')
plt.plot(dates, testPredictPlot, color='green', label='Test Predict')
plt.plot(np.concatenate((dates, future_dates)), futurePredictPlot, color='red', label='Future Predict')
plt.xlabel('Date')
plt.ylabel('Price')
plt.title('Stock Prices along with sentiment score Over Time for GRU')
plt.legend()
plt.show()

# %%
future_predict_senti
# Out:
# array([185.04371993, 181.49597925, 177.32987119, 173.81104592,
#        171.29911364])
