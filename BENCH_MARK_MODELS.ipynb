# %%
#installing pandas datareader
#!pip install pandas-datareader

# %%
import pandas_datareader as pdr
import pandas as pd
from datetime import datetime

# %%
#!pip install yfinance

# %%
import yfinance as yf

# Define the stock symbol and the date range
symbol = 'AAPL'
start_date = '2021-08-18'
end_date = '2023-07-17'

# Retrieve the stock data from Yahoo Finance
data = yf.download(symbol, start=start_date, end=end_date)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
data.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2021-08-18  149.800003  150.720001  146.149994  146.360001  144.881500
# 2021-08-19  145.029999  148.000000  144.500000  146.699997  145.218033
# 2021-08-20  147.440002  148.500000  146.779999  148.190002  146.692978
# 2021-08-23  148.309998  150.190002  147.889999  149.710007  148.197632
# 2021-08-24  149.449997  150.860001  149.149994  149.619995  148.108521
#
#               Volume
# Date
# 2021-08-18  86326000
# 2021-08-19  86960300
# 2021-08-20  60549600
# 2021-08-23  60131800
# 2021-08-24  48606400

# %%
data.tail()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2023-07-10  189.259995  189.990005  187.039993  188.610001  188.610001
# 2023-07-11  189.160004  189.300003  186.600006  188.080002  188.080002
# 2023-07-12  189.679993  191.699997  188.470001  189.770004  189.770004
# 2023-07-13  190.500000  191.190002  189.779999  190.539993  190.539993
# 2023-07-14  190.229996  191.179993  189.630005  190.690002  190.690002
#
#               Volume
# Date
# 2023-07-10  59922200
# 2023-07-11  46638100
# 2023-07-12  60750200
# 2023-07-13  41342300
# 2023-07-14  41573900

# %%
data['High'].plot(xlim=['2021-08-18','2023-07-17'],ylim=[120,200],figsize=(12,4),ls='--',c='green')
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
index = data.loc['2021-08-18':'2023-07-17'].index
stock_open = data.loc['2021-08-18':'2023-07-17']['Open']
stock_high = data.loc['2021-08-18':'2023-07-17']['High']
stock_low = data.loc['2021-08-18':'2023-07-17']['Low']
stock_close = data.loc['2021-08-18':'2023-07-17']['Close']

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

figure, axis = plt.subplots(figsize=(12,4))
plt.tight_layout()
# preventing overlapping
figure.autofmt_xdate()

# assuming 'index', 'stock_open', 'stock_high', 'stock_low', 'stock_close' are defined
axis.plot(index, stock_open, label='Open')
axis.plot(index, stock_high, label='High')
axis.plot(index, stock_low, label='Low')
axis.plot(index, stock_close, label='Close')

# Add labels and title
axis.set_xlabel('Date')
axis.set_ylabel('Price')
axis.set_title('Stock Prices Over Time')

# Add a legend
axis.legend()

plt.show()

# %%
df1 = stock_open

# %%
df1
# Out:
# Date
# 2021-08-18    149.800003
# 2021-08-19    145.029999
# 2021-08-20    147.440002
# 2021-08-23    148.309998
# 2021-08-24    149.449997
#                  ...
# 2023-07-10    189.259995
# 2023-07-11    189.160004
# 2023-07-12    189.679993
# 2023-07-13    190.500000
# 2023-07-14    190.229996
# Name: Open, Length: 479, dtype: float64

# %%
# Calculate the split point
split_point = int(len(df1) * 0.8)

# Split the data
train_data = df1.iloc[:split_point]
test_data = df1.iloc[split_point:]

# Print the shapes of the training and testing sets
print("Training set shape:", train_data.shape)
print("Testing set shape:", test_data.shape)
# Out:
# Training set shape: (383,)
# Testing set shape: (96,)

# %%
import numpy as np
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler(feature_range=(0,1))
train_data_scaled=scaler.fit_transform(np.array(train_data).reshape(-1,1))
test_data_scaled=scaler.fit_transform(np.array(test_data).reshape(-1,1))

# %%
train_data_scaled
# Out:
# array([[0.42016955],
#        [0.33592363],
#        [0.37848815],
#        [0.39385366],
#        [0.41398788],
#        [0.42034607],
#        [0.39456028],
#        [0.3791945 ],
#        [0.40604021],
#        [0.47068174],
#        [0.47368418],
#        [0.49205213],
#        [0.49010934],
#        [0.51148   ],
#        [0.54697973],
#        [0.52066411],
#        [0.51200983],
#        [0.43482871],
#        [0.42988348],
#        [0.39826906],
#        [0.39614976],
#        [0.40286125],
#        [0.31419993],
#        [0.31649576],
#        [0.32567986],
#        [0.36453534],
#        [0.34705052],
#        [0.34369477],
#        [0.30448599],
#        [0.29070997],
#        [0.31172732],
#        [0.28064272],
#        [0.27817011],
#        [0.23807847],
#        [0.23772516],
#        [0.30113025],
#        [0.31826202],
#        [0.2871777 ],
#        [0.30413269],
#        [0.26898627],
#        [0.28435178],
#        [0.3136701 ],
#        [0.30801826],
#        [0.37089352],
#        [0.40074168],
#        [0.40268446],
#        [0.41822676],
#        [0.40038837],
#        [0.41186857],
#        [0.4123984 ],
#        [0.42052285],
#        [0.37460258],
#        [0.40586369],
#        [0.40003533],
#        [0.43058983],
#        [0.45160718],
#        [0.45708223],
#        [0.44860474],
#        [0.42723408],
#        [0.42405512],
#        [0.40533387],
#        [0.39597297],
#        [0.43023652],
#        [0.42264216],
#        [0.44136342],
#        [0.48922648],
#        [0.55881297],
#        [0.62998921],
#        [0.62009875],
#        [0.61356404],
#        [0.59272348],
#        [0.58919095],
#        [0.60014132],
#        [0.73242656],
#        [0.57806432],
#        [0.67131756],
#        [0.676086  ],
#        [0.76068523],
#        [0.81455317],
#        [0.8636524 ],
#        [0.86895094],
#        [0.97333081],
#        [0.86965728],
#        [0.86718467],
#        [0.94083352],
#        [0.77569743],
#        [0.74655589],
#        [0.80448593],
#        [0.83062502],
#        [0.88025435],
#        [0.90215457],
#        [0.95637582],
#        [0.94171666],
#        [0.94418927],
#        [0.91981617],
#        [0.91522425],
#        [1.        ],
#        [0.94666188],
#        [0.82462014],
#        [0.82797589],
#        [0.76068523],
#        [0.81790892],
#        [0.88502279],
#        [0.87901791],
#        [0.80060035],
#        [0.80360279],
#        [0.77693387],
#        [0.72359575],
#        [0.67838209],
#        [0.60067115],
#        [0.58230293],
#        [0.66213345],
#        [0.64358872],
#        [0.70116571],
#        [0.77975979],
#        [0.8477568 ],
#        [0.86082648],
#        [0.85605778],
#        [0.80660523],
#        [0.82744607],
#        [0.80748837],
#        [0.88378662],
#        [0.8500529 ],
#        [0.81808544],
#        [0.73048377],
#        [0.79406565],
#        [0.80960794],
#        [0.7951253 ],
#        [0.77375491],
#        [0.68827255],
#        [0.698163  ],
#        [0.46926878],
#        [0.66813833],
#        [0.6543623 ],
#        [0.68332732],
#        [0.67785227],
#        [0.74991164],
#        [0.67961854],
#        [0.65966084],
#        [0.57947728],
#        [0.62645694],
#        [0.60385011],
#        [0.5814198 ],
#        [0.44931108],
#        [0.43959715],
#        [0.54821617],
#        [0.57576822],
#        [0.60932516],
#        [0.66230997],
#        [0.69763318],
#        [0.74143415],
#        [0.79565513],
#        [0.84546098],
#        [0.81525952],
#        [0.89509004],
#        [0.92794063],
#        [0.91540077],
#        [0.84811011],
#        [0.85764752],
#        [0.90939589],
#        [0.81861526],
#        [0.79742139],
#        [0.8083715 ],
#        [0.75415052],
#        [0.74196397],
#        [0.73083708],
#        [0.78788398],
#        [0.66955129],
#        [0.68897916],
#        [0.75503339],
#        [0.75768279],
#        [0.71441191],
#        [0.62009875],
#        [0.64005645],
#        [0.52808195],
#        [0.58707164],
#        [0.63281513],
#        [0.54221129],
#        [0.56764377],
#        [0.59448948],
#        [0.66831512],
#        [0.52984795],
#        [0.51077339],
#        [0.52119394],
#        [0.48551742],
#        [0.2960085 ],
#        [0.32815248],
#        [0.34510774],
#        [0.4035676 ],
#        [0.36806787],
#        [0.24496648],
#        [0.23101366],
#        [0.20805352],
#        [0.26139164],
#        [0.21935694],
#        [0.20098899],
#        [0.34228181],
#        [0.40727665],
#        [0.42193555],
#        [0.38537617],
#        [0.36895074],
#        [0.37124683],
#        [0.32391387],
#        [0.39862237],
#        [0.37212997],
#        [0.25203101],
#        [0.12115847],
#        [0.12575066],
#        [0.14623792],
#        [0.10720592],
#        [0.0717062 ],
#        [0.13087241],
#        [0.15506872],
#        [0.19092202],
#        [0.24531952],
#        [0.29477206],
#        [0.28470509],
#        [0.20222543],
#        [0.19851638],
#        [0.17714572],
#        [0.20770049],
#        [0.27092906],
#        [0.30519234],
#        [0.33998572],
#        [0.34722704],
#        [0.34881652],
#        [0.29989408],
#        [0.31914516],
#        [0.41981624],
#        [0.4367715 ],
#        [0.38696565],
#        [0.44348272],
#        [0.50317903],
#        [0.51889784],
#        [0.49452474],
#        [0.46361694],
#        [0.46926878],
#        [0.54697973],
#        [0.62221833],
#        [0.61815596],
#        [0.60208411],
#        [0.61515352],
#        [0.70646398],
#        [0.65701171],
#        [0.71282217],
#        [0.67131756],
#        [0.73595882],
#        [0.77799352],
#        [0.77375491],
#        [0.80377958],
#        [0.8260331 ],
#        [0.82585659],
#        [0.84316488],
#        [0.83044851],
#        [0.77145882],
#        [0.72536202],
#        [0.7296009 ],
#        [0.75538669],
#        [0.78700111],
#        [0.62062858],
#        [0.63793714],
#        [0.6057929 ],
#        [0.54097485],
#        [0.59590244],
#        [0.53797241],
#        [0.50883087],
#        [0.50565164],
#        [0.5203108 ],
#        [0.59307652],
#        [0.59855157],
#        [0.50830077],
#        [0.50582816],
#        [0.44507247],
#        [0.41151526],
#        [0.48375116],
#        [0.55333791],
#        [0.46573651],
#        [0.44471916],
#        [0.41769693],
#        [0.4720947 ],
#        [0.38202042],
#        [0.35482167],
#        [0.26969262],
#        [0.21547164],
#        [0.33592363],
#        [0.31896864],
#        [0.34969965],
#        [0.29194614],
#        [0.25450363],
#        [0.24531952],
#        [0.23172028],
#        [0.15860125],
#        [0.32320725],
#        [0.26598383],
#        [0.34404808],
#        [0.27693394],
#        [0.3004239 ],
#        [0.2977745 ],
#        [0.37407275],
#        [0.42529129],
#        [0.44065707],
#        [0.38961505],
#        [0.39191087],
#        [0.47951254],
#        [0.51342279],
#        [0.40515708],
#        [0.28346864],
#        [0.28399847],
#        [0.19604376],
#        [0.25432711],
#        [0.22059338],
#        [0.26898627],
#        [0.34987644],
#        [0.40551038],
#        [0.46291059],
#        [0.40833631],
#        [0.36064976],
#        [0.46450007],
#        [0.42652773],
#        [0.3906747 ],
#        [0.41398788],
#        [0.39385366],
#        [0.33786641],
#        [0.32285394],
#        [0.27181192],
#        [0.39208766],
#        [0.35234906],
#        [0.38431652],
#        [0.37195345],
#        [0.28576474],
#        [0.28876718],
#        [0.28841387],
#        [0.29477206],
#        [0.41487101],
#        [0.34157547],
#        [0.26669018],
#        [0.18862592],
#        [0.16072056],
#        [0.09501937],
#        [0.12310126],
#        [0.14729784],
#        [0.0867184 ],
#        [0.09484286],
#        [0.0646414 ],
#        [0.0349699 ],
#        [0.04238787],
#        [0.07541498],
#        [0.01554216],
#        [0.01978091],
#        [0.        ],
#        [0.07877073],
#        [0.07506168],
#        [0.09254676],
#        [0.13899686],
#        [0.10632279],
#        [0.15577533],
#        [0.19092202],
#        [0.14252913],
#        [0.163723  ],
#        [0.21388189],
#        [0.25256084],
#        [0.2628046 ],
#        [0.30307303],
#        [0.30289652],
#        [0.33468745],
#        [0.29477206],
#        [0.31720237],
#        [0.40427394],
#        [0.38890843],
#        [0.46909226],
#        [0.43500523],
#        [0.49222892],
#        [0.49046265],
#        [0.41416467],
#        [0.44048028],
#        [0.46114433],
#        [0.47862941],
#        [0.48569394],
#        [0.46520669],
#        [0.42723408],
#        [0.40374412],
#        [0.42529129],
#        [0.37265979]])

# %%
train_data_scaled.shape,test_data_scaled.shape
# Out:
# ((383, 1), (96, 1))

# %%
def prepare_data(train_data, window_size):
    X, y = [], []
    for i in range(len(train_data) - window_size):
        X.append(train_data[i:i+window_size])
        y.append(train_data[i+window_size])
    X = np.array(X)
    y = np.array(y)
    return X, y

# %%
X_train, y_train = prepare_data(train_data_scaled, window_size=5)
X_test, y_test = prepare_data(test_data_scaled, window_size=5)

# %%
X_train.shape,y_train.shape
# Out:
# ((378, 5, 1), (378, 1))

# %%
from keras.models import Sequential
from keras.layers import SimpleRNN, Dense

# Assuming each data point has 5 time steps and 2 features (open and score)
n_steps = 5
n_features = 1
input_shape=(n_steps, n_features)
model = Sequential()
model.add(SimpleRNN(128, return_sequences=True, input_shape=(n_steps, n_features)))
model.add(SimpleRNN(128))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mse')

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn (SimpleRNN)      (None, 5, 128)            16640
#
#  simple_rnn_1 (SimpleRNN)    (None, 128)               32896
#
#  dense (Dense)               (None, 1)                 129
#
# =================================================================
# Total params: 49,665
# Trainable params: 49,665
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Train the model
model.fit(X_train, y_train, epochs=200, verbose=1)
# Out:
# Epoch 1/200
# 12/12 [==============================] - 1s 3ms/step - loss: 0.1153
# Epoch 2/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0259
# Epoch 3/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0122
# Epoch 4/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0076
# Epoch 5/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0059
# Epoch 6/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0054
# Epoch 7/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0044
# Epoch 8/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0042
# Epoch 9/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0042
# Epoch 10/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0037
# Epoch 11/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0040
# Epoch 12/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0035
# Epoch 13/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0034
# Epoch 14/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0041
# Epoch 15/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0034
# Epoch 16/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0035
# Epoch 17/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0035
# Epoch 18/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0033
# Epoch 19/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0036
# Epoch 20/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0038
# Epoch 21/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0037
# Epoch 22/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0034
# Epoch 23/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0037
# Epoch 24/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0035
# Epoch 25/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0042
# Epoch 26/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0034
# Epoch 27/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0034
# Epoch 28/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0038
# Epoch 29/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0033
# Epoch 30/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0032
# Epoch 31/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0039
# Epoch 32/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0043
# Epoch 33/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0034
# Epoch 34/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0033
# Epoch 35/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0034
# Epoch 36/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0033
# Epoch 37/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0033
# Epoch 38/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0035
# Epoch 39/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0040
# Epoch 40/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0032
# Epoch 41/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0036
# Epoch 42/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0035
# Epoch 43/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0037
# Epoch 44/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0034
# Epoch 45/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0032
# Epoch 46/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0031
# Epoch 47/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0034
# Epoch 48/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0033
# Epoch 49/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0032
# Epoch 50/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0033
# Epoch 51/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0033
# Epoch 52/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0031
# Epoch 53/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0031
# Epoch 54/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0034
# Epoch 55/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0033
# Epoch 56/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0034
# Epoch 57/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0032
# Epoch 58/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0032
# Epoch 59/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0032
# Epoch 60/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0033
# Epoch 61/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0034
# Epoch 62/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0033
# Epoch 63/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0032
# Epoch 64/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0032
# Epoch 65/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0032
# Epoch 66/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0034
# Epoch 67/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0033
# Epoch 68/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0033
# Epoch 69/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0032
# Epoch 70/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0032
# Epoch 71/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0035
# Epoch 72/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0034
# Epoch 73/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0033
# Epoch 74/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0033
# Epoch 75/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0035
# Epoch 76/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0037
# Epoch 77/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0041
# Epoch 78/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0041
# Epoch 79/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0035
# Epoch 80/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0032
# Epoch 81/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0032
# Epoch 82/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0033
# Epoch 83/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0033
# Epoch 84/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0032
# Epoch 85/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0032
# Epoch 86/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0031
# Epoch 87/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0033
# Epoch 88/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0033
# Epoch 89/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0031
# Epoch 90/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0033
# Epoch 91/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0034
# Epoch 92/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0038
# Epoch 93/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0032
# Epoch 94/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0037
# Epoch 95/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0036
# Epoch 96/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0032
# Epoch 97/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0032
# Epoch 98/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0034
# Epoch 99/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0033
# Epoch 100/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0033
# Epoch 101/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0033
# Epoch 102/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0032
# Epoch 103/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0032
# Epoch 104/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0033
# Epoch 105/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0033
# Epoch 106/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0037
# Epoch 107/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0032
# Epoch 108/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0033
# Epoch 109/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0032
# Epoch 110/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0032
# Epoch 111/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0032
# Epoch 112/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0032
# Epoch 113/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0032
# Epoch 114/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0033
# Epoch 115/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0036
# Epoch 116/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0034
# Epoch 117/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0032
# Epoch 118/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0035
# Epoch 119/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0032
# Epoch 120/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0031
# Epoch 121/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0035
# Epoch 122/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0034
# Epoch 123/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0032
# Epoch 124/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0032
# Epoch 125/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0033
# Epoch 126/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0033
# Epoch 127/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0032
# Epoch 128/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0032
# Epoch 129/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0031
# Epoch 130/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0034
# Epoch 131/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0034
# Epoch 132/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0033
# Epoch 133/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0032
# Epoch 134/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0031
# Epoch 135/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0033
# Epoch 136/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0032
# Epoch 137/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0033
# Epoch 138/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0034
# Epoch 139/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0033
# Epoch 140/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0032
# Epoch 141/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0032
# Epoch 142/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0033
# Epoch 143/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0032
# Epoch 144/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0031
# Epoch 145/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0034
# Epoch 146/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0033
# Epoch 147/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0032
# Epoch 148/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0032
# Epoch 149/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0032
# Epoch 150/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0032
# Epoch 151/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0032
# Epoch 152/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0032
# Epoch 153/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0032
# Epoch 154/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0033
# Epoch 155/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0033
# Epoch 156/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0031
# Epoch 157/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0031
# Epoch 158/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0032
# Epoch 159/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0031
# Epoch 160/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0032
# Epoch 161/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0032
# Epoch 162/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0031
# Epoch 163/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0033
# Epoch 164/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0032
# Epoch 165/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0034
# Epoch 166/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0034
# Epoch 167/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0033
# Epoch 168/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0036
# Epoch 169/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0033
# Epoch 170/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0032
# Epoch 171/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0032
# Epoch 172/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0032
# Epoch 173/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0035
# Epoch 174/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0034
# Epoch 175/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0034
# Epoch 176/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0032
# Epoch 177/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0033
# Epoch 178/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0033
# Epoch 179/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0033
# Epoch 180/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0034
# Epoch 181/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0038
# Epoch 182/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0036
# Epoch 183/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0032
# Epoch 184/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0032
# Epoch 185/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0034
# Epoch 186/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0032
# Epoch 187/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0032
# Epoch 188/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0032
# Epoch 189/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0032
# Epoch 190/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0032
# Epoch 191/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0032
# Epoch 192/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0031
# Epoch 193/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0033
# Epoch 194/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0033
# Epoch 195/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0032
# Epoch 196/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0032
# Epoch 197/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0033
# Epoch 198/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0036
# Epoch 199/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0032
# Epoch 200/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0033

# %%
### Lets Do the prediction and check performance metrics
train_predict=model.predict(X_train)
test_predict=model.predict(X_test)
# Out:
# 12/12 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 1ms/step

# %%
train_predict.shape
# Out:
# (378, 1)

# %%
##Transformback to original form
train_predict=scaler.inverse_transform(train_predict)
test_predict=scaler.inverse_transform(test_predict)

# %%
train_predict.shape,test_predict.shape
# Out:
# ((378, 1), (91, 1))

# %%
train_data_compare = np.array(train_data[n_steps:]).reshape(-1,1)
test_data_campare = np.array(test_data[n_steps:]).reshape(-1,1)
train_data_compare.shape,test_data_campare.shape
# Out:
# ((378, 1), (91, 1))

# %%
### Calculate RMSE performance metrics
import math
from sklearn.metrics import mean_squared_error

print(f"The RMSE for train is {math.sqrt(mean_squared_error(train_data_compare, train_predict))}")
print(f"The RMSE for test is {math.sqrt(mean_squared_error(test_data_campare, test_predict))}")
# Out:
# The RMSE for train is 15.645408051907378
# The RMSE for test is 1.9032124773780537

# %%
#predicting for next five days
# Assuming `test_data_scaled` is your time series data and `model` is your trained model
window_size=n_steps
input_seq = test_data_scaled[-n_steps:]

for _ in range(window_size):
    # Reshape the input sequence
    input_seq = input_seq.reshape((1, n_steps, n_features))

    # Make a prediction
    prediction = model.predict(input_seq)

    # Update the input sequence
    input_seq = np.append(input_seq[:, 1:, :], prediction)

# `input_seq` now contains the original data for the last `n_steps` time steps followed by `window_size` forecasted time steps
# Out:
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step

# %%
future_predict = scaler.inverse_transform(np.array(input_seq).reshape(-1,1))

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming 'dates', 'stock_open', 'train_predict', 'test_predict' are defined
dates = np.array(index)
stock_open = np.array(stock_open)
train_predict = np.array(train_predict)
test_predict = np.array(test_predict)

# Create empty arrays for the plot
trainPredictPlot = np.empty_like(stock_open)
trainPredictPlot[:] = np.nan
trainPredictPlot[n_steps:len(train_predict)+n_steps] = train_predict.flatten()

testPredictPlot = np.empty_like(stock_open)
testPredictPlot[:] = np.nan
testPredictPlot[len(train_predict)+(n_steps*2):len(train_predict)+(n_steps*2)+len(test_predict)] = test_predict.flatten()

# Flatten future_predict
future_predict = future_predict.flatten()

# Create an array for the future prediction dates
future_dates = np.arange(dates[-1] + np.timedelta64(1, 'D'), dates[-1] + np.timedelta64(window_size + 1, 'D'), np.timedelta64(1, 'D'))

# Create an array for the plot
futurePredictPlot = np.empty_like(np.concatenate((stock_open, np.full(window_size, np.nan))))
futurePredictPlot[:] = np.nan
futurePredictPlot[len(train_predict) + (n_steps * 2) + len(test_predict):] = future_predict

# Plotting
plt.figure(figsize=(8,4))
plt.plot(np.concatenate((dates, future_dates)), np.concatenate((stock_open, np.full(window_size, np.nan))), color='blue', label='Actual')
plt.plot(dates, trainPredictPlot, color='orange', label='Train Predict')
plt.plot(dates, testPredictPlot, color='green', label='Test Predict')
plt.plot(np.concatenate((dates, future_dates)), futurePredictPlot, color='red', label='Future Predict')
plt.xlabel('Date')
plt.ylabel('Price')
plt.title('BENCHMARK_RNN')
plt.legend()
plt.show()

# %%
future_predict
# Out:
# array([190.07820341, 189.90050764, 189.79128551, 189.69839634,
#        189.6083692 ])

# %% [markdown]
# # LSTM

# %%
from keras.models import Sequential
from keras.layers import LSTM, Dense

model = Sequential()
model.add(LSTM(128, input_shape=(n_steps, n_features)))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mse')

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 128)               66560
#
#  dense_1 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 66,689
# Trainable params: 66,689
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Train the model
model.fit(X_train, y_train, epochs=200, verbose=1)
# Out:
# Epoch 1/200
# 12/12 [==============================] - 2s 7ms/step - loss: 0.1511
# Epoch 2/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0200
# Epoch 3/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0105
# Epoch 4/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0093
# Epoch 5/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0083
# Epoch 6/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0075
# Epoch 7/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0072
# Epoch 8/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0070
# Epoch 9/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0070
# Epoch 10/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0069
# Epoch 11/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0068
# Epoch 12/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0068
# Epoch 13/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0067
# Epoch 14/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0068
# Epoch 15/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0068
# Epoch 16/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0067
# Epoch 17/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0067
# Epoch 18/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0066
# Epoch 19/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0066
# Epoch 20/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0064
# Epoch 21/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0066
# Epoch 22/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0064
# Epoch 23/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0064
# Epoch 24/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0065
# Epoch 25/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0064
# Epoch 26/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0061
# Epoch 27/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0062
# Epoch 28/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0063
# Epoch 29/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0065
# Epoch 30/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0062
# Epoch 31/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0060
# Epoch 32/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0059
# Epoch 33/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0058
# Epoch 34/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0058
# Epoch 35/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0057
# Epoch 36/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0058
# Epoch 37/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0057
# Epoch 38/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0055
# Epoch 39/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0055
# Epoch 40/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0055
# Epoch 41/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0054
# Epoch 42/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0053
# Epoch 43/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0053
# Epoch 44/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0054
# Epoch 45/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0052
# Epoch 46/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0051
# Epoch 47/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0052
# Epoch 48/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0051
# Epoch 49/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0051
# Epoch 50/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0048
# Epoch 51/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0051
# Epoch 52/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0051
# Epoch 53/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0048
# Epoch 54/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0049
# Epoch 55/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0047
# Epoch 56/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0048
# Epoch 57/200
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0048
# Epoch 58/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0046
# Epoch 59/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0049
# Epoch 60/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0046
# Epoch 61/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0045
# Epoch 62/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0049
# Epoch 63/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0053
# Epoch 64/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0047
# Epoch 65/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0051
# Epoch 66/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0049
# Epoch 67/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0046
# Epoch 68/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0045
# Epoch 69/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0045
# Epoch 70/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0043
# Epoch 71/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0042
# Epoch 72/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0043
# Epoch 73/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0043
# Epoch 74/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0045
# Epoch 75/200
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0044
# Epoch 76/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0043
# Epoch 77/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0043
# Epoch 78/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0042
# Epoch 79/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0043
# Epoch 80/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0041
# Epoch 81/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0040
# Epoch 82/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0043
# Epoch 83/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0044
# Epoch 84/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0041
# Epoch 85/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0041
# Epoch 86/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0040
# Epoch 87/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0043
# Epoch 88/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0040
# Epoch 89/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0039
# Epoch 90/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0041
# Epoch 91/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0040
# Epoch 92/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0040
# Epoch 93/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0041
# Epoch 94/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0038
# Epoch 95/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0039
# Epoch 96/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0039
# Epoch 97/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0039
# Epoch 98/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0038
# Epoch 99/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0039
# Epoch 100/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0041
# Epoch 101/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0039
# Epoch 102/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0042
# Epoch 103/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0043
# Epoch 104/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0039
# Epoch 105/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0041
# Epoch 106/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0038
# Epoch 107/200
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0039
# Epoch 108/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0037
# Epoch 109/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0040
# Epoch 110/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0037
# Epoch 111/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0039
# Epoch 112/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0039
# Epoch 113/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0036
# Epoch 114/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0036
# Epoch 115/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0036
# Epoch 116/200
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0038
# Epoch 117/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0039
# Epoch 118/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0039
# Epoch 119/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0039
# Epoch 120/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0038
# Epoch 121/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0035
# Epoch 122/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0037
# Epoch 123/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0035
# Epoch 124/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0035
# Epoch 125/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0038
# Epoch 126/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0037
# Epoch 127/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0037
# Epoch 128/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0034
# Epoch 129/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0036
# Epoch 130/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0036
# Epoch 131/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0035
# Epoch 132/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0035
# Epoch 133/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0036
# Epoch 134/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0035
# Epoch 135/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0035
# Epoch 136/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0037
# Epoch 137/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0037
# Epoch 138/200
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0036
# Epoch 139/200
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0034
# Epoch 140/200
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0035
# Epoch 141/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0033
# Epoch 142/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0036
# Epoch 143/200
# 12/12 [==============================] - 0s 9ms/step - loss: 0.0035
# Epoch 144/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0035
# Epoch 145/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0035
# Epoch 146/200
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0037
# Epoch 147/200
# 12/12 [==============================] - 0s 9ms/step - loss: 0.0035
# Epoch 148/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0034
# Epoch 149/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0034
# Epoch 150/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0033
# Epoch 151/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0033
# Epoch 152/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0034
# Epoch 153/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0033
# Epoch 154/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0033
# Epoch 155/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0033
# Epoch 156/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0034
# Epoch 157/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0035
# Epoch 158/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0033
# Epoch 159/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0033
# Epoch 160/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0033
# Epoch 161/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0034
# Epoch 162/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0033
# Epoch 163/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0033
# Epoch 164/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0033
# Epoch 165/200
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0033
# Epoch 166/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0036
# Epoch 167/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0035
# Epoch 168/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0033
# Epoch 169/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0033
# Epoch 170/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0033
# Epoch 171/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0033
# Epoch 172/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0033
# Epoch 173/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0033
# Epoch 174/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0033
# Epoch 175/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0032
# Epoch 176/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0033
# Epoch 177/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0033
# Epoch 178/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0033
# Epoch 179/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0032
# Epoch 180/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0032
# Epoch 181/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0034
# Epoch 182/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0032
# Epoch 183/200
# 12/12 [==============================] - 0s 9ms/step - loss: 0.0034
# Epoch 184/200
# 12/12 [==============================] - 0s 9ms/step - loss: 0.0032
# Epoch 185/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0033
# Epoch 186/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0032
# Epoch 187/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0033
# Epoch 188/200
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0034
# Epoch 189/200
# 12/12 [==============================] - 0s 10ms/step - loss: 0.0032
# Epoch 190/200
# 12/12 [==============================] - 0s 9ms/step - loss: 0.0032
# Epoch 191/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0032
# Epoch 192/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0033
# Epoch 193/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0032
# Epoch 194/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0032
# Epoch 195/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0031
# Epoch 196/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0034
# Epoch 197/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0033
# Epoch 198/200
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0032
# Epoch 199/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0034
# Epoch 200/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0033

# %%
### Lets Do the prediction and check performance metrics
train_predict=model.predict(X_train)
test_predict=model.predict(X_test)
# Out:
# 12/12 [==============================] - 0s 4ms/step
# 3/3 [==============================] - 0s 3ms/step

# %%
##Transformback to original form
train_predict=scaler.inverse_transform(train_predict)
test_predict=scaler.inverse_transform(test_predict)

# %%
train_data_compare = np.array(train_data[n_steps:]).reshape(-1,1)
test_data_campare = np.array(test_data[n_steps:]).reshape(-1,1)
train_data_compare.shape,test_data_campare.shape
# Out:
# ((378, 1), (91, 1))

# %%
### Calculate RMSE performance metrics
import math
from sklearn.metrics import mean_squared_error

print(f"The RMSE for train is {math.sqrt(mean_squared_error(train_data_compare, train_predict))}")
print(f"The RMSE for test is {math.sqrt(mean_squared_error(test_data_campare, test_predict))}")
# Out:
# The RMSE for train is 15.655311344930189
# The RMSE for test is 1.9284243295007435

# %%
#predicting for next five days
# Assuming `test_data_scaled` is your time series data and `model` is your trained model
window_size=n_steps
input_seq = test_data_scaled[-n_steps:]

for _ in range(window_size):
    # Reshape the input sequence
    input_seq = input_seq.reshape((1, n_steps, n_features))

    # Make a prediction
    prediction = model.predict(input_seq)

    # Update the input sequence
    input_seq = np.append(input_seq[:, 1:, :], prediction)

# `input_seq` now contains the original data for the last `n_steps` time steps followed by `window_size` forecasted time steps
# Out:
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step

# %%
future_predict = scaler.inverse_transform(np.array(input_seq).reshape(-1,1))

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming 'dates', 'stock_open', 'train_predict', 'test_predict' are defined
dates = np.array(index)
stock_open = np.array(stock_open)
train_predict = np.array(train_predict)
test_predict = np.array(test_predict)

# Create empty arrays for the plot
trainPredictPlot = np.empty_like(stock_open)
trainPredictPlot[:] = np.nan
trainPredictPlot[n_steps:len(train_predict)+n_steps] = train_predict.flatten()

testPredictPlot = np.empty_like(stock_open)
testPredictPlot[:] = np.nan
testPredictPlot[len(train_predict)+(n_steps*2):len(train_predict)+(n_steps*2)+len(test_predict)] = test_predict.flatten()

# Flatten future_predict
future_predict = future_predict.flatten()

# Create an array for the future prediction dates
future_dates = np.arange(dates[-1] + np.timedelta64(1, 'D'), dates[-1] + np.timedelta64(window_size + 1, 'D'), np.timedelta64(1, 'D'))

# Create an array for the plot
futurePredictPlot = np.empty_like(np.concatenate((stock_open, np.full(window_size, np.nan))))
futurePredictPlot[:] = np.nan
futurePredictPlot[len(train_predict) + (n_steps * 2) + len(test_predict):] = future_predict

# Plotting
plt.figure(figsize=(8,4))
plt.plot(np.concatenate((dates, future_dates)), np.concatenate((stock_open, np.full(window_size, np.nan))), color='blue', label='Actual')
plt.plot(dates, trainPredictPlot, color='orange', label='Train Predict')
plt.plot(dates, testPredictPlot, color='green', label='Test Predict')
plt.plot(np.concatenate((dates, future_dates)), futurePredictPlot, color='red', label='Future Predict')
plt.xlabel('Date')
plt.ylabel('Price')
plt.title('BENCHMARK_LSTM')
plt.legend()
plt.show()

# %%
future_predict
# Out:
# array([190.59395367, 190.89680998, 191.2569215 , 191.62104043,
#        191.97635835])

# %% [markdown]
# # GRU

# %%
from keras.models import Sequential
from keras.layers import GRU, Dense

model = Sequential()
model.add(GRU(128, input_shape=(n_steps, n_features)))
model.add(Dense(1))

model.compile(optimizer='adam', loss='mse')

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru (GRU)                   (None, 128)               50304
#
#  dense_2 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 50,433
# Trainable params: 50,433
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Train the model
model.fit(X_train, y_train, epochs=200, verbose=1)
# Out:
# Epoch 1/200
# 12/12 [==============================] - 2s 9ms/step - loss: 0.1083
# Epoch 2/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0254
# Epoch 3/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0134
# Epoch 4/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0089
# Epoch 5/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0074
# Epoch 6/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0066
# Epoch 7/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0061
# Epoch 8/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0060
# Epoch 9/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0058
# Epoch 10/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0057
# Epoch 11/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0057
# Epoch 12/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0056
# Epoch 13/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0055
# Epoch 14/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0054
# Epoch 15/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0054
# Epoch 16/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0056
# Epoch 17/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0054
# Epoch 18/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0051
# Epoch 19/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0051
# Epoch 20/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0050
# Epoch 21/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0050
# Epoch 22/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0048
# Epoch 23/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0048
# Epoch 24/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0047
# Epoch 25/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0046
# Epoch 26/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0047
# Epoch 27/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0046
# Epoch 28/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0046
# Epoch 29/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0047
# Epoch 30/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0044
# Epoch 31/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0044
# Epoch 32/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0042
# Epoch 33/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0042
# Epoch 34/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0042
# Epoch 35/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0042
# Epoch 36/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0041
# Epoch 37/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0041
# Epoch 38/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0040
# Epoch 39/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0040
# Epoch 40/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0040
# Epoch 41/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0040
# Epoch 42/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0039
# Epoch 43/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0038
# Epoch 44/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0039
# Epoch 45/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0039
# Epoch 46/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0039
# Epoch 47/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0040
# Epoch 48/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0041
# Epoch 49/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0039
# Epoch 50/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0037
# Epoch 51/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0037
# Epoch 52/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0037
# Epoch 53/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0036
# Epoch 54/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0037
# Epoch 55/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0037
# Epoch 56/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0037
# Epoch 57/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0036
# Epoch 58/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0036
# Epoch 59/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0035
# Epoch 60/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0037
# Epoch 61/200
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0035
# Epoch 62/200
# 12/12 [==============================] - 0s 10ms/step - loss: 0.0036
# Epoch 63/200
# 12/12 [==============================] - 0s 9ms/step - loss: 0.0038
# Epoch 64/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0039
# Epoch 65/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0037
# Epoch 66/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0036
# Epoch 67/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0035
# Epoch 68/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0035
# Epoch 69/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0036
# Epoch 70/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0036
# Epoch 71/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0039
# Epoch 72/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0036
# Epoch 73/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0034
# Epoch 74/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0036
# Epoch 75/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0036
# Epoch 76/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0034
# Epoch 77/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0034
# Epoch 78/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0034
# Epoch 79/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0035
# Epoch 80/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0033
# Epoch 81/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0034
# Epoch 82/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0034
# Epoch 83/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0035
# Epoch 84/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0035
# Epoch 85/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0035
# Epoch 86/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0035
# Epoch 87/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0033
# Epoch 88/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0033
# Epoch 89/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0035
# Epoch 90/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0033
# Epoch 91/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0033
# Epoch 92/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0033
# Epoch 93/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0033
# Epoch 94/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0032
# Epoch 95/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0032
# Epoch 96/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0032
# Epoch 97/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0032
# Epoch 98/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0032
# Epoch 99/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0035
# Epoch 100/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0036
# Epoch 101/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0035
# Epoch 102/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0032
# Epoch 103/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0033
# Epoch 104/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0032
# Epoch 105/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0033
# Epoch 106/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0033
# Epoch 107/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0033
# Epoch 108/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0032
# Epoch 109/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0032
# Epoch 110/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0032
# Epoch 111/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0032
# Epoch 112/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0032
# Epoch 113/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0032
# Epoch 114/200
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0032
# Epoch 115/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0033
# Epoch 116/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0032
# Epoch 117/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0032
# Epoch 118/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0032
# Epoch 119/200
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0032
# Epoch 120/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0033
# Epoch 121/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0032
# Epoch 122/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0032
# Epoch 123/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0031
# Epoch 124/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0033
# Epoch 125/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0033
# Epoch 126/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0034
# Epoch 127/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0033
# Epoch 128/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0032
# Epoch 129/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0032
# Epoch 130/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0032
# Epoch 131/200
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0032
# Epoch 132/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0032
# Epoch 133/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0032
# Epoch 134/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0032
# Epoch 135/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0032
# Epoch 136/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0032
# Epoch 137/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0031
# Epoch 138/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0032
# Epoch 139/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0033
# Epoch 140/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0032
# Epoch 141/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0032
# Epoch 142/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0032
# Epoch 143/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0032
# Epoch 144/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0032
# Epoch 145/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0032
# Epoch 146/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0031
# Epoch 147/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0032
# Epoch 148/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0033
# Epoch 149/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0031
# Epoch 150/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0032
# Epoch 151/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0032
# Epoch 152/200
# 12/12 [==============================] - 0s 9ms/step - loss: 0.0032
# Epoch 153/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0032
# Epoch 154/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0032
# Epoch 155/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0032
# Epoch 156/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0032
# Epoch 157/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0031
# Epoch 158/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0032
# Epoch 159/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0032
# Epoch 160/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0031
# Epoch 161/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0031
# Epoch 162/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0033
# Epoch 163/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0032
# Epoch 164/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0032
# Epoch 165/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0033
# Epoch 166/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0033
# Epoch 167/200
# 12/12 [==============================] - 0s 10ms/step - loss: 0.0032
# Epoch 168/200
# 12/12 [==============================] - 0s 9ms/step - loss: 0.0032
# Epoch 169/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0033
# Epoch 170/200
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0032
# Epoch 171/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0032
# Epoch 172/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0032
# Epoch 173/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0034
# Epoch 174/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0033
# Epoch 175/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0036
# Epoch 176/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0036
# Epoch 177/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0032
# Epoch 178/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0032
# Epoch 179/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0032
# Epoch 180/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0033
# Epoch 181/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0032
# Epoch 182/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0031
# Epoch 183/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0032
# Epoch 184/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0032
# Epoch 185/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0032
# Epoch 186/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0032
# Epoch 187/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0032
# Epoch 188/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0032
# Epoch 189/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0031
# Epoch 190/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0032
# Epoch 191/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0032
# Epoch 192/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0033
# Epoch 193/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0032
# Epoch 194/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0031
# Epoch 195/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0033
# Epoch 196/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0031
# Epoch 197/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0032
# Epoch 198/200
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0036
# Epoch 199/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0034
# Epoch 200/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0032

# %%
### Lets Do the prediction and check performance metrics
train_predict=model.predict(X_train)
test_predict=model.predict(X_test)
# Out:
# 12/12 [==============================] - 0s 3ms/step
# 3/3 [==============================] - 0s 4ms/step

# %%
##Transformback to original form
train_predict=scaler.inverse_transform(train_predict)
test_predict=scaler.inverse_transform(test_predict)

# %%
train_data_compare = np.array(train_data[n_steps:]).reshape(-1,1)
test_data_campare = np.array(test_data[n_steps:]).reshape(-1,1)
train_data_compare.shape,test_data_campare.shape
# Out:
# ((378, 1), (91, 1))

# %%
### Calculate RMSE performance metrics
import math
from sklearn.metrics import mean_squared_error

print(f"The RMSE for train is {math.sqrt(mean_squared_error(train_data_compare, train_predict))}")
print(f"The RMSE for test is {math.sqrt(mean_squared_error(test_data_campare, test_predict))}")
# Out:
# The RMSE for train is 15.564698186571997
# The RMSE for test is 1.920918082353486

# %%
#predicting for next five days
# Assuming `test_data_scaled` is your time series data and `model` is your trained model
window_size=n_steps
input_seq = test_data_scaled[-n_steps:]

for _ in range(window_size):
    # Reshape the input sequence
    input_seq = input_seq.reshape((1, n_steps, n_features))

    # Make a prediction
    prediction = model.predict(input_seq)

    # Update the input sequence
    input_seq = np.append(input_seq[:, 1:, :], prediction)

# `input_seq` now contains the original data for the last `n_steps` time steps followed by `window_size` forecasted time steps
# Out:
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 31ms/step

# %%
future_predict = scaler.inverse_transform(np.array(input_seq).reshape(-1,1))

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming 'dates', 'stock_open', 'train_predict', 'test_predict' are defined
dates = np.array(index)
stock_open = np.array(stock_open)
train_predict = np.array(train_predict)
test_predict = np.array(test_predict)

# Create empty arrays for the plot
trainPredictPlot = np.empty_like(stock_open)
trainPredictPlot[:] = np.nan
trainPredictPlot[n_steps:len(train_predict)+n_steps] = train_predict.flatten()

testPredictPlot = np.empty_like(stock_open)
testPredictPlot[:] = np.nan
testPredictPlot[len(train_predict)+(n_steps*2):len(train_predict)+(n_steps*2)+len(test_predict)] = test_predict.flatten()

# Flatten future_predict
future_predict = future_predict.flatten()

# Create an array for the future prediction dates
future_dates = np.arange(dates[-1] + np.timedelta64(1, 'D'), dates[-1] + np.timedelta64(window_size + 1, 'D'), np.timedelta64(1, 'D'))

# Create an array for the plot
futurePredictPlot = np.empty_like(np.concatenate((stock_open, np.full(window_size, np.nan))))
futurePredictPlot[:] = np.nan
futurePredictPlot[len(train_predict) + (n_steps * 2) + len(test_predict):] = future_predict

# Plotting
plt.figure(figsize=(8,4))
plt.plot(np.concatenate((dates, future_dates)), np.concatenate((stock_open, np.full(window_size, np.nan))), color='blue', label='Actual')
plt.plot(dates, trainPredictPlot, color='orange', label='Train Predict')
plt.plot(dates, testPredictPlot, color='green', label='Test Predict')
plt.plot(np.concatenate((dates, future_dates)), futurePredictPlot, color='red', label='Future Predict')
plt.xlabel('Date')
plt.ylabel('Price')
plt.title('BENCHMARK_GRU')
plt.legend()
plt.show()

# %%
future_predict
# Out:
# array([190.16261545, 190.08942184, 190.06460585, 190.03227852,
#        189.99990114])
